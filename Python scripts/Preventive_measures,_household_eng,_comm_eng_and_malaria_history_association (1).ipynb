# %%
#simple regression 1: Association between preventive measures and malaria history

import pandas as pd
import statsmodels.api as sm
import numpy as np

#step 1 Load the data
file_path = r'/content/Data of Malaria (THESIS) 17 april.xlsx'
sheet_name = 'Form responses 1'

#step 2 read the data
df = pd.read_excel(file_path, sheet_name=sheet_name)

# Convert outcome (malaria history) to binary
df['malaria_history'] = df['History of malaria in the past year in the household'].map({'Yes': 1, 'No': 0})

# Convert predictor (use of preventive measures) to binary
df['used_prevention'] = df['Use of malaria preventive measures'].map({'Yes': 1, 'No': 0})

# Set up predictor and outcome
X = sm.add_constant(df['used_prevention'])  # add intercept
y = df['malaria_history']

# Run logistic regression
model = sm.Logit(y, X).fit()

# Print regression results
print(model.summary())

# Calculate and display odds ratio + 95% confidence interval
odds_ratio = np.exp(model.params)
conf = np.exp(model.conf_int())
conf.columns = ['2.5%', '97.5%']

print("\nOdds Ratio and 95% CI:")
print(pd.concat([odds_ratio, conf], axis=1))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.663783
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:        malaria_history   No. Observations:                  282
# Model:                          Logit   Df Residuals:                      280
# Method:                           MLE   Df Model:                            1
# Date:                Sat, 10 May 2025   Pseudo R-squ.:               4.146e-06
# Time:                        12:38:33   Log-Likelihood:                -187.19
# converged:                       True   LL-Null:                       -187.19
# Covariance Type:            nonrobust   LLR p-value:                    0.9686
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.4700      0.570      0.824      0.410      -0.647       1.587
# used_prevention     0.0230      0.584      0.039      0.969      -1.121       1.167
# ===================================================================================
#
# Odds Ratio and 95% CI:
#                         0      2.5%     97.5%
# const            1.600000  0.523432  4.890796
# used_prevention  1.023284  0.325902  3.212962

# %%
#simple regression 2: using cases of malaria as the outcome
# Filter out rows with missing or invalid data
df_clean = df[['Cases of malaria in the past year', 'used_prevention']].copy()
df_clean = df_clean.dropna()

# Ensure both columns are numeric
df_clean['Cases of malaria in the past year'] = pd.to_numeric(df_clean['Cases of malaria in the past year'], errors='coerce')
df_clean['used_prevention'] = pd.to_numeric(df_clean['used_prevention'], errors='coerce')

# Drop again if coercion introduced NaNs
df_clean = df_clean.dropna()

# Drop rows with negative malaria case counts (shouldn't happen, but just in case)
df_clean = df_clean[df_clean['Cases of malaria in the past year'] >= 0]


# Define X and y
X = sm.add_constant(df_clean['used_prevention'])
y = df_clean['Cases of malaria in the past year']

# Run Poisson model
poisson_model = sm.GLM(y, X, family=sm.families.Poisson()).fit()

# Show results
print(poisson_model.summary())

# IRRs
import numpy as np
irr = np.exp(poisson_model.params)
conf = np.exp(poisson_model.conf_int())
conf.columns = ['2.5%', '97.5%']

print("\nIRRs and 95% CI:")
print(pd.concat([irr, conf], axis=1))
# Out:
#                          Generalized Linear Model Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  281
# Model:                                           GLM   Df Residuals:                      279
# Model Family:                                Poisson   Df Model:                            1
# Link Function:                                   Log   Scale:                          1.0000
# Method:                                         IRLS   Log-Likelihood:                -562.35
# Date:                               Sat, 10 May 2025   Deviance:                       650.84
# Time:                                       14:28:08   Pearson chi2:                     683.
# No. Iterations:                                    5   Pseudo R-squ. (CS):            0.02133
# Covariance Type:                           nonrobust
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.9614      0.171      5.606      0.000       0.625       1.298
# used_prevention    -0.4679      0.178     -2.628      0.009      -0.817      -0.119
# ===================================================================================
#
# IRRs and 95% CI:
#                         0      2.5%     97.5%
# const            2.615385  1.868769  3.660289
# used_prevention  0.626317  0.441842  0.887813

# %%
#separating the sample into rural and urban for preventive measures
import pandas as pd
import statsmodels.api as sm
import numpy as np

#step 1 Load the data
file_path = r'/content/Data of Malaria (THESIS) 17 april.xlsx'
sheet_name = 'Form responses 1'

#step 2 read the data
data = pd.read_excel(file_path, sheet_name=sheet_name)

# Map dependent and independent variables to numeric
data['History of malaria in the past year in the household'] = data['History of malaria in the past year in the household'].map({'Yes': 1, 'No': 0})
data['Use of malaria preventive measures'] = data['Use of malaria preventive measures'].map({'Yes': 1, 'No': 0})

# Filter rural and urban samples
rural_data = data[data['Area of residence'] == 'Rural area']
urban_data = data[data['Area of residence'] == 'Urban area']

# Define a function to run logistic regression
def run_logistic(X, y):
    X = sm.add_constant(X)
    model = sm.Logit(y, X)
    result = model.fit(disp=0)
    return result

# Prepare variables
predictor = 'Use of malaria preventive measures'
outcome = 'History of malaria in the past year in the household'

# 1. Rural regression
print("=== Rural Area Logistic Regression ===")
X_rural = rural_data[[predictor]]
y_rural = rural_data[outcome]

result_rural = run_logistic(X_rural, y_rural)
print(result_rural.summary())

odds_ratios_rural = pd.DataFrame({
    "OR": np.exp(result_rural.params),
    "2.5%": np.exp(result_rural.conf_int()[0]),
    "97.5%": np.exp(result_rural.conf_int()[1])
})
print("\nOdds Ratios and 95% CI (Rural):")
print(odds_ratios_rural)

# 2. Urban regression
print("\n=== Urban Area Logistic Regression ===")
X_urban = urban_data[[predictor]]
y_urban = urban_data[outcome]

result_urban = run_logistic(X_urban, y_urban)
print(result_urban.summary())

odds_ratios_urban = pd.DataFrame({
    "OR": np.exp(result_urban.params),
    "2.5%": np.exp(result_urban.conf_int()[0]),
    "97.5%": np.exp(result_urban.conf_int()[1])
})
print("\nOdds Ratios and 95% CI (Urban):")
print(odds_ratios_urban)
# Out:
# === Rural Area Logistic Regression ===
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       73
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Sun, 11 May 2025   Pseudo R-squ.:                 0.02546
# Time:                                                          14:09:25   Log-Likelihood:                -37.886
# converged:                                                        False   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                    0.1594
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                 16.0509   1528.898      0.010      0.992   -2980.534    3012.636
# Use of malaria preventive measures   -14.8162   1528.898     -0.010      0.992   -3011.401    2981.769
# ======================================================================================================
#
# Odds Ratios and 95% CI (Rural):
#                                               OR  2.5%  97.5%
# const                               9.350114e+06   0.0    inf
# Use of malaria preventive measures  3.676426e-07   0.0    inf
#
# === Urban Area Logistic Regression ===
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      205
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Sun, 11 May 2025   Pseudo R-squ.:                0.001791
# Time:                                                          14:09:25   Log-Likelihood:                -141.71
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                    0.4757
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                 -0.2231      0.671     -0.333      0.739      -1.538       1.092
# Use of malaria preventive measures     0.4873      0.686      0.710      0.477      -0.857       1.832
# ======================================================================================================
#
# Odds Ratios and 95% CI (Urban):
#                                           OR      2.5%     97.5%
# const                               0.800000  0.214826  2.979157
# Use of malaria preventive measures  1.627907  0.424356  6.244955
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# for individual preventive measures


import pandas as pd
import statsmodels.api as sm
import numpy as np

# Load dataset
#step 1 Load the data
file_path = r'/content/Data of Malaria (THESIS) 17 april.xlsx'
sheet_name = 'Form responses 1'

#step 2 read the data
data = pd.read_excel(file_path, sheet_name=sheet_name)

# Clean column names (if needed)
data.columns = data.columns.str.strip()

# Transform outcome variable
data['History of malaria in the past year in the household'] = data['History of malaria in the past year in the household'].map({'Yes': 1, 'No': 0})

# Define preventive measure columns
preventive_measures = [
    'LLITNs',
    'Insecticide sprays',
    'Mosquito coils',
    'House modification e.g putting up wire nets on windows'
]

# Transform activities into ordinal values: Never = 0, Rarely = 1, Monthly/Weekly/Daily = 2
def transform_activity(x):
    if x == 'Never':
        return 0
    elif x == 'Rarely':
        return 1
    elif x in ['Monthly', 'Weekly', 'Daily']:
        return 2
    else:
        return np.nan

for col in preventive_measures:
    data[col] = data[col].apply(transform_activity)

# Function to run logistic regression
def run_logistic(X, y):
    X = sm.add_constant(X)
    model = sm.Logit(y, X)
    result = model.fit(disp=0)
    return result

# Outcome variable
outcome = 'History of malaria in the past year in the household'

# Run separate logistic regression for each preventive measure
for measure in preventive_measures:
    print(f"\n=== Logistic Regression for {measure} ===")
    X = data[[measure]]
    y = data[outcome]

    # Drop rows with missing values
    df_temp = pd.concat([X, y], axis=1).dropna()
    X_clean = df_temp[[measure]]
    y_clean = df_temp[outcome]

    try:
        result = run_logistic(X_clean, y_clean)
        print(result.summary())

        odds_ratios = pd.DataFrame({
            "OR": np.exp(result.params),
            "2.5%": np.exp(result.conf_int()[0]),
            "97.5%": np.exp(result.conf_int()[1])
        })
        print("\nOdds Ratios and 95% CI:")
        print(odds_ratios)
    except Exception as e:
        print(f"⚠️ Regression failed for {measure}: {e}")
# Out:
# === Logistic Regression for LLITNs ===
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      280
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                 0.01276
# Time:                                                          10:39:14   Log-Likelihood:                -184.80
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                   0.02886
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0413      0.238      0.174      0.862      -0.425       0.508
# LLITNs         0.3253      0.149      2.186      0.029       0.034       0.617
# ==============================================================================
#
# Odds Ratios and 95% CI:
#               OR      2.5%     97.5%
# const   1.042193  0.653564  1.661914
# LLITNs  1.384457  1.034149  1.853427
#
# === Logistic Regression for Insecticide sprays ===
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      280
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                 0.01442
# Time:                                                          10:39:14   Log-Likelihood:                -184.49
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                   0.02014
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.7808      0.179      4.374      0.000       0.431       1.131
# Insecticide sprays    -0.3569      0.154     -2.314      0.021      -0.659      -0.055
# ======================================================================================
#
# Odds Ratios and 95% CI:
#                           OR      2.5%     97.5%
# const               2.183260  1.538741  3.097744
# Insecticide sprays  0.699808  0.517222  0.946850
#
# === Logistic Regression for Mosquito coils ===
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      280
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:               4.633e-05
# Time:                                                          10:39:14   Log-Likelihood:                -187.18
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                    0.8952
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.4741      0.183      2.592      0.010       0.116       0.833
# Mosquito coils     0.0202      0.154      0.132      0.895      -0.281       0.321
# ==================================================================================
#
# Odds Ratios and 95% CI:
#                       OR      2.5%     97.5%
# const           1.606516  1.122533  2.299168
# Mosquito coils  1.020421  0.755276  1.378647
#
# === Logistic Regression for House modification e.g putting up wire nets on windows ===
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  280
# Model:                                                            Logit   Df Residuals:                      278
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                0.001879
# Time:                                                          10:39:14   Log-Likelihood:                -185.88
# converged:                                                         True   LL-Null:                       -186.23
# Covariance Type:                                              nonrobust   LLR p-value:                    0.4029
# ==========================================================================================================================
#                                                              coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# const                                                      0.4449      0.130      3.426      0.001       0.190       0.699
# House modification e.g putting up wire nets on windows     0.2037      0.248      0.822      0.411      -0.282       0.690
# ==========================================================================================================================
#
# Odds Ratios and 95% CI:
#                                                           OR      2.5%  \
# const                                               1.560314  1.209720
# House modification e.g putting up wire nets on ...  1.225974  0.754063
#
#                                                        97.5%
# const                                               2.012517
# House modification e.g putting up wire nets on ...  1.993219

# %%
#after separating sample into rural and urban having malaria history as the outcome

import pandas as pd
import statsmodels.api as sm
import numpy as np

# Load dataset
#step 1 Load the data
file_path = r'/content/Data of Malaria (THESIS) 17 april.xlsx'
sheet_name = 'Form responses 1'

#step 2 read the data
data = pd.read_excel(file_path, sheet_name=sheet_name)

# Clean column names
data.columns = data.columns.str.strip()

# Map outcome variable
data['History of malaria in the past year in the household'] = data['History of malaria in the past year in the household'].map({'Yes': 1, 'No': 0})

# Define preventive measures
preventive_measures = [
    'LLITNs',
    'Insecticide sprays',
    'Mosquito coils',
    'House modification e.g putting up wire nets on windows'
]

# Transform activities into ordinal values: Never = 0, Rarely = 1, Monthly/Weekly/Daily = 2
def transform_activity(x):
    if x == 'Never':
        return 0
    elif x == 'Rarely':
        return 1
    elif x in ['Monthly', 'Weekly', 'Daily']:
        return 2
    else:
        return np.nan

for col in preventive_measures:
    data[col] = data[col].apply(transform_activity)

# Logistic regression function
def run_logistic(X, y):
    X = sm.add_constant(X)
    model = sm.Logit(y, X)
    result = model.fit(disp=0)
    return result

# Outcome variable
outcome = 'History of malaria in the past year in the household'

# Function to run models for a subset
def run_models_for_subset(subset_data, label="Full Sample"):
    print(f"\n====== Logistic Regressions for {label} ======")
    for measure in preventive_measures:
        print(f"\n--- Logistic Regression for {measure} ---")

        X = subset_data[[measure]]
        y = subset_data[outcome]

        df_temp = pd.concat([X, y], axis=1).dropna()
        X_clean = df_temp[[measure]]
        y_clean = df_temp[outcome]

        if X_clean.shape[0] > 0:  # Make sure there are observations left
            try:
                result = run_logistic(X_clean, y_clean)
                print(result.summary())

                odds_ratios = pd.DataFrame({
                    "OR": np.exp(result.params),
                    "2.5%": np.exp(result.conf_int()[0]),
                    "97.5%": np.exp(result.conf_int()[1])
                })
                print("\nOdds Ratios and 95% CI:")
                print(odds_ratios)
            except Exception as e:
                print(f"⚠️ Regression failed for {measure}: {e}")
        else:
            print(f"⚠️ No data available for {measure} in {label}")

# 1. Run models for the full dataset
run_models_for_subset(data, label="Full Sample")

# 2. Split the dataset
rural_data = data[data['Area of residence'] == 'Rural area']
urban_data = data[data['Area of residence'] == 'Urban area']

# 3. Run models for Rural households
run_models_for_subset(rural_data, label="Rural Area")

# 4. Run models for Urban households
run_models_for_subset(urban_data, label="Urban Area")
# Out:
# ====== Logistic Regressions for Full Sample ======
#
# --- Logistic Regression for LLITNs ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      280
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                 0.01276
# Time:                                                          10:40:00   Log-Likelihood:                -184.80
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                   0.02886
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0413      0.238      0.174      0.862      -0.425       0.508
# LLITNs         0.3253      0.149      2.186      0.029       0.034       0.617
# ==============================================================================
#
# Odds Ratios and 95% CI:
#               OR      2.5%     97.5%
# const   1.042193  0.653564  1.661914
# LLITNs  1.384457  1.034149  1.853427
#
# --- Logistic Regression for Insecticide sprays ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      280
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                 0.01442
# Time:                                                          10:40:00   Log-Likelihood:                -184.49
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                   0.02014
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.7808      0.179      4.374      0.000       0.431       1.131
# Insecticide sprays    -0.3569      0.154     -2.314      0.021      -0.659      -0.055
# ======================================================================================
#
# Odds Ratios and 95% CI:
#                           OR      2.5%     97.5%
# const               2.183260  1.538741  3.097744
# Insecticide sprays  0.699808  0.517222  0.946850
#
# --- Logistic Regression for Mosquito coils ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      280
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:               4.633e-05
# Time:                                                          10:40:00   Log-Likelihood:                -187.18
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                    0.8952
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.4741      0.183      2.592      0.010       0.116       0.833
# Mosquito coils     0.0202      0.154      0.132      0.895      -0.281       0.321
# ==================================================================================
#
# Odds Ratios and 95% CI:
#                       OR      2.5%     97.5%
# const           1.606516  1.122533  2.299168
# Mosquito coils  1.020421  0.755276  1.378647
#
# --- Logistic Regression for House modification e.g putting up wire nets on windows ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  280
# Model:                                                            Logit   Df Residuals:                      278
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                0.001879
# Time:                                                          10:40:00   Log-Likelihood:                -185.88
# converged:                                                         True   LL-Null:                       -186.23
# Covariance Type:                                              nonrobust   LLR p-value:                    0.4029
# ==========================================================================================================================
#                                                              coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# const                                                      0.4449      0.130      3.426      0.001       0.190       0.699
# House modification e.g putting up wire nets on windows     0.2037      0.248      0.822      0.411      -0.282       0.690
# ==========================================================================================================================
#
# Odds Ratios and 95% CI:
#                                                           OR      2.5%  \
# const                                               1.560314  1.209720
# House modification e.g putting up wire nets on ...  1.225974  0.754063
#
#                                                        97.5%
# const                                               2.012517
# House modification e.g putting up wire nets on ...  1.993219
#
# ====== Logistic Regressions for Rural Area ======
#
# --- Logistic Regression for LLITNs ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       73
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                 0.01397
# Time:                                                          10:40:00   Log-Likelihood:                -38.333
# converged:                                                         True   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                    0.2974
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.9812      0.769      2.576      0.010       0.474       3.489
# LLITNs        -0.4257      0.432     -0.986      0.324      -1.272       0.421
# ==============================================================================
#
# Odds Ratios and 95% CI:
#               OR      2.5%      97.5%
# const   7.251687  1.606303  32.737889
# LLITNs  0.653296  0.280226   1.523041
#
# --- Logistic Regression for Insecticide sprays ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       73
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                 0.03670
# Time:                                                          10:40:00   Log-Likelihood:                -37.449
# converged:                                                         True   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                   0.09120
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  1.7211      0.400      4.297      0.000       0.936       2.506
# Insecticide sprays    -0.6095      0.359     -1.696      0.090      -1.314       0.095
# ======================================================================================
#
# Odds Ratios and 95% CI:
#                           OR      2.5%      97.5%
# const               5.590696  2.550125  12.256611
# Insecticide sprays  0.543643  0.268782   1.099579
#
# --- Logistic Regression for Mosquito coils ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       73
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                0.001120
# Time:                                                          10:40:00   Log-Likelihood:                -38.832
# converged:                                                         True   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                    0.7679
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              1.4035      0.442      3.173      0.002       0.537       2.270
# Mosquito coils    -0.1020      0.346     -0.295      0.768      -0.780       0.576
# ==================================================================================
#
# Odds Ratios and 95% CI:
#                       OR      2.5%     97.5%
# const           4.069408  1.710186  9.683204
# Mosquito coils  0.903021  0.458564  1.778260
#
# --- Logistic Regression for House modification e.g putting up wire nets on windows ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   74
# Model:                                                            Logit   Df Residuals:                       72
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:               0.0002910
# Time:                                                          10:40:00   Log-Likelihood:                -38.622
# converged:                                                         True   LL-Null:                       -38.634
# Covariance Type:                                              nonrobust   LLR p-value:                    0.8808
# ==========================================================================================================================
#                                                              coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# const                                                      1.3041      0.303      4.299      0.000       0.709       1.899
# House modification e.g putting up wire nets on windows    -0.0687      0.454     -0.151      0.880      -0.959       0.822
# ==========================================================================================================================
#
# Odds Ratios and 95% CI:
#                                                           OR      2.5%  \
# const                                               3.684475  2.032970
# House modification e.g putting up wire nets on ...  0.933599  0.383301
#
#                                                        97.5%
# const                                               6.677600
# House modification e.g putting up wire nets on ...  2.273948
#
# ====== Logistic Regressions for Urban Area ======
#
# --- Logistic Regression for LLITNs ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      205
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                 0.02354
# Time:                                                          10:40:00   Log-Likelihood:                -138.63
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                  0.009732
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.3479      0.270     -1.287      0.198      -0.878       0.182
# LLITNs         0.4357      0.170      2.560      0.010       0.102       0.769
# ==============================================================================
#
# Odds Ratios and 95% CI:
#               OR      2.5%     97.5%
# const   0.706140  0.415628  1.199713
# LLITNs  1.546039  1.107558  2.158112
#
# --- Logistic Regression for Insecticide sprays ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      205
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                0.005528
# Time:                                                          10:40:00   Log-Likelihood:                -141.18
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                    0.2103
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.4314      0.207      2.082      0.037       0.025       0.838
# Insecticide sprays    -0.2186      0.175     -1.250      0.211      -0.561       0.124
# ======================================================================================
#
# Odds Ratios and 95% CI:
#                           OR      2.5%     97.5%
# const               1.539416  1.025624  2.310597
# Insecticide sprays  0.803637  0.570447  1.132150
#
# --- Logistic Regression for Mosquito coils ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      205
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:               5.241e-05
# Time:                                                          10:40:00   Log-Likelihood:                -141.96
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                    0.9029
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.2241      0.207      1.083      0.279      -0.182       0.630
# Mosquito coils     0.0215      0.177      0.122      0.903      -0.325       0.368
# ==================================================================================
#
# Odds Ratios and 95% CI:
#                       OR      2.5%     97.5%
# const           1.251222  0.833948  1.877283
# Mosquito coils  1.021775  0.722802  1.444413
#
# --- Logistic Regression for House modification e.g putting up wire nets on windows ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  206
# Model:                                                            Logit   Df Residuals:                      204
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                0.002760
# Time:                                                          10:40:00   Log-Likelihood:                -141.00
# converged:                                                         True   LL-Null:                       -141.39
# Covariance Type:                                              nonrobust   LLR p-value:                    0.3770
# ==========================================================================================================================
#                                                              coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# const                                                      0.1922      0.148      1.299      0.194      -0.098       0.482
# House modification e.g putting up wire nets on windows     0.2621      0.302      0.868      0.385      -0.330       0.854
# ==========================================================================================================================
#
# Odds Ratios and 95% CI:
#                                                           OR      2.5%  \
# const                                               1.211914  0.906856
# House modification e.g putting up wire nets on ...  1.299706  0.719047
#
#                                                        97.5%
# const                                               1.619589
# House modification e.g putting up wire nets on ...  2.349271

# %%
#for specific preventive measures and cases of malaria as the outcome

import pandas as pd
import statsmodels.api as sm
import numpy as np

# Load dataset
#step 1 Load the data
file_path = r'/content/Data of Malaria (THESIS) 17 april.xlsx'
sheet_name = 'Form responses 1'

#step 2 read the data
data = pd.read_excel(file_path, sheet_name=sheet_name)

# Clean column names
data.columns = data.columns.str.strip()

# Define preventive measures
preventive_measures = [
    'LLITNs',
    'Insecticide sprays',
    'Mosquito coils',
    'House modification e.g putting up wire nets on windows'
]

# Transform activities into ordinal values: Never = 0, Rarely = 1, Monthly/Weekly/Daily = 2
def transform_activity(x):
    if x == 'Never':
        return 0
    elif x == 'Rarely':
        return 1
    elif x in ['Monthly', 'Weekly', 'Daily']:
        return 2
    else:
        return np.nan

for col in preventive_measures:
    data[col] = data[col].apply(transform_activity)

# Transform "Cases of malaria in the past year"
# Replace cases > 10 with the household size
data['Cases of malaria in the past year'] = np.where(
    data['Cases of malaria in the past year'] > 10,
    data['Household size'],
    data['Cases of malaria in the past year']
)

# Function to run Poisson regression
def run_poisson(X, y):
    X = sm.add_constant(X)
    model = sm.Poisson(y, X)
    result = model.fit(disp=0)
    return result

# Outcome variable
outcome = 'Cases of malaria in the past year'

# Function to run models for a subset
def run_poisson_models_for_subset(subset_data, label="Full Sample"):
    print(f"\n====== Poisson Regressions for {label} ======")
    for measure in preventive_measures:
        print(f"\n--- Poisson Regression for {measure} ---")

        X = subset_data[[measure]]
        y = subset_data[outcome]

        df_temp = pd.concat([X, y], axis=1).dropna()
        X_clean = df_temp[[measure]]
        y_clean = df_temp[outcome]

        if X_clean.shape[0] > 0:  # Make sure there are observations left
            try:
                result = run_poisson(X_clean, y_clean)
                print(result.summary())

                incidence_rate_ratios = pd.DataFrame({
                    "IRR": np.exp(result.params),
                    "2.5%": np.exp(result.conf_int()[0]),
                    "97.5%": np.exp(result.conf_int()[1])
                })
                print("\nIncidence Rate Ratios (IRR) and 95% CI:")
                print(incidence_rate_ratios)
            except Exception as e:
                print(f"⚠️ Regression failed for {measure}: {e}")
        else:
            print(f"⚠️ No data available for {measure} in {label}")

# 1. Run models for the full dataset
run_poisson_models_for_subset(data, label="Full Sample")

# 2. Split the dataset
rural_data = data[data['Area of residence'] == 'Rural area']
urban_data = data[data['Area of residence'] == 'Urban area']

# 3. Run models for Rural households
run_poisson_models_for_subset(rural_data, label="Rural Area")

# 4. Run models for Urban households
run_poisson_models_for_subset(urban_data, label="Urban Area")
# Out:
# ====== Poisson Regressions for Full Sample ======
#
# --- Poisson Regression for LLITNs ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  282
# Model:                                       Poisson   Df Residuals:                      280
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:                0.001266
# Time:                                       10:42:42   Log-Likelihood:                -566.35
# converged:                                      True   LL-Null:                       -567.06
# Covariance Type:                           nonrobust   LLR p-value:                    0.2308
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4190      0.096      4.380      0.000       0.232       0.607
# LLITNs         0.0686      0.058      1.188      0.235      -0.045       0.182
# ==============================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#              IRR      2.5%     97.5%
# const   1.520503  1.260507  1.834127
# LLITNs  1.071029  0.956373  1.199429
#
# --- Poisson Regression for Insecticide sprays ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  282
# Model:                                       Poisson   Df Residuals:                      280
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:                0.006779
# Time:                                       10:42:42   Log-Likelihood:                -563.22
# converged:                                      True   LL-Null:                       -567.06
# Covariance Type:                           nonrobust   LLR p-value:                  0.005559
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.6366      0.061     10.376      0.000       0.516       0.757
# Insecticide sprays    -0.1630      0.059     -2.740      0.006      -0.280      -0.046
# ======================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                          IRR      2.5%     97.5%
# const               1.890093  1.675929  2.131626
# Insecticide sprays  0.849588  0.756078  0.954664
#
# --- Poisson Regression for Mosquito coils ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  282
# Model:                                       Poisson   Df Residuals:                      280
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:                0.001767
# Time:                                       10:42:42   Log-Likelihood:                -566.06
# converged:                                      True   LL-Null:                       -567.06
# Covariance Type:                           nonrobust   LLR p-value:                    0.1568
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.4432      0.071      6.270      0.000       0.305       0.582
# Mosquito coils     0.0811      0.057      1.418      0.156      -0.031       0.193
# ==================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                      IRR      2.5%     97.5%
# const           1.557659  1.356135  1.789130
# Mosquito coils  1.084474  0.969468  1.213123
#
# --- Poisson Regression for House modification e.g putting up wire nets on windows ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  280
# Model:                                       Poisson   Df Residuals:                      278
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:                0.001191
# Time:                                       10:42:42   Log-Likelihood:                -563.90
# converged:                                      True   LL-Null:                       -564.57
# Covariance Type:                           nonrobust   LLR p-value:                    0.2462
# ==========================================================================================================================
#                                                              coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# const                                                      0.4987      0.049     10.115      0.000       0.402       0.595
# House modification e.g putting up wire nets on windows     0.0981      0.083      1.187      0.235      -0.064       0.260
# ==========================================================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                                                          IRR      2.5%  \
# const                                               1.646590  1.494916
# House modification e.g putting up wire nets on ...  1.103093  0.938061
#
#                                                        97.5%
# const                                               1.813652
# House modification e.g putting up wire nets on ...  1.297159
#
# ====== Poisson Regressions for Rural Area ======
#
# --- Poisson Regression for LLITNs ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                   75
# Model:                                       Poisson   Df Residuals:                       73
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:                 0.02957
# Time:                                       10:42:42   Log-Likelihood:                -172.05
# converged:                                      True   LL-Null:                       -177.30
# Covariance Type:                           nonrobust   LLR p-value:                  0.001203
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.3552      0.135     10.016      0.000       1.090       1.620
# LLITNs        -0.2864      0.086     -3.341      0.001      -0.454      -0.118
# ==============================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#              IRR      2.5%     97.5%
# const   3.877381  2.974227  5.054786
# LLITNs  0.750998  0.634882  0.888350
#
# --- Poisson Regression for Insecticide sprays ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                   75
# Model:                                       Poisson   Df Residuals:                       73
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:               0.0002722
# Time:                                       10:42:42   Log-Likelihood:                -177.25
# converged:                                      True   LL-Null:                       -177.30
# Covariance Type:                           nonrobust   LLR p-value:                    0.7561
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.9626      0.091     10.609      0.000       0.785       1.140
# Insecticide sprays    -0.0300      0.097     -0.310      0.757      -0.220       0.160
# ======================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                          IRR      2.5%     97.5%
# const               2.618378  2.191811  3.127964
# Insecticide sprays  0.970438  0.802566  1.173423
#
# --- Poisson Regression for Mosquito coils ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                   75
# Model:                                       Poisson   Df Residuals:                       73
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:                0.005138
# Time:                                       10:42:42   Log-Likelihood:                -176.39
# converged:                                      True   LL-Null:                       -177.30
# Covariance Type:                           nonrobust   LLR p-value:                    0.1771
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.8278      0.116      7.157      0.000       0.601       1.054
# Mosquito coils     0.1191      0.088      1.350      0.177      -0.054       0.292
# ==================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                      IRR      2.5%     97.5%
# const           2.288174  1.824075  2.870353
# Mosquito coils  1.126463  0.947561  1.339142
#
# --- Poisson Regression for House modification e.g putting up wire nets on windows ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                   74
# Model:                                       Poisson   Df Residuals:                       72
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:               0.0006286
# Time:                                       10:42:42   Log-Likelihood:                -175.81
# converged:                                      True   LL-Null:                       -175.92
# Covariance Type:                           nonrobust   LLR p-value:                    0.6382
# ==========================================================================================================================
#                                                              coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# const                                                      0.9609      0.077     12.490      0.000       0.810       1.112
# House modification e.g putting up wire nets on windows    -0.0578      0.125     -0.464      0.643      -0.302       0.187
# ==========================================================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                                                          IRR      2.5%  \
# const                                               2.614052  2.248172
# House modification e.g putting up wire nets on ...  0.943797  0.739030
#
#                                                        97.5%
# const                                               3.039476
# House modification e.g putting up wire nets on ...  1.205299
#
# ====== Poisson Regressions for Urban Area ======
#
# --- Poisson Regression for LLITNs ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  207
# Model:                                       Poisson   Df Residuals:                      205
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:                 0.01583
# Time:                                       10:42:42   Log-Likelihood:                -361.58
# converged:                                      True   LL-Null:                       -367.39
# Covariance Type:                           nonrobust   LLR p-value:                 0.0006489
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0766      0.136     -0.565      0.572      -0.342       0.189
# LLITNs         0.2607      0.079      3.283      0.001       0.105       0.416
# ==============================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#              IRR      2.5%     97.5%
# const   0.926296  0.710205  1.208136
# LLITNs  1.297814  1.110785  1.516333
#
# --- Poisson Regression for Insecticide sprays ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  207
# Model:                                       Poisson   Df Residuals:                      205
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:                0.005320
# Time:                                       10:42:42   Log-Likelihood:                -365.44
# converged:                                      True   LL-Null:                       -367.39
# Covariance Type:                           nonrobust   LLR p-value:                   0.04803
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.4224      0.083      5.081      0.000       0.259       0.585
# Insecticide sprays    -0.1490      0.076     -1.961      0.050      -0.298      -0.000
# ======================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                          IRR      2.5%     97.5%
# const               1.525625  1.296237  1.795606
# Insecticide sprays  0.861562  0.742372  0.999887
#
# --- Poisson Regression for Mosquito coils ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  207
# Model:                                       Poisson   Df Residuals:                      205
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:               0.0001158
# Time:                                       10:42:42   Log-Likelihood:                -367.35
# converged:                                      True   LL-Null:                       -367.39
# Covariance Type:                           nonrobust   LLR p-value:                    0.7705
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.2829      0.089      3.176      0.001       0.108       0.458
# Mosquito coils     0.0220      0.075      0.292      0.770      -0.125       0.169
# ==================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                      IRR      2.5%     97.5%
# const           1.327021  1.114420  1.580182
# Mosquito coils  1.022194  0.882116  1.184516
#
# --- Poisson Regression for House modification e.g putting up wire nets on windows ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  206
# Model:                                       Poisson   Df Residuals:                      204
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:                0.003207
# Time:                                       10:42:42   Log-Likelihood:                -365.17
# converged:                                      True   LL-Null:                       -366.34
# Covariance Type:                           nonrobust   LLR p-value:                    0.1253
# ==========================================================================================================================
#                                                              coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# const                                                      0.2707      0.064      4.218      0.000       0.145       0.396
# House modification e.g putting up wire nets on windows     0.1743      0.109      1.595      0.111      -0.040       0.389
# ==========================================================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                                                          IRR      2.5%  \
# const                                               1.310860  1.155923
# House modification e.g putting up wire nets on ...  1.190432  0.960841
#
#                                                        97.5%
# const                                               1.486565
# House modification e.g putting up wire nets on ...  1.474883

# %%
#for household measures (first binary, then specific ones) as predictors and history of malaria and cases of malaria as the outcome

import pandas as pd
import statsmodels.api as sm
import numpy as np

# Load dataset
#step 1 Load the data
file_path = r'/content/Data of Malaria (THESIS) 17 april.xlsx'
sheet_name = 'Form responses 1'

#step 2 read the data
data = pd.read_excel(file_path, sheet_name=sheet_name)

# Clean column names: remove extra spaces but KEEP normal spaces
data.columns = data.columns.str.strip()

# Recode outcome: History of malaria
data['History of malaria in the past year in the household'] = data['History of malaria in the past year in the household'].map({'Yes': 1, 'No': 0})

# Transform 'Cases of malaria' > 10 to Household size
data['Cases of malaria in the past year'] = np.where(
    data['Cases of malaria in the past year'] > 10,
    data['Household size'],
    data['Cases of malaria in the past year']
)

# Recode main environmental engagement variable
data['Engaged in household environmental measures'] = data['Engaged in household environmental measures'].map({'Yes': 1, 'No': 0})

# Define individual environmental practices (your exact names)
environmental_practices = [
    'Eliminating standing water',
    'Managing trash cans',
    'Mowing grass around the house',
    'Maintaining drainage systems used to direct water away from homes',
    'Covering water storage containers',
    'Sweeping the yard'
]

# Transform activities into ordinal values: Never = 0, Rarely = 1, Monthly/Weekly/Daily = 2
def transform_activity(x):
    if x == 'Never':
        return 0
    elif x == 'Rarely':
        return 1
    elif x in ['Monthly', 'Weekly', 'Daily']:
        return 2
    else:
        return np.nan

for col in environmental_practices:
    data[col] = data[col].apply(transform_activity)

# Logistic regression function
def run_logistic(X, y):
    X = sm.add_constant(X)
    model = sm.Logit(y, X)
    result = model.fit(disp=0)
    return result

# Poisson regression function
def run_poisson(X, y):
    X = sm.add_constant(X)
    model = sm.Poisson(y, X)
    result = model.fit(disp=0)
    return result

# Function to run models for a subset
def run_models(subset_data, predictor_list, outcome, model_type="logistic", label="Full Sample"):
    print(f"\n====== {model_type.capitalize()} Regressions for {label} (Outcome: {outcome}) ======")
    for predictor in predictor_list:
        print(f"\n--- Regression for Predictor: {predictor} ---")

        X = subset_data[[predictor]]
        y = subset_data[outcome]

        df_temp = pd.concat([X, y], axis=1).dropna()
        X_clean = df_temp[[predictor]]
        y_clean = df_temp[outcome]

        if X_clean.shape[0] > 0:
            try:
                if model_type == "logistic":
                    result = run_logistic(X_clean, y_clean)
                else:
                    result = run_poisson(X_clean, y_clean)

                print(result.summary())

                if model_type == "logistic":
                    or_table = pd.DataFrame({
                        "OR": np.exp(result.params),
                        "2.5%": np.exp(result.conf_int()[0]),
                        "97.5%": np.exp(result.conf_int()[1])
                    })
                    print("\nOdds Ratios (OR) and 95% CI:")
                    print(or_table)
                else:
                    irr_table = pd.DataFrame({
                        "IRR": np.exp(result.params),
                        "2.5%": np.exp(result.conf_int()[0]),
                        "97.5%": np.exp(result.conf_int()[1])
                    })
                    print("\nIncidence Rate Ratios (IRR) and 95% CI:")
                    print(irr_table)

            except Exception as e:
                print(f"⚠️ Regression failed for {predictor}: {e}")
        else:
            print(f"⚠️ No data for {predictor} in {label}")

# Main predictor
main_predictor = ['Engaged in household environmental measures']

# Correct outcome names
outcome_logistic = 'History of malaria in the past year in the household'
outcome_poisson = 'Cases of malaria in the past year'

# Split data into Rural and Urban
rural_data = data[data['Area of residence'] == 'Rural area']
urban_data = data[data['Area of residence'] == 'Urban area']

# ===== RUN ALL MODELS =====

# Full sample
run_models(data, main_predictor, outcome=outcome_logistic, model_type="logistic", label="Full Sample")
run_models(data, environmental_practices, outcome=outcome_logistic, model_type="logistic", label="Full Sample")
run_models(data, main_predictor, outcome=outcome_poisson, model_type="poisson", label="Full Sample")
run_models(data, environmental_practices, outcome=outcome_poisson, model_type="poisson", label="Full Sample")

# Rural sample
run_models(rural_data, main_predictor, outcome=outcome_logistic, model_type="logistic", label="Rural Area")
run_models(rural_data, environmental_practices, outcome=outcome_logistic, model_type="logistic", label="Rural Area")
run_models(rural_data, main_predictor, outcome=outcome_poisson, model_type="poisson", label="Rural Area")
run_models(rural_data, environmental_practices, outcome=outcome_poisson, model_type="poisson", label="Rural Area")

# Urban sample
run_models(urban_data, main_predictor, outcome=outcome_logistic, model_type="logistic", label="Urban Area")
run_models(urban_data, environmental_practices, outcome=outcome_logistic, model_type="logistic", label="Urban Area")
run_models(urban_data, main_predictor, outcome=outcome_poisson, model_type="poisson", label="Urban Area")
run_models(urban_data, environmental_practices, outcome=outcome_poisson, model_type="poisson", label="Urban Area")
# Out:
# ====== Logistic Regressions for Full Sample (Outcome: History of malaria in the past year in the household) ======
#
# --- Regression for Predictor: Engaged in household environmental measures ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      280
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:               0.0006384
# Time:                                                          10:44:43   Log-Likelihood:                -187.07
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                    0.6249
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                           0.2513      0.504      0.499      0.618      -0.736       1.239
# Engaged in household environmental measures     0.2555      0.520      0.492      0.623      -0.763       1.274
# ===============================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                                    OR      2.5%     97.5%
# const                                        1.285714  0.478828  3.452310
# Engaged in household environmental measures  1.291111  0.466308  3.574824
#
# ====== Logistic Regressions for Full Sample (Outcome: History of malaria in the past year in the household) ======
#
# --- Regression for Predictor: Eliminating standing water ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      280
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                0.007689
# Time:                                                          10:44:43   Log-Likelihood:                -185.75
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                   0.08976
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          0.2270      0.197      1.153      0.249      -0.159       0.613
# Eliminating standing water     0.2365      0.140      1.694      0.090      -0.037       0.510
# ==============================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                   OR      2.5%     97.5%
# const                       1.254833  0.852997  1.845968
# Eliminating standing water  1.266762  0.963547  1.665394
#
# --- Regression for Predictor: Managing trash cans ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      280
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                0.002570
# Time:                                                          10:44:43   Log-Likelihood:                -186.71
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                    0.3266
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.6326      0.190      3.322      0.001       0.259       1.006
# Managing trash cans    -0.1318      0.135     -0.979      0.327      -0.396       0.132
# =======================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                            OR      2.5%     97.5%
# const                1.882426  1.296104  2.733983
# Managing trash cans  0.876496  0.673221  1.141149
#
# --- Regression for Predictor: Mowing grass around the house ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      280
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:               0.0008090
# Time:                                                          10:44:43   Log-Likelihood:                -187.04
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                    0.5821
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                             0.3801      0.236      1.607      0.108      -0.083       0.843
# Mowing grass around the house     0.0809      0.147      0.551      0.581      -0.207       0.368
# =================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                      OR      2.5%     97.5%
# const                          1.462372  0.920012  2.324460
# Mowing grass around the house  1.084238  0.813274  1.445481
#
# --- Regression for Predictor: Maintaining drainage systems used to direct water away from homes ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      280
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:               1.200e-05
# Time:                                                          10:44:43   Log-Likelihood:                -187.19
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                    0.9466
# =====================================================================================================================================
#                                                                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------
# const                                                                 0.5014      0.187      2.680      0.007       0.135       0.868
# Maintaining drainage systems used to direct water away from homes    -0.0093      0.139     -0.067      0.947      -0.282       0.263
# =====================================================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                                           OR      2.5%  \
# const                                               1.651048  1.144284
# Maintaining drainage systems used to direct wat...  0.990731  0.754518
#
#                                                        97.5%
# const                                               2.382240
# Maintaining drainage systems used to direct wat...  1.300892
#
# --- Regression for Predictor: Covering water storage containers ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      280
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:               0.0006447
# Time:                                                          10:44:43   Log-Likelihood:                -187.07
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                    0.6232
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                 0.4180      0.193      2.161      0.031       0.039       0.797
# Covering water storage containers     0.0659      0.134      0.491      0.623      -0.197       0.329
# =====================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                          OR      2.5%     97.5%
# const                              1.518991  1.039622  2.219397
# Covering water storage containers  1.068150  0.821185  1.389388
#
# --- Regression for Predictor: Sweeping the yard ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      280
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                0.004011
# Time:                                                          10:44:43   Log-Likelihood:                -186.44
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                    0.2204
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 0.7826      0.272      2.875      0.004       0.249       1.316
# Sweeping the yard    -0.1877      0.155     -1.211      0.226      -0.491       0.116
# =====================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                          OR      2.5%     97.5%
# const              2.187214  1.282806  3.729249
# Sweeping the yard  0.828864  0.611717  1.123094
#
# ====== Poisson Regressions for Full Sample (Outcome: Cases of malaria in the past year) ======
#
# --- Regression for Predictor: Engaged in household environmental measures ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  282
# Model:                                       Poisson   Df Residuals:                      280
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:               0.0001590
# Time:                                       10:44:43   Log-Likelihood:                -566.97
# converged:                                      True   LL-Null:                       -567.06
# Covariance Type:                           nonrobust   LLR p-value:                    0.6711
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                           0.5947      0.186      3.203      0.001       0.231       0.959
# Engaged in household environmental measures    -0.0824      0.192     -0.430      0.667      -0.458       0.293
# ===============================================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                                                   IRR      2.5%     97.5%
# const                                        1.812500  1.259545  2.608208
# Engaged in household environmental measures  0.920923  0.632527  1.340812
#
# ====== Poisson Regressions for Full Sample (Outcome: Cases of malaria in the past year) ======
#
# --- Regression for Predictor: Eliminating standing water ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  282
# Model:                                       Poisson   Df Residuals:                      280
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:               5.806e-05
# Time:                                       10:44:43   Log-Likelihood:                -567.03
# converged:                                      True   LL-Null:                       -567.06
# Covariance Type:                           nonrobust   LLR p-value:                    0.7975
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          0.5018      0.076      6.616      0.000       0.353       0.650
# Eliminating standing water     0.0134      0.052      0.256      0.798      -0.089       0.116
# ==============================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                                  IRR      2.5%     97.5%
# const                       1.651675  1.423534  1.916378
# Eliminating standing water  1.013515  0.914688  1.123020
#
# --- Regression for Predictor: Managing trash cans ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  282
# Model:                                       Poisson   Df Residuals:                      280
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:                0.007005
# Time:                                       10:44:43   Log-Likelihood:                -563.09
# converged:                                      True   LL-Null:                       -567.06
# Covariance Type:                           nonrobust   LLR p-value:                  0.004823
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.6578      0.066     10.006      0.000       0.529       0.787
# Managing trash cans    -0.1415      0.050     -2.814      0.005      -0.240      -0.043
# =======================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                           IRR      2.5%     97.5%
# const                1.930574  1.697182  2.196060
# Managing trash cans  0.868051  0.786587  0.957952
#
# --- Regression for Predictor: Mowing grass around the house ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  282
# Model:                                       Poisson   Df Residuals:                      280
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:               0.0005722
# Time:                                       10:44:43   Log-Likelihood:                -566.74
# converged:                                      True   LL-Null:                       -567.06
# Covariance Type:                           nonrobust   LLR p-value:                    0.4205
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                             0.4539      0.092      4.928      0.000       0.273       0.634
# Mowing grass around the house     0.0450      0.056      0.801      0.423      -0.065       0.155
# =================================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                                     IRR      2.5%     97.5%
# const                          1.574479  1.314401  1.886019
# Mowing grass around the house  1.046041  0.936971  1.167807
#
# --- Regression for Predictor: Maintaining drainage systems used to direct water away from homes ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  282
# Model:                                       Poisson   Df Residuals:                      280
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:               0.0006672
# Time:                                       10:44:43   Log-Likelihood:                -566.69
# converged:                                      True   LL-Null:                       -567.06
# Covariance Type:                           nonrobust   LLR p-value:                    0.3844
# =====================================================================================================================================
#                                                                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------
# const                                                                 0.5623      0.069      8.192      0.000       0.428       0.697
# Maintaining drainage systems used to direct water away from homes    -0.0453      0.052     -0.870      0.384      -0.147       0.057
# =====================================================================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                                                          IRR      2.5%  \
# const                                               1.754738  1.533846
# Maintaining drainage systems used to direct wat...  0.955721  0.862995
#
#                                                        97.5%
# const                                               2.007442
# Maintaining drainage systems used to direct wat...  1.058411
#
# --- Regression for Predictor: Covering water storage containers ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  282
# Model:                                       Poisson   Df Residuals:                      280
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:               7.054e-05
# Time:                                       10:44:43   Log-Likelihood:                -567.02
# converged:                                      True   LL-Null:                       -567.06
# Covariance Type:                           nonrobust   LLR p-value:                    0.7773
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                 0.5010      0.074      6.809      0.000       0.357       0.645
# Covering water storage containers     0.0143      0.050      0.283      0.777      -0.085       0.113
# =====================================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                                         IRR      2.5%     97.5%
# const                              1.650427  1.428773  1.906468
# Covering water storage containers  1.014352  0.918919  1.119696
#
# --- Regression for Predictor: Sweeping the yard ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  282
# Model:                                       Poisson   Df Residuals:                      280
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:                0.004857
# Time:                                       10:44:43   Log-Likelihood:                -564.31
# converged:                                      True   LL-Null:                       -567.06
# Covariance Type:                           nonrobust   LLR p-value:                   0.01892
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 0.7059      0.089      7.912      0.000       0.531       0.881
# Sweeping the yard    -0.1268      0.053     -2.392      0.017      -0.231      -0.023
# =====================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                         IRR      2.5%     97.5%
# const              2.025587  1.700634  2.412632
# Sweeping the yard  0.880898  0.793946  0.977372
#
# ====== Logistic Regressions for Rural Area (Outcome: History of malaria in the past year in the household) ======
#
# --- Regression for Predictor: Engaged in household environmental measures ---
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       73
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                 0.03209
# Time:                                                          10:44:43   Log-Likelihood:                -37.628
# converged:                                                        False   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                    0.1142
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                          23.1708   4.81e+04      0.000      1.000   -9.42e+04    9.43e+04
# Engaged in household environmental measures   -21.9544   4.81e+04     -0.000      1.000   -9.43e+04    9.42e+04
# ===============================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                                        OR  2.5%  97.5%
# const                                        1.155943e+10   0.0    inf
# Engaged in household environmental measures  2.919694e-10   0.0    inf
#
# ====== Logistic Regressions for Rural Area (Outcome: History of malaria in the past year in the household) ======
#
# --- Regression for Predictor: Eliminating standing water ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       73
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                0.002670
# Time:                                                          10:44:43   Log-Likelihood:                -38.772
# converged:                                                         True   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                    0.6487
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          1.4779      0.484      3.057      0.002       0.530       2.426
# Eliminating standing water    -0.1449      0.320     -0.453      0.651      -0.772       0.482
# ==============================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                   OR      2.5%      97.5%
# const                       4.383703  1.699337  11.308439
# Eliminating standing water  0.865080  0.461970   1.619941
#
# --- Regression for Predictor: Managing trash cans ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       73
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:               0.0003942
# Time:                                                          10:44:43   Log-Likelihood:                -38.860
# converged:                                                         True   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                    0.8610
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   1.2536      0.404      3.102      0.002       0.462       2.046
# Managing trash cans     0.0535      0.306      0.175      0.861      -0.546       0.653
# =======================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                            OR      2.5%     97.5%
# const                3.502890  1.586514  7.734087
# Managing trash cans  1.054942  0.579483  1.920510
#
# --- Regression for Predictor: Mowing grass around the house ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       73
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:               0.0001610
# Time:                                                          10:44:43   Log-Likelihood:                -38.869
# converged:                                                         True   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                    0.9109
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                             1.2552      0.523      2.399      0.016       0.230       2.281
# Mowing grass around the house     0.0375      0.334      0.112      0.911      -0.618       0.693
# =================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                      OR      2.5%     97.5%
# const                          3.508714  1.258302  9.783880
# Mowing grass around the house  1.038198  0.539088  1.999403
#
# --- Regression for Predictor: Maintaining drainage systems used to direct water away from homes ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       73
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:               0.0008740
# Time:                                                          10:44:43   Log-Likelihood:                -38.842
# converged:                                                         True   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                    0.7943
# =====================================================================================================================================
#                                                                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------
# const                                                                 1.3819      0.412      3.351      0.001       0.574       2.190
# Maintaining drainage systems used to direct water away from homes    -0.0796      0.305     -0.261      0.794      -0.678       0.519
# =====================================================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                                           OR      2.5%  \
# const                                               3.982290  1.774544
# Maintaining drainage systems used to direct wat...  0.923477  0.507568
#
#                                                        97.5%
# const                                               8.936734
# Maintaining drainage systems used to direct wat...  1.680190
#
# --- Regression for Predictor: Covering water storage containers ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       73
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:               0.0008740
# Time:                                                          10:44:43   Log-Likelihood:                -38.842
# converged:                                                         True   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                    0.7943
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                 1.2226      0.419      2.918      0.004       0.402       2.044
# Covering water storage containers     0.0796      0.305      0.261      0.794      -0.519       0.678
# =====================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                          OR      2.5%     97.5%
# const                              3.396138  1.494146  7.719296
# Covering water storage containers  1.082864  0.595171  1.970181
#
# --- Regression for Predictor: Sweeping the yard ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       73
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:               0.0009512
# Time:                                                          10:44:43   Log-Likelihood:                -38.839
# converged:                                                         True   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                    0.7857
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 1.1797      0.533      2.215      0.027       0.136       2.224
# Sweeping the yard     0.0889      0.325      0.274      0.784      -0.548       0.726
# =====================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                          OR      2.5%    97.5%
# const              3.253517  1.145646  9.23966
# Sweeping the yard  1.092989  0.578007  2.06680
#
# ====== Poisson Regressions for Rural Area (Outcome: Cases of malaria in the past year) ======
#
# --- Regression for Predictor: Engaged in household environmental measures ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                   75
# Model:                                       Poisson   Df Residuals:                       73
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:                 0.01984
# Time:                                       10:44:43   Log-Likelihood:                -173.78
# converged:                                      True   LL-Null:                       -177.30
# Covariance Type:                           nonrobust   LLR p-value:                  0.007999
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                           1.5261      0.209      7.319      0.000       1.117       1.935
# Engaged in household environmental measures    -0.6388      0.222     -2.875      0.004      -1.074      -0.203
# ===============================================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                                                  IRR      2.5%     97.5%
# const                                        4.60000  3.056821  6.922224
# Engaged in household environmental measures  0.52795  0.341570  0.816031
#
# ====== Poisson Regressions for Rural Area (Outcome: Cases of malaria in the past year) ======
#
# --- Regression for Predictor: Eliminating standing water ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                   75
# Model:                                       Poisson   Df Residuals:                       73
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:                 0.01116
# Time:                                       10:44:43   Log-Likelihood:                -175.32
# converged:                                      True   LL-Null:                       -177.30
# Covariance Type:                           nonrobust   LLR p-value:                   0.04671
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          1.1186      0.109     10.266      0.000       0.905       1.332
# Eliminating standing water    -0.1583      0.079     -1.995      0.046      -0.314      -0.003
# ==============================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                                  IRR      2.5%     97.5%
# const                       3.060707  2.472109  3.789448
# Eliminating standing water  0.853614  0.730676  0.997237
#
# --- Regression for Predictor: Managing trash cans ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                   75
# Model:                                       Poisson   Df Residuals:                       73
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:                0.008994
# Time:                                       10:44:43   Log-Likelihood:                -175.70
# converged:                                      True   LL-Null:                       -177.30
# Covariance Type:                           nonrobust   LLR p-value:                   0.07413
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   1.0732      0.099     10.884      0.000       0.880       1.266
# Managing trash cans    -0.1401      0.079     -1.777      0.076      -0.295       0.014
# =======================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                           IRR      2.5%     97.5%
# const                2.924736  2.410786  3.548255
# Managing trash cans  0.869306  0.744873  1.014526
#
# --- Regression for Predictor: Mowing grass around the house ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                   75
# Model:                                       Poisson   Df Residuals:                       73
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:                0.003634
# Time:                                       10:44:43   Log-Likelihood:                -176.65
# converged:                                      True   LL-Null:                       -177.30
# Covariance Type:                           nonrobust   LLR p-value:                    0.2563
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                             1.0697      0.128      8.353      0.000       0.819       1.321
# Mowing grass around the house    -0.0959      0.084     -1.144      0.253      -0.260       0.068
# =================================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                                     IRR      2.5%     97.5%
# const                          2.914598  2.267598  3.746202
# Mowing grass around the house  0.908591  0.770992  1.070748
#
# --- Regression for Predictor: Maintaining drainage systems used to direct water away from homes ---
#                                   Poisson Regression Results
# ...
# Model:                                                            Logit   Df Residuals:                      205
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                0.001382
# Time:                                                          10:44:43   Log-Likelihood:                -141.77
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                    0.5311
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                 0.1318      0.225      0.585      0.559      -0.310       0.573
# Covering water storage containers     0.0965      0.154      0.626      0.531      -0.205       0.398
# =====================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                          OR      2.5%     97.5%
# const                              1.140900  0.733619  1.774290
# Covering water storage containers  1.101255  0.814352  1.489238
#
# --- Regression for Predictor: Sweeping the yard ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      205
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                0.005545
# Time:                                                          10:44:43   Log-Likelihood:                -141.18
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                    0.2096
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 0.5953      0.319      1.865      0.062      -0.030       1.221
# Sweeping the yard    -0.2230      0.180     -1.241      0.215      -0.575       0.129
# =====================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                          OR      2.5%     97.5%
# const              1.813596  0.970037  3.390724
# Sweeping the yard  0.800153  0.562651  1.137908
#
# ====== Poisson Regressions for Urban Area (Outcome: Cases of malaria in the past year) ======
#
# --- Regression for Predictor: Engaged in household environmental measures ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  207
# Model:                                       Poisson   Df Residuals:                      205
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:                0.009736
# Time:                                       10:44:43   Log-Likelihood:                -363.82
# converged:                                      True   LL-Null:                       -367.39
# Covariance Type:                           nonrobust   LLR p-value:                  0.007479
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                          -0.6061      0.408     -1.485      0.138      -1.406       0.194
# Engaged in household environmental measures     0.9411      0.413      2.281      0.023       0.132       1.750
# ===============================================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                                                   IRR      2.5%     97.5%
# const                                        0.545455  0.245051  1.214116
# Engaged in household environmental measures  2.562925  1.141432  5.754686
#
# ====== Poisson Regressions for Urban Area (Outcome: Cases of malaria in the past year) ======
#
# --- Regression for Predictor: Eliminating standing water ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  207
# Model:                                       Poisson   Df Residuals:                      205
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:                0.005092
# Time:                                       10:44:43   Log-Likelihood:                -365.52
# converged:                                      True   LL-Null:                       -367.39
# Covariance Type:                           nonrobust   LLR p-value:                   0.05307
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          0.1432      0.105      1.364      0.173      -0.063       0.349
# Eliminating standing water     0.1340      0.070      1.919      0.055      -0.003       0.271
# ==============================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                                  IRR      2.5%     97.5%
# const                       1.153936  0.939368  1.417516
# Eliminating standing water  1.143382  0.997128  1.311087
#
# --- Regression for Predictor: Managing trash cans ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  207
# Model:                                       Poisson   Df Residuals:                      205
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:                0.003946
# Time:                                       10:44:43   Log-Likelihood:                -365.94
# converged:                                      True   LL-Null:                       -367.39
# Covariance Type:                           nonrobust   LLR p-value:                   0.08860
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.4175      0.088      4.740      0.000       0.245       0.590
# Managing trash cans    -0.1114      0.065     -1.704      0.088      -0.240       0.017
# =======================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                           IRR      2.5%     97.5%
# const                1.518116  1.277420  1.804164
# Managing trash cans  0.894568  0.786944  1.016910
#
# --- Regression for Predictor: Mowing grass around the house ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  207
# Model:                                       Poisson   Df Residuals:                      205
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:                0.008096
# Time:                                       10:44:43   Log-Likelihood:                -364.42
# converged:                                      True   LL-Null:                       -367.39
# Covariance Type:                           nonrobust   LLR p-value:                   0.01473
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                             0.0300      0.133      0.225      0.822      -0.231       0.291
# Mowing grass around the house     0.1849      0.078      2.372      0.018       0.032       0.338
# =================================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                                     IRR      2.5%     97.5%
# const                          1.030498  0.793566  1.338171
# Mowing grass around the house  1.203113  1.032655  1.401707
#
# --- Regression for Predictor: Maintaining drainage systems used to direct water away from homes ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  207
# Model:                                       Poisson   Df Residuals:                      205
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:               0.0006704
# Time:                                       10:44:43   Log-Likelihood:                -367.15
# converged:                                      True   LL-Null:                       -367.39
# Covariance Type:                           nonrobust   LLR p-value:                    0.4828
# =====================================================================================================================================
#                                                                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------
# const                                                                 0.2509      0.095      2.632      0.008       0.064       0.438
# Maintaining drainage systems used to direct water away from homes     0.0484      0.069      0.701      0.483      -0.087       0.184
# =====================================================================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                                                          IRR      2.5%  \
# const                                               1.285163  1.066178
# Maintaining drainage systems used to direct wat...  1.049624  0.916734
#
#                                                        97.5%
# const                                               1.549127
# Maintaining drainage systems used to direct wat...  1.201778
#
# --- Regression for Predictor: Covering water storage containers ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  207
# Model:                                       Poisson   Df Residuals:                      205
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:               0.0008114
# Time:                                       10:44:43   Log-Likelihood:                -367.10
# converged:                                      True   LL-Null:                       -367.39
# Covariance Type:                           nonrobust   LLR p-value:                    0.4400
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                 0.2421      0.099      2.438      0.015       0.047       0.437
# Covering water storage containers     0.0510      0.066      0.770      0.441      -0.079       0.181
# =====================================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                                         IRR      2.5%     97.5%
# const                              1.273900  1.048612  1.547591
# Covering water storage containers  1.052353  0.924154  1.198336
#
# --- Regression for Predictor: Sweeping the yard ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  207
# Model:                                       Poisson   Df Residuals:                      205
# Method:                                          MLE   Df Model:                            1
# Date:                               Mon, 19 May 2025   Pseudo R-squ.:                0.004738
# Time:                                       10:44:43   Log-Likelihood:                -365.65
# converged:                                      True   LL-Null:                       -367.39
# Covariance Type:                           nonrobust   LLR p-value:                   0.06206
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 0.5048      0.119      4.236      0.000       0.271       0.738
# Sweeping the yard    -0.1329      0.070     -1.906      0.057      -0.270       0.004
# =====================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                         IRR      2.5%     97.5%
# const              1.656666  1.311620  2.092483
# Sweeping the yard  0.875542  0.763714  1.003746

# %%
#engaged in household practices as predictor and breeding sites as outcome
import pandas as pd
import statsmodels.api as sm
import numpy as np

# Load dataset
#step 1 Load the data
file_path = r'/content/Data of Malaria (THESIS) 17 april.xlsx'
sheet_name = 'Form responses 1'

#step 2 read the data
data = pd.read_excel(file_path, sheet_name=sheet_name)

# Clean column names
data.columns = data.columns.str.strip()

# Transform outcome: 'Observed breeding sites in the past year' to binary
data['Observed breeding sites in the past year'] = data['Observed breeding sites in the past year'].map({'Yes': 1, 'No': 0})

# Recode main environmental engagement variable
data['Engaged in household environmental measures'] = data['Engaged in household environmental measures'].map({'Yes': 1, 'No': 0})

# Define individual environmental practices (your exact names)
environmental_practices = [
    'Eliminating standing water',
    'Managing trash cans',
    'Mowing grass around the house',
    'Maintaining drainage systems used to direct water away from homes',
    'Covering water storage containers',
    'Sweeping the yard'
]

# Transform activities into ordinal values: Never = 0, Rarely = 1, Monthly/Weekly/Daily = 2
def transform_activity(x):
    if x == 'Never':
        return 0
    elif x == 'Rarely':
        return 1
    elif x in ['Monthly', 'Weekly', 'Daily']:
        return 2
    else:
        return np.nan

for col in environmental_practices:
    data[col] = data[col].apply(transform_activity)

# Logistic regression function
def run_logistic(X, y):
    X = sm.add_constant(X)
    model = sm.Logit(y, X)
    result = model.fit(disp=0)
    return result

# General function to run regression
def simple_regression(subset_data, predictor_list, outcome, model_type="logistic", label="Full Sample"):
    print(f"\n====== {model_type.capitalize()} Regressions for {label} (Outcome: {outcome}) ======")
    for predictor in predictor_list:
        print(f"\n--- Regression for Predictor: {predictor} ---")

        X = subset_data[[predictor]]
        y = subset_data[outcome]

        df_temp = pd.concat([X, y], axis=1).dropna()
        X_clean = df_temp[[predictor]]
        y_clean = df_temp[outcome]

        if X_clean.shape[0] > 0:
            try:
                result = run_logistic(X_clean, y_clean)

                print(result.summary())

                or_table = pd.DataFrame({
                    "OR": np.exp(result.params),
                    "2.5%": np.exp(result.conf_int()[0]),
                    "97.5%": np.exp(result.conf_int()[1])
                })
                print("\nOdds Ratios (OR) and 95% CI:")
                print(or_table)

            except Exception as e:
                print(f"⚠️ Regression failed for {predictor}: {e}")
        else:
            print(f"⚠️ No valid data for {predictor} in {label}")

# Main predictor
main_predictor = ['Engaged in household environmental measures']

# Outcome
outcome_logistic = 'Observed breeding sites in the past year'

# Split data
rural_data = data[data['Area of residence'] == 'Rural area']
urban_data = data[data['Area of residence'] == 'Urban area']

# ===== RUNNING =====

# 1. Full Sample - General
simple_regression(data, main_predictor, outcome=outcome_logistic, model_type="logistic", label="Full Sample")

# 2. Full Sample - Individual practices
simple_regression(data, environmental_practices, outcome=outcome_logistic, model_type="logistic", label="Full Sample")

# 3. Rural - General
simple_regression(rural_data, main_predictor, outcome=outcome_logistic, model_type="logistic", label="Rural Area")

# 4. Rural - Individual practices
simple_regression(rural_data, environmental_practices, outcome=outcome_logistic, model_type="logistic", label="Rural Area")

# 5. Urban - General
simple_regression(urban_data, main_predictor, outcome=outcome_logistic, model_type="logistic", label="Urban Area")

# 6. Urban - Individual practices
simple_regression(urban_data, environmental_practices, outcome=outcome_logistic, model_type="logistic", label="Urban Area")
# Out:
# ====== Logistic Regressions for Full Sample (Outcome: Observed breeding sites in the past year) ======
#
# --- Regression for Predictor: Engaged in household environmental measures ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                  282
# Model:                                                Logit   Df Residuals:                      280
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Mon, 19 May 2025   Pseudo R-squ.:                 0.01273
# Time:                                              10:51:24   Log-Likelihood:                -133.08
# converged:                                             True   LL-Null:                       -134.79
# Covariance Type:                                  nonrobust   LLR p-value:                   0.06399
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                           0.5108      0.516      0.989      0.323      -0.501       1.523
# Engaged in household environmental measures     1.0542      0.541      1.948      0.051      -0.007       2.115
# ===============================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                                    OR      2.5%     97.5%
# const                                        1.666667  0.605745  4.585718
# Engaged in household environmental measures  2.869565  0.993353  8.289507
#
# ====== Logistic Regressions for Full Sample (Outcome: Observed breeding sites in the past year) ======
#
# --- Regression for Predictor: Eliminating standing water ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                  282
# Model:                                                Logit   Df Residuals:                      280
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Mon, 19 May 2025   Pseudo R-squ.:                 0.01205
# Time:                                              10:51:24   Log-Likelihood:                -133.17
# converged:                                             True   LL-Null:                       -134.79
# Covariance Type:                                  nonrobust   LLR p-value:                   0.07149
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          1.1537      0.231      4.991      0.000       0.701       1.607
# Eliminating standing water     0.3127      0.174      1.798      0.072      -0.028       0.653
# ==============================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                   OR      2.5%     97.5%
# const                       3.169919  2.015115  4.986508
# Eliminating standing water  1.367103  0.972294  1.922228
#
# --- Regression for Predictor: Managing trash cans ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                  282
# Model:                                                Logit   Df Residuals:                      280
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Mon, 19 May 2025   Pseudo R-squ.:               0.0005220
# Time:                                              10:51:24   Log-Likelihood:                -134.72
# converged:                                             True   LL-Null:                       -134.79
# Covariance Type:                                  nonrobust   LLR p-value:                    0.7076
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   1.5543      0.239      6.510      0.000       1.086       2.022
# Managing trash cans    -0.0630      0.168     -0.375      0.708      -0.393       0.267
# =======================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                            OR      2.5%     97.5%
# const                4.731711  2.963332  7.555375
# Managing trash cans  0.938899  0.675151  1.305680
#
# --- Regression for Predictor: Mowing grass around the house ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                  282
# Model:                                                Logit   Df Residuals:                      280
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Mon, 19 May 2025   Pseudo R-squ.:                0.002275
# Time:                                              10:51:24   Log-Likelihood:                -134.49
# converged:                                             True   LL-Null:                       -134.79
# Covariance Type:                                  nonrobust   LLR p-value:                    0.4335
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                             1.2939      0.284      4.557      0.000       0.737       1.850
# Mowing grass around the house     0.1419      0.180      0.790      0.430      -0.210       0.494
# =================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                      OR      2.5%     97.5%
# const                          3.647123  2.090645  6.362395
# Mowing grass around the house  1.152513  0.810250  1.639355
#
# --- Regression for Predictor: Maintaining drainage systems used to direct water away from homes ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                  282
# Model:                                                Logit   Df Residuals:                      280
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Mon, 19 May 2025   Pseudo R-squ.:               0.0005744
# Time:                                              10:51:24   Log-Likelihood:                -134.72
# converged:                                             True   LL-Null:                       -134.79
# Covariance Type:                                  nonrobust   LLR p-value:                    0.6939
# =====================================================================================================================================
#                                                                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------
# const                                                                 1.5574      0.239      6.530      0.000       1.090       2.025
# Maintaining drainage systems used to direct water away from homes    -0.0685      0.174     -0.393      0.694      -0.410       0.273
# =====================================================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                                           OR      2.5%  \
# const                                               4.746640  2.974170
# Maintaining drainage systems used to direct wat...  0.933816  0.663802
#
#                                                        97.5%
# const                                               7.575423
# Maintaining drainage systems used to direct wat...  1.313662
#
# --- Regression for Predictor: Covering water storage containers ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                  282
# Model:                                                Logit   Df Residuals:                      280
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Mon, 19 May 2025   Pseudo R-squ.:                0.003311
# Time:                                              10:51:24   Log-Likelihood:                -134.35
# converged:                                             True   LL-Null:                       -134.79
# Covariance Type:                                  nonrobust   LLR p-value:                    0.3447
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                 1.3152      0.233      5.655      0.000       0.859       1.771
# Covering water storage containers     0.1580      0.167      0.946      0.344      -0.169       0.485
# =====================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                          OR      2.5%     97.5%
# const                              3.725599  2.361674  5.877224
# Covering water storage containers  1.171192  0.844132  1.624972
#
# --- Regression for Predictor: Sweeping the yard ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                  282
# Model:                                                Logit   Df Residuals:                      280
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Mon, 19 May 2025   Pseudo R-squ.:                0.005571
# Time:                                              10:51:24   Log-Likelihood:                -134.04
# converged:                                             True   LL-Null:                       -134.79
# Covariance Type:                                  nonrobust   LLR p-value:                    0.2204
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 1.8739      0.371      5.056      0.000       1.147       2.600
# Sweeping the yard    -0.2446      0.207     -1.184      0.236      -0.649       0.160
# =====================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                          OR      2.5%      97.5%
# const              6.513514  3.150256  13.467434
# Sweeping the yard  0.783036  0.522313   1.173903
#
# ====== Logistic Regressions for Rural Area (Outcome: Observed breeding sites in the past year) ======
#
# --- Regression for Predictor: Engaged in household environmental measures ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                   75
# Model:                                                Logit   Df Residuals:                       73
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Mon, 19 May 2025   Pseudo R-squ.:               0.0003710
# Time:                                              10:51:24   Log-Likelihood:                -34.572
# converged:                                             True   LL-Null:                       -34.585
# Covariance Type:                                  nonrobust   LLR p-value:                    0.8727
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                           1.3863      1.118      1.240      0.215      -0.805       3.578
# Engaged in household environmental measures     0.1892      1.162      0.163      0.871      -2.089       2.467
# ===============================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                                    OR      2.5%      97.5%
# const                                        4.000000  0.447083  35.787573
# Engaged in household environmental measures  1.208333  0.123871  11.787021
#
# ====== Logistic Regressions for Rural Area (Outcome: Observed breeding sites in the past year) ======
#
# --- Regression for Predictor: Eliminating standing water ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                   75
# Model:                                                Logit   Df Residuals:                       73
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Mon, 19 May 2025   Pseudo R-squ.:                 0.02761
# Time:                                              10:51:24   Log-Likelihood:                -33.630
# converged:                                             True   LL-Null:                       -34.585
# Covariance Type:                                  nonrobust   LLR p-value:                    0.1670
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          1.0759      0.440      2.444      0.015       0.213       1.939
# Eliminating standing water     0.4690      0.343      1.368      0.171      -0.203       1.141
# ==============================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                   OR      2.5%     97.5%
# const                       2.932609  1.237483  6.949748
# Eliminating standing water  1.598337  0.816287  3.129637
#
# --- Regression for Predictor: Managing trash cans ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                   75
# Model:                                                Logit   Df Residuals:                       73
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Mon, 19 May 2025   Pseudo R-squ.:               0.0001896
# Time:                                              10:51:24   Log-Likelihood:                -34.578
# converged:                                             True   LL-Null:                       -34.585
# Covariance Type:                                  nonrobust   LLR p-value:                    0.9088
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   1.5994      0.448      3.568      0.000       0.721       2.478
# Managing trash cans    -0.0378      0.330     -0.115      0.909      -0.685       0.610
# =======================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                            OR      2.5%      97.5%
# const                4.950035  2.056152  11.916845
# Managing trash cans  0.962886  0.504020   1.839512
#
# --- Regression for Predictor: Mowing grass around the house ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                   75
# Model:                                                Logit   Df Residuals:                       73
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Mon, 19 May 2025   Pseudo R-squ.:               0.0008616
# Time:                                              10:51:24   Log-Likelihood:                -34.555
# converged:                                             True   LL-Null:                       -34.585
# Covariance Type:                                  nonrobust   LLR p-value:                    0.8071
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                             1.6840      0.594      2.834      0.005       0.520       2.848
# Mowing grass around the house    -0.0900      0.371     -0.243      0.808      -0.817       0.637
# =================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                      OR      2.5%      97.5%
# const                          5.386909  1.681243  17.260317
# Mowing grass around the house  0.913974  0.441793   1.890812
#
# --- Regression for Predictor: Maintaining drainage systems used to direct water away from homes ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                   75
# Model:                                                Logit   Df Residuals:                       73
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Mon, 19 May 2025   Pseudo R-squ.:               0.0007595
# Time:                                              10:51:24   Log-Likelihood:                -34.559
# converged:                                             True   LL-Null:                       -34.585
# Covariance Type:                                  nonrobust   LLR p-value:                    0.8187
# =====================================================================================================================================
#                                                                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------
# const                                                                 1.6355      0.447      3.658      0.000       0.759       2.512
# Maintaining drainage systems used to direct water away from homes    -0.0757      0.330     -0.229      0.819      -0.723       0.572
# =====================================================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                                           OR      2.5%  \
# const                                               5.131940  2.136707
# Maintaining drainage systems used to direct wat...  0.927054  0.485116
#
#                                                         97.5%
# const                                               12.325885
# Maintaining drainage systems used to direct wat...   1.771593
#
# --- Regression for Predictor: Covering water storage containers ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                   75
# Model:                                                Logit   Df Residuals:                       73
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Mon, 19 May 2025   Pseudo R-squ.:                0.004530
# Time:                                              10:51:24   Log-Likelihood:                -34.428
# converged:                                             True   LL-Null:                       -34.585
# Covariance Type:                                  nonrobust   LLR p-value:                    0.5756
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                 1.3767      0.439      3.136      0.002       0.516       2.237
# Covering water storage containers     0.1852      0.332      0.559      0.576      -0.465       0.835
# =====================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                          OR      2.5%     97.5%
# const                              3.961635  1.675694  9.366000
# Covering water storage containers  1.203437  0.628399  2.304685
#
# --- Regression for Predictor: Sweeping the yard ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                   75
# Model:                                                Logit   Df Residuals:                       73
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Mon, 19 May 2025   Pseudo R-squ.:                 0.01196
# Time:                                              10:51:24   Log-Likelihood:                -34.171
# converged:                                             True   LL-Null:                       -34.585
# Covariance Type:                                  nonrobust   LLR p-value:                    0.3630
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 2.0921      0.711      2.941      0.003       0.698       3.486
# Sweeping the yard    -0.3515      0.405     -0.868      0.385      -1.145       0.442
# =====================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                          OR      2.5%      97.5%
# const              8.101657  2.009667  32.660550
# Sweeping the yard  0.703639  0.318250   1.555721
#
# ====== Logistic Regressions for Urban Area (Outcome: Observed breeding sites in the past year) ======
#
# --- Regression for Predictor: Engaged in household environmental measures ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                  207
# Model:                                                Logit   Df Residuals:                      205
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Mon, 19 May 2025   Pseudo R-squ.:                 0.02162
# Time:                                              10:51:24   Log-Likelihood:                -98.003
# converged:                                             True   LL-Null:                       -100.17
# Covariance Type:                                  nonrobust   LLR p-value:                   0.03744
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                           0.1823      0.606      0.301      0.763      -1.004       1.369
# Engaged in household environmental measures     1.3789      0.634      2.174      0.030       0.136       2.622
# ===============================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                                    OR      2.5%      97.5%
# const                                        1.200000  0.366229   3.931963
# Engaged in household environmental measures  3.970588  1.145499  13.763054
#
# ====== Logistic Regressions for Urban Area (Outcome: Observed breeding sites in the past year) ======
#
# --- Regression for Predictor: Eliminating standing water ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                  207
# Model:                                                Logit   Df Residuals:                      205
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Mon, 19 May 2025   Pseudo R-squ.:                0.008062
# Time:                                              10:51:24   Log-Likelihood:                -99.360
# converged:                                             True   LL-Null:                       -100.17
# Covariance Type:                                  nonrobust   LLR p-value:                    0.2038
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          1.1844      0.272      4.359      0.000       0.652       1.717
# Eliminating standing water     0.2569      0.202      1.270      0.204      -0.140       0.653
# ==============================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                   OR      2.5%     97.5%
# const                       3.268864  1.919178  5.567733
# Eliminating standing water  1.292967  0.869742  1.922135
#
# --- Regression for Predictor: Managing trash cans ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                  207
# Model:                                                Logit   Df Residuals:                      205
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Mon, 19 May 2025   Pseudo R-squ.:               0.0006159
# Time:                                              10:51:24   Log-Likelihood:                -100.11
# converged:                                             True   LL-Null:                       -100.17
# Covariance Type:                                  nonrobust   LLR p-value:                    0.7254
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   1.5360      0.282      5.444      0.000       0.983       2.089
# Managing trash cans    -0.0688      0.196     -0.351      0.726      -0.453       0.315
# =======================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                            OR      2.5%     97.5%
# const                4.646072  2.672427  8.077298
# Managing trash cans  0.933557  0.635723  1.370926
#
# --- Regression for Predictor: Mowing grass around the house ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                  207
# Model:                                                Logit   Df Residuals:                      205
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Mon, 19 May 2025   Pseudo R-squ.:                0.005603
# Time:                                              10:51:24   Log-Likelihood:                -99.607
# converged:                                             True   LL-Null:                       -100.17
# Covariance Type:                                  nonrobust   LLR p-value:                    0.2894
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                             1.1592      0.325      3.571      0.000       0.523       1.795
# Mowing grass around the house     0.2209      0.206      1.072      0.284      -0.183       0.625
# =================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                      OR      2.5%     97.5%
# const                          3.187430  1.687161  6.021779
# Mowing grass around the house  1.247259  0.832627  1.868369
#
# --- Regression for Predictor: Maintaining drainage systems used to direct water away from homes ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                  207
# Model:                                                Logit   Df Residuals:                      205
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Mon, 19 May 2025   Pseudo R-squ.:               0.0004677
# Time:                                              10:51:24   Log-Likelihood:                -100.12
# converged:                                             True   LL-Null:                       -100.17
# Covariance Type:                                  nonrobust   LLR p-value:                    0.7595
# =====================================================================================================================================
#                                                                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------
# const                                                                 1.5266      0.282      5.407      0.000       0.973       2.080
# Maintaining drainage systems used to direct water away from homes    -0.0628      0.205     -0.306      0.760      -0.465       0.340
# =====================================================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                                           OR      2.5%  \
# const                                               4.602364  2.646313
# Maintaining drainage systems used to direct wat...  0.939117  0.627923
#
#                                                        97.5%
# const                                               8.004252
# Maintaining drainage systems used to direct wat...  1.404535
#
# --- Regression for Predictor: Covering water storage containers ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                  207
# Model:                                                Logit   Df Residuals:                      205
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Mon, 19 May 2025   Pseudo R-squ.:                0.003076
# Time:                                              10:51:24   Log-Likelihood:                -99.860
# converged:                                             True   LL-Null:                       -100.17
# Covariance Type:                                  nonrobust   LLR p-value:                    0.4325
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                 1.2903      0.274      4.704      0.000       0.753       1.828
# Covering water storage containers     0.1525      0.194      0.786      0.432      -0.228       0.533
# =====================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                          OR      2.5%     97.5%
# const                              3.633857  2.122719  6.220754
# Covering water storage containers  1.164774  0.796432  1.703470
#
# --- Regression for Predictor: Sweeping the yard ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                  207
# Model:                                                Logit   Df Residuals:                      205
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Mon, 19 May 2025   Pseudo R-squ.:                0.003665
# Time:                                              10:51:24   Log-Likelihood:                -99.801
# converged:                                             True   LL-Null:                       -100.17
# Covariance Type:                                  nonrobust   LLR p-value:                    0.3915
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 1.7826      0.434      4.103      0.000       0.931       2.634
# Sweeping the yard    -0.2002      0.240     -0.833      0.405      -0.671       0.271
# =====================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                          OR      2.5%      97.5%
# const              5.945142  2.537293  13.930087
# Sweeping the yard  0.818592  0.510997   1.311343

# %%
#community engagement vs malaria history and cases of malaria as well as breeding sites
import pandas as pd
import statsmodels.api as sm
import numpy as np

# Load dataset
#step 1 Load the data
file_path = r'/content/Data of Malaria (THESIS) 17 april.xlsx'
sheet_name = 'Form responses 1'

#read the data
data = pd.read_excel(file_path, sheet_name=sheet_name)

# Step 2: Clean column names
data.columns = data.columns.str.strip()

# Step 3: Transform outcome variables
data['Observed breeding sites in the past year'] = data['Observed breeding sites in the past year'].map({'Yes': 1, 'No': 0})

# Cap malaria cases at household size if >10
data['Cases of malaria in the past year'] = np.where(
    data['Cases of malaria in the past year'] > 10,
    data['Household size'],
    data['Cases of malaria in the past year']
)

# Main community engagement variable
data['Community engagement in control of mosquito breeding sites'] = data['Community engagement in control of mosquito breeding sites'].map({'Yes': 1, 'No': 0})

# Binary variable for malaria history
data['History of malaria in the past year in the household'] = data['History of malaria in the past year in the household'].map({'Yes': 1, 'No': 0})

# Step 4: Transform activity-level variables
community_activities = [
    'Removing stagnant water in open places like markets and hospitals',
    'Mowing grass in open places',
    'Filling potholes',
    'Sweeping around markets',
    'Information sharing'
]

def transform_activity(x):
    if x == 'Never':
        return 0
    elif x == 'Rarely':
        return 1
    elif x in ['Monthly', 'Weekly', 'Daily']:
        return 2
    else:
        return np.nan

for col in community_activities:
    data[col] = data[col].apply(transform_activity)

# Step 5: Regression functions
def run_logistic(X, y):
    X = sm.add_constant(X)
    model = sm.Logit(y, X)
    result = model.fit(disp=0)
    return result

def run_poisson(X, y):
    X = sm.add_constant(X)
    model = sm.Poisson(y, X)
    result = model.fit(disp=0)
    return result

def simple_regression(subset_data, predictor_list, outcome, model_type="logistic", label="Full Sample"):
    print(f"\n====== {model_type.capitalize()} Regressions for {label} (Outcome: {outcome}) ======")
    for predictor in predictor_list:
        print(f"\n--- Regression for Predictor: {predictor} ---")

        X = subset_data[[predictor]]
        y = subset_data[outcome]

        df_temp = pd.concat([X, y], axis=1).dropna()
        X_clean = df_temp[[predictor]]
        y_clean = df_temp[outcome]

        if X_clean.shape[0] > 0:
            try:
                if model_type == "logistic":
                    result = run_logistic(X_clean, y_clean)
                else:
                    result = run_poisson(X_clean, y_clean)

                print(result.summary())

                if model_type == "logistic":
                    or_table = pd.DataFrame({
                        "OR": np.exp(result.params),
                        "2.5%": np.exp(result.conf_int()[0]),
                        "97.5%": np.exp(result.conf_int()[1])
                    })
                    print("\nOdds Ratios (OR) and 95% CI:")
                    print(or_table)
                else:
                    irr_table = pd.DataFrame({
                        "IRR": np.exp(result.params),
                        "2.5%": np.exp(result.conf_int()[0]),
                        "97.5%": np.exp(result.conf_int()[1])
                    })
                    print("\nIncidence Rate Ratios (IRR) and 95% CI:")
                    print(irr_table)

            except Exception as e:
                print(f"⚠️ Regression failed for {predictor}: {e}")
        else:
            print(f"⚠️ No valid data for {predictor} in {label}")

# Step 6: Define predictors and outcomes
main_community_engagement = ['Community engagement in control of mosquito breeding sites']
outcome_poisson = 'Cases of malaria in the past year'
outcome_logistic_breeding = 'Observed breeding sites in the past year'
outcome_logistic_history = 'History of malaria in the past year in the household'

# Step 7: Split by residence area
rural_data = data[data['Area of residence'] == 'Rural area']
urban_data = data[data['Area of residence'] == 'Urban area']

# ===== RUNNING ANALYSIS =====

# --- Poisson regression: Cases of malaria ---
simple_regression(data, main_community_engagement, outcome=outcome_poisson, model_type="poisson", label="Full Sample")
simple_regression(data, community_activities, outcome=outcome_poisson, model_type="poisson", label="Full Sample")

simple_regression(rural_data, main_community_engagement, outcome=outcome_poisson, model_type="poisson", label="Rural Area")
simple_regression(rural_data, community_activities, outcome=outcome_poisson, model_type="poisson", label="Rural Area")

simple_regression(urban_data, main_community_engagement, outcome=outcome_poisson, model_type="poisson", label="Urban Area")
simple_regression(urban_data, community_activities, outcome=outcome_poisson, model_type="poisson", label="Urban Area")

# --- Logistic regression: Observed breeding sites ---
simple_regression(data, main_community_engagement, outcome=outcome_logistic_breeding, model_type="logistic", label="Full Sample")
simple_regression(data, community_activities, outcome=outcome_logistic_breeding, model_type="logistic", label="Full Sample")

simple_regression(rural_data, main_community_engagement, outcome=outcome_logistic_breeding, model_type="logistic", label="Rural Area")
simple_regression(rural_data, community_activities, outcome=outcome_logistic_breeding, model_type="logistic", label="Rural Area")

simple_regression(urban_data, main_community_engagement, outcome=outcome_logistic_breeding, model_type="logistic", label="Urban Area")
simple_regression(urban_data, community_activities, outcome=outcome_logistic_breeding, model_type="logistic", label="Urban Area")

# --- Logistic regression: History of malaria in household ---
simple_regression(data, main_community_engagement, outcome=outcome_logistic_history, model_type="logistic", label="Full Sample")
simple_regression(data, community_activities, outcome=outcome_logistic_history, model_type="logistic", label="Full Sample")

simple_regression(rural_data, main_community_engagement, outcome=outcome_logistic_history, model_type="logistic", label="Rural Area")
simple_regression(rural_data, community_activities, outcome=outcome_logistic_history, model_type="logistic", label="Rural Area")

simple_regression(urban_data, main_community_engagement, outcome=outcome_logistic_history, model_type="logistic", label="Urban Area")
simple_regression(urban_data, community_activities, outcome=outcome_logistic_history, model_type="logistic", label="Urban Area")
# Out:
# ====== Poisson Regressions for Full Sample (Outcome: Cases of malaria in the past year) ======
#
# --- Regression for Predictor: Community engagement in control of mosquito breeding sites ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  282
# Model:                                       Poisson   Df Residuals:                      280
# Method:                                          MLE   Df Model:                            1
# Date:                               Wed, 21 May 2025   Pseudo R-squ.:                0.003557
# Time:                                       17:34:39   Log-Likelihood:                -565.05
# converged:                                      True   LL-Null:                       -567.06
# Covariance Type:                           nonrobust   LLR p-value:                   0.04459
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                          0.3640      0.092      3.954      0.000       0.184       0.544
# Community engagement in control of mosquito breeding sites     0.2098      0.106      1.975      0.048       0.002       0.418
# ==============================================================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                                                          IRR      2.5%  \
# const                                               1.439024  1.201458
# Community engagement in control of mosquito bre...  1.233475  1.001568
#
#                                                        97.5%
# const                                               1.723565
# Community engagement in control of mosquito bre...  1.519078
#
# ====== Poisson Regressions for Full Sample (Outcome: Cases of malaria in the past year) ======
#
# --- Regression for Predictor: Removing stagnant water in open places like markets and hospitals ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  282
# Model:                                       Poisson   Df Residuals:                      280
# Method:                                          MLE   Df Model:                            1
# Date:                               Wed, 21 May 2025   Pseudo R-squ.:                0.001538
# Time:                                       17:34:39   Log-Likelihood:                -566.19
# converged:                                      True   LL-Null:                       -567.06
# Covariance Type:                           nonrobust   LLR p-value:                    0.1866
# =====================================================================================================================================
#                                                                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------
# const                                                                 0.5815      0.066      8.803      0.000       0.452       0.711
# Removing stagnant water in open places like markets and hospitals    -0.0726      0.055     -1.317      0.188      -0.181       0.035
# =====================================================================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                                                          IRR      2.5%  \
# const                                               1.788761  1.571519
# Removing stagnant water in open places like mar...  0.929950  0.834708
#
#                                                        97.5%
# const                                               2.036033
# Removing stagnant water in open places like mar...  1.036058
#
# --- Regression for Predictor: Mowing grass in open places ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  282
# Model:                                       Poisson   Df Residuals:                      280
# Method:                                          MLE   Df Model:                            1
# Date:                               Wed, 21 May 2025   Pseudo R-squ.:               0.0002394
# Time:                                       17:34:39   Log-Likelihood:                -566.93
# converged:                                      True   LL-Null:                       -567.06
# Covariance Type:                           nonrobust   LLR p-value:                    0.6023
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                           0.4890      0.071      6.849      0.000       0.349       0.629
# Mowing grass in open places     0.0266      0.051      0.521      0.602      -0.074       0.127
# ===============================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                                   IRR      2.5%     97.5%
# const                        1.630729  1.417778  1.875665
# Mowing grass in open places  1.027004  0.929020  1.135322
#
# --- Regression for Predictor: Filling potholes ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  282
# Model:                                       Poisson   Df Residuals:                      280
# Method:                                          MLE   Df Model:                            1
# Date:                               Wed, 21 May 2025   Pseudo R-squ.:               0.0006553
# Time:                                       17:34:39   Log-Likelihood:                -566.69
# converged:                                      True   LL-Null:                       -567.06
# Covariance Type:                           nonrobust   LLR p-value:                    0.3886
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.4772      0.066      7.245      0.000       0.348       0.606
# Filling potholes     0.0496      0.057      0.864      0.388      -0.063       0.162
# ====================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                        IRR      2.5%     97.5%
# const             1.611580  1.416384  1.833676
# Filling potholes  1.050809  0.939080  1.175833
#
# --- Regression for Predictor: Sweeping around markets ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  282
# Model:                                       Poisson   Df Residuals:                      280
# Method:                                          MLE   Df Model:                            1
# Date:                               Wed, 21 May 2025   Pseudo R-squ.:                0.001322
# Time:                                       17:34:40   Log-Likelihood:                -566.31
# converged:                                      True   LL-Null:                       -567.06
# Covariance Type:                           nonrobust   LLR p-value:                    0.2208
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.5821      0.069      8.419      0.000       0.447       0.718
# Sweeping around markets    -0.0599      0.049     -1.226      0.220      -0.156       0.036
# ===========================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                               IRR      2.5%     97.5%
# const                    1.789740  1.562937  2.049455
# Sweeping around markets  0.941878  0.855896  1.036499
#
# --- Regression for Predictor: Information sharing ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  282
# Model:                                       Poisson   Df Residuals:                      280
# Method:                                          MLE   Df Model:                            1
# Date:                               Wed, 21 May 2025   Pseudo R-squ.:               5.154e-05
# Time:                                       17:34:40   Log-Likelihood:                -567.04
# converged:                                      True   LL-Null:                       -567.06
# Covariance Type:                           nonrobust   LLR p-value:                    0.8090
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.5279      0.064      8.275      0.000       0.403       0.653
# Information sharing    -0.0130      0.054     -0.242      0.809      -0.119       0.093
# =======================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                           IRR      2.5%     97.5%
# const                1.695431  1.496140  1.921269
# Information sharing  0.987056  0.888062  1.097085
#
# ====== Poisson Regressions for Rural Area (Outcome: Cases of malaria in the past year) ======
#
# --- Regression for Predictor: Community engagement in control of mosquito breeding sites ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                   75
# Model:                                       Poisson   Df Residuals:                       73
# Method:                                          MLE   Df Model:                            1
# Date:                               Wed, 21 May 2025   Pseudo R-squ.:                 0.01774
# Time:                                       17:34:40   Log-Likelihood:                -174.15
# converged:                                      True   LL-Null:                       -177.30
# Covariance Type:                           nonrobust   LLR p-value:                   0.01214
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                          1.2528      0.134      9.375      0.000       0.991       1.515
# Community engagement in control of mosquito breeding sites    -0.4103      0.159     -2.587      0.010      -0.721      -0.099
# ==============================================================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                                                          IRR      2.5%  \
# const                                               3.500000  2.693528
# Community engagement in control of mosquito bre...  0.663438  0.486176
#
#                                                        97.5%
# const                                               4.547939
# Community engagement in control of mosquito bre...  0.905332
#
# ====== Poisson Regressions for Rural Area (Outcome: Cases of malaria in the past year) ======
#
# --- Regression for Predictor: Removing stagnant water in open places like markets and hospitals ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                   75
# Model:                                       Poisson   Df Residuals:                       73
# Method:                                          MLE   Df Model:                            1
# Date:                               Wed, 21 May 2025   Pseudo R-squ.:                 0.01223
# Time:                                       17:34:40   Log-Likelihood:                -175.13
# converged:                                      True   LL-Null:                       -177.30
# Covariance Type:                           nonrobust   LLR p-value:                   0.03731
# =====================================================================================================================================
#                                                                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------
# const                                                                 1.1135      0.105     10.646      0.000       0.909       1.319
# Removing stagnant water in open places like markets and hospitals    -0.1871      0.090     -2.070      0.038      -0.364      -0.010
# =====================================================================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                                                          IRR      2.5%  \
# const                                               3.045018  2.480628
# Removing stagnant water in open places like mar...  0.829338  0.694675
#
#                                                        97.5%
# const                                               3.737817
# Removing stagnant water in open places like mar...  0.990106
#
# --- Regression for Predictor: Mowing grass in open places ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                   75
# Model:                                       Poisson   Df Residuals:                       73
# Method:                                          MLE   Df Model:                            1
# Date:                               Wed, 21 May 2025   Pseudo R-squ.:                 0.02127
# Time:                                       17:34:40   Log-Likelihood:                -173.53
# converged:                                      True   LL-Null:                       -177.30
# Covariance Type:                           nonrobust   LLR p-value:                  0.006030
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                           1.1667      0.103     11.326      0.000       0.965       1.369
# Mowing grass in open places    -0.2178      0.079     -2.741      0.006      -0.374      -0.062
# ===============================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                                   IRR      2.5%     97.5%
# const                        3.211507  2.624366  3.930008
# Mowing grass in open places  0.804286  0.688303  0.939814
#
# --- Regression for Predictor: Filling potholes ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                   75
# Model:                                       Poisson   Df Residuals:                       73
# Method:                                          MLE   Df Model:                            1
# Date:                               Wed, 21 May 2025   Pseudo R-squ.:                 0.01376
# Time:                                       17:34:40   Log-Likelihood:                -174.86
# converged:                                      True   LL-Null:                       -177.30
# Covariance Type:                           nonrobust   LLR p-value:                   0.02719
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.1140      0.101     10.986      0.000       0.915       1.313
# Filling potholes    -0.2065      0.094     -2.186      0.029      -0.392      -0.021
# ====================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                        IRR      2.5%     97.5%
# const             3.046572  2.497432  3.716458
# Filling potholes  0.813466  0.676031  0.978841
#
# --- Regression for Predictor: Sweeping around markets ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                   75
# Model:                                       Poisson   Df Residuals:                       73
# Method:                                          MLE   Df Model:                            1
# Date:                               Wed, 21 May 2025   Pseudo R-squ.:                 0.02900
# Time:                                       17:34:40   Log-Likelihood:                -172.16
# converged:                                      True   LL-Null:                       -177.30
# Covariance Type:                           nonrobust   LLR p-value:                  0.001344
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       1.2321      0.108     11.399      0.000       1.020       1.444
# Sweeping around markets    -0.2524      0.078     -3.227      0.001      -0.406      -0.099
# ===========================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                               IRR      2.5%     97.5%
# const                    3.428266  2.773761  4.237209
# Sweeping around markets  0.776957  0.666547  0.905656
#
# --- Regression for Predictor: Information sharing ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                   75
# Model:                                       Poisson   Df Residuals:                       73
# Method:                                          MLE   Df Model:                            1
# Date:                               Wed, 21 May 2025   Pseudo R-squ.:                 0.02918
# Time:                                       17:34:40   Log-Likelihood:                -172.12
# converged:                                      True   LL-Null:                       -177.30
# Covariance Type:                           nonrobust   LLR p-value:                  0.001296
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   1.1810      0.098     12.093      0.000       0.990       1.372
# Information sharing    -0.2821      0.089     -3.166      0.002      -0.457      -0.107
# =======================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                           IRR      2.5%     97.5%
# const                3.257701  2.690160  3.944976
# Information sharing  0.754204  0.633367  0.898094
#
# ====== Poisson Regressions for Urban Area (Outcome: Cases of malaria in the past year) ======
#
# --- Regression for Predictor: Community engagement in control of mosquito breeding sites ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  207
# Model:                                       Poisson   Df Residuals:                      205
# Method:                                          MLE   Df Model:                            1
# Date:                               Wed, 21 May 2025   Pseudo R-squ.:                 0.01779
# Time:                                       17:34:40   Log-Likelihood:                -360.86
# converged:                                      True   LL-Null:                       -367.39
# Covariance Type:                           nonrobust   LLR p-value:                 0.0003003
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -0.0625      0.127     -0.492      0.623      -0.311       0.186
# Community engagement in control of mosquito breeding sites     0.4983      0.144      3.462      0.001       0.216       0.780
# ==============================================================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                                                          IRR      2.5%  \
# const                                               0.939394  0.732394
# Community engagement in control of mosquito bre...  1.645848  1.241295
#
#                                                        97.5%
# const                                               1.204898
# Community engagement in control of mosquito bre...  2.182248
#
# ====== Poisson Regressions for Urban Area (Outcome: Cases of malaria in the past year) ======
#
# --- Regression for Predictor: Removing stagnant water in open places like markets and hospitals ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  207
# Model:                                       Poisson   Df Residuals:                      205
# Method:                                          MLE   Df Model:                            1
# Date:                               Wed, 21 May 2025   Pseudo R-squ.:               0.0001850
# Time:                                       17:34:40   Log-Likelihood:                -367.33
# converged:                                      True   LL-Null:                       -367.39
# Covariance Type:                           nonrobust   LLR p-value:                    0.7124
# =====================================================================================================================================
#                                                                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------
# const                                                                 0.3250      0.086      3.785      0.000       0.157       0.493
# Removing stagnant water in open places like markets and hospitals    -0.0260      0.070     -0.368      0.713      -0.164       0.112
# =====================================================================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                                                          IRR      2.5%  \
# const                                               1.384062  1.169691
# Removing stagnant water in open places like mar...  0.974380  0.848705
#
#                                                        97.5%
# const                                               1.637721
# Removing stagnant water in open places like mar...  1.118666
#
# --- Regression for Predictor: Mowing grass in open places ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  207
# Model:                                       Poisson   Df Residuals:                      205
# Method:                                          MLE   Df Model:                            1
# Date:                               Wed, 21 May 2025   Pseudo R-squ.:                0.009338
# Time:                                       17:34:40   Log-Likelihood:                -363.96
# converged:                                      True   LL-Null:                       -367.39
# Covariance Type:                           nonrobust   LLR p-value:                  0.008806
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                           0.1097      0.099      1.111      0.267      -0.084       0.303
# Mowing grass in open places     0.1757      0.068      2.602      0.009       0.043       0.308
# ===============================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                                   IRR      2.5%     97.5%
# const                        1.115959  0.919557  1.354311
# Mowing grass in open places  1.192126  1.044319  1.360853
#
# --- Regression for Predictor: Filling potholes ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  207
# Model:                                       Poisson   Df Residuals:                      205
# Method:                                          MLE   Df Model:                            1
# Date:                               Wed, 21 May 2025   Pseudo R-squ.:                0.007026
# Time:                                       17:34:40   Log-Likelihood:                -364.81
# converged:                                      True   LL-Null:                       -367.39
# Covariance Type:                           nonrobust   LLR p-value:                   0.02308
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.1662      0.087      1.907      0.057      -0.005       0.337
# Filling potholes     0.1672      0.073      2.288      0.022       0.024       0.310
# ====================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                        IRR      2.5%     97.5%
# const             1.180783  0.995377  1.400724
# Filling potholes  1.182000  1.024240  1.364059
#
# --- Regression for Predictor: Sweeping around markets ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  207
# Model:                                       Poisson   Df Residuals:                      205
# Method:                                          MLE   Df Model:                            1
# Date:                               Wed, 21 May 2025   Pseudo R-squ.:               6.307e-05
# Time:                                       17:34:40   Log-Likelihood:                -367.37
# converged:                                      True   LL-Null:                       -367.39
# Covariance Type:                           nonrobust   LLR p-value:                    0.8295
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.2876      0.090      3.182      0.001       0.110       0.465
# Sweeping around markets     0.0136      0.063      0.215      0.830      -0.110       0.137
# ===========================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                               IRR      2.5%     97.5%
# const                    1.333173  1.116751  1.591537
# Sweeping around markets  1.013666  0.895798  1.147043
#
# --- Regression for Predictor: Information sharing ---
#                                   Poisson Regression Results
# =============================================================================================
# Dep. Variable:     Cases of malaria in the past year   No. Observations:                  207
# Model:                                       Poisson   Df Residuals:                      205
# Method:                                          MLE   Df Model:                            1
# Date:                               Wed, 21 May 2025   Pseudo R-squ.:                0.003509
# Time:                                       17:34:40   Log-Likelihood:                -366.11
# converged:                                      True   LL-Null:                       -367.39
# Covariance Type:                           nonrobust   LLR p-value:                    0.1084
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.2098      0.085      2.476      0.013       0.044       0.376
# Information sharing     0.1107      0.069      1.613      0.107      -0.024       0.245
# =======================================================================================
#
# Incidence Rate Ratios (IRR) and 95% CI:
#                           IRR      2.5%     97.5%
# const                1.233429  1.044706  1.456244
# Information sharing  1.117077  0.976464  1.277939
#
# ====== Logistic Regressions for Full Sample (Outcome: Observed breeding sites in the past year) ======
#
# --- Regression for Predictor: Community engagement in control of mosquito breeding sites ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                  282
# Model:                                                Logit   Df Residuals:                      280
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Wed, 21 May 2025   Pseudo R-squ.:                0.003426
# Time:                                              17:34:40   Log-Likelihood:                -134.33
# converged:                                             True   LL-Null:                       -134.79
# Covariance Type:                                  nonrobust   LLR p-value:                    0.3365
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                          1.2685      0.267      4.755      0.000       0.746       1.791
# Community engagement in control of mosquito breeding sites     0.3171      0.327      0.971      0.331      -0.323       0.957
# ==============================================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                                           OR      2.5%  \
# const                                               3.555556  2.107704
# Community engagement in control of mosquito bre...  1.373162  0.724079
#
#                                                        97.5%
# const                                               5.997985
# Community engagement in control of mosquito bre...  2.604099
#
# ====== Logistic Regressions for Full Sample (Outcome: Observed breeding sites in the past year) ======
#
# --- Regression for Predictor: Removing stagnant water in open places like markets and hospitals ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                  282
# Model:                                                Logit   Df Residuals:                      280
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Wed, 21 May 2025   Pseudo R-squ.:                0.002405
# Time:                                              17:34:40   Log-Likelihood:                -134.47
# converged:                                             True   LL-Null:                       -134.79
# Covariance Type:                                  nonrobust   LLR p-value:                    0.4207
# =====================================================================================================================================
#                                                                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------
# const                                                                 1.3566      0.219      6.188      0.000       0.927       1.786
# Removing stagnant water in open places like markets and hospitals     0.1482      0.185      0.802      0.423      -0.214       0.511
# =====================================================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                                           OR      2.5%  \
# const                                               3.883098  2.526717
# Removing stagnant water in open places like mar...  1.159769  0.807266
#
#                                                        97.5%
# const                                               5.967606
# Removing stagnant water in open places like mar...  1.666198
#
# --- Regression for Predictor: Mowing grass in open places ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                  282
# Model:                                                Logit   Df Residuals:                      280
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Wed, 21 May 2025   Pseudo R-squ.:                0.003143
# Time:                                              17:34:40   Log-Likelihood:                -134.37
# converged:                                             True   LL-Null:                       -134.79
# Covariance Type:                                  nonrobust   LLR p-value:                    0.3573
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                           1.3289      0.226      5.891      0.000       0.887       1.771
# Mowing grass in open places     0.1570      0.171      0.919      0.358      -0.178       0.492
# ===============================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                    OR      2.5%     97.5%
# const                        3.776701  2.427240  5.876415
# Mowing grass in open places  1.170054  0.837102  1.635435
#
# --- Regression for Predictor: Filling potholes ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                  282
# Model:                                                Logit   Df Residuals:                      280
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Wed, 21 May 2025   Pseudo R-squ.:                0.009342
# Time:                                              17:34:40   Log-Likelihood:                -133.54
# converged:                                             True   LL-Null:                       -134.79
# Covariance Type:                                  nonrobust   LLR p-value:                    0.1125
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.2573      0.205      6.136      0.000       0.856       1.659
# Filling potholes     0.3152      0.202      1.557      0.119      -0.081       0.712
# ====================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                         OR      2.5%     97.5%
# const             3.515885  2.352950  5.253596
# Filling potholes  1.370484  0.921765  2.037642
#
# --- Regression for Predictor: Sweeping around markets ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                  282
# Model:                                                Logit   Df Residuals:                      280
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Wed, 21 May 2025   Pseudo R-squ.:               0.0007330
# Time:                                              17:34:40   Log-Likelihood:                -134.70
# converged:                                             True   LL-Null:                       -134.79
# Covariance Type:                                  nonrobust   LLR p-value:                    0.6567
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       1.4076      0.233      6.051      0.000       0.952       1.864
# Sweeping around markets     0.0727      0.163      0.445      0.656      -0.247       0.393
# ===========================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                OR      2.5%     97.5%
# const                    4.086328  2.590198  6.446640
# Sweeping around markets  1.075370  0.780814  1.481046
#
# --- Regression for Predictor: Information sharing ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                  282
# Model:                                                Logit   Df Residuals:                      280
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Wed, 21 May 2025   Pseudo R-squ.:                0.003215
# Time:                                              17:34:40   Log-Likelihood:                -134.36
# converged:                                             True   LL-Null:                       -134.79
# Covariance Type:                                  nonrobust   LLR p-value:                    0.3519
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   1.3528      0.207      6.546      0.000       0.948       1.758
# Information sharing     0.1695      0.184      0.924      0.356      -0.190       0.529
# =======================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                            OR      2.5%     97.5%
# const                3.868125  2.579849  5.799717
# Information sharing  1.184731  0.826786  1.697644
#
# ====== Logistic Regressions for Rural Area (Outcome: Observed breeding sites in the past year) ======
#
# --- Regression for Predictor: Community engagement in control of mosquito breeding sites ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                   75
# Model:                                                Logit   Df Residuals:                       73
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Wed, 21 May 2025   Pseudo R-squ.:                 0.07261
# Time:                                              17:34:40   Log-Likelihood:                -32.074
# converged:                                             True   LL-Null:                       -34.585
# Covariance Type:                                  nonrobust   LLR p-value:                   0.02502
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                          0.5108      0.516      0.989      0.323      -0.501       1.523
# Community engagement in control of mosquito breeding sites     1.4945      0.655      2.282      0.022       0.211       2.778
# ==============================================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                                           OR      2.5%  \
# const                                               1.666667  0.605745
# Community engagement in control of mosquito bre...  4.457143  1.235081
#
#                                                         97.5%
# const                                                4.585718
# Community engagement in control of mosquito bre...  16.084880
#
# ====== Logistic Regressions for Rural Area (Outcome: Observed breeding sites in the past year) ======
#
# --- Regression for Predictor: Removing stagnant water in open places like markets and hospitals ---
#                                       Logit Regression Results
# ====================================================================================================
# Dep. Variable:     Observed breeding sites in the past year   No. Observations:                   75
# Model:                                                Logit   Df Residuals:                       73
# Method:                                                 MLE   Df Model:                            1
# Date:                                      Wed, 21 May 2025   Pseudo R-squ.:                 0.04284
# ...
# ====================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                         OR      2.5%      97.5%
# const             5.270852  2.126774  13.062924
# Filling potholes  0.685469  0.337386   1.392672
#
# --- Regression for Predictor: Sweeping around markets ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       73
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Wed, 21 May 2025   Pseudo R-squ.:                 0.03660
# Time:                                                          17:34:40   Log-Likelihood:                -37.453
# converged:                                                         True   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                   0.09162
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       2.0985      0.617      3.399      0.001       0.889       3.308
# Sweeping around markets    -0.5790      0.365     -1.587      0.113      -1.294       0.136
# ===========================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                OR      2.5%      97.5%
# const                    8.153977  2.431778  27.341045
# Sweeping around markets  0.560464  0.274128   1.145885
#
# --- Regression for Predictor: Information sharing ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       73
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Wed, 21 May 2025   Pseudo R-squ.:                0.006206
# Time:                                                          17:34:40   Log-Likelihood:                -38.634
# converged:                                                         True   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                    0.4873
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   1.5340      0.447      3.431      0.001       0.658       2.410
# Information sharing    -0.2337      0.337     -0.693      0.488      -0.895       0.427
# =======================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                            OR      2.5%      97.5%
# const                4.636731  1.930231  11.138185
# Information sharing  0.791628  0.408781   1.533036
#
# ====== Logistic Regressions for Urban Area (Outcome: History of malaria in the past year in the household) ======
#
# --- Regression for Predictor: Community engagement in control of mosquito breeding sites ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      205
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Wed, 21 May 2025   Pseudo R-squ.:                 0.01135
# Time:                                                          17:34:40   Log-Likelihood:                -140.36
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                   0.07260
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -0.1214      0.247     -0.492      0.623      -0.605       0.362
# Community engagement in control of mosquito breeding sites     0.5387      0.301      1.791      0.073      -0.051       1.128
# ==============================================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                                           OR      2.5%  \
# const                                               0.885714  0.546206
# Community engagement in control of mosquito bre...  1.713710  0.950468
#
#                                                        97.5%
# const                                               1.436253
# Community engagement in control of mosquito bre...  3.089849
#
# ====== Logistic Regressions for Urban Area (Outcome: History of malaria in the past year in the household) ======
#
# --- Regression for Predictor: Removing stagnant water in open places like markets and hospitals ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      205
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Wed, 21 May 2025   Pseudo R-squ.:                0.001792
# Time:                                                          17:34:40   Log-Likelihood:                -141.71
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                    0.4756
# =====================================================================================================================================
#                                                                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------
# const                                                                 0.1382      0.202      0.683      0.495      -0.258       0.535
# Removing stagnant water in open places like markets and hospitals     0.1177      0.165      0.712      0.476      -0.206       0.441
# =====================================================================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                                           OR      2.5%  \
# const                                               1.148175  0.772306
# Removing stagnant water in open places like mar...  1.124891  0.813768
#
#                                                        97.5%
# const                                               1.706974
# Removing stagnant water in open places like mar...  1.554964
#
# --- Regression for Predictor: Mowing grass in open places ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      205
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Wed, 21 May 2025   Pseudo R-squ.:                 0.01279
# Time:                                                          17:34:40   Log-Likelihood:                -140.15
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                   0.05671
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                          -0.0589      0.211     -0.279      0.780      -0.473       0.355
# Mowing grass in open places     0.2987      0.158      1.895      0.058      -0.010       0.608
# ===============================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                    OR      2.5%     97.5%
# const                        0.942759  0.623244  1.426077
# Mowing grass in open places  1.348164  0.989843  1.836198
#
# --- Regression for Predictor: Filling potholes ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      205
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Wed, 21 May 2025   Pseudo R-squ.:                0.005368
# Time:                                                          17:34:40   Log-Likelihood:                -141.21
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                    0.2170
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0794      0.192      0.413      0.679      -0.297       0.456
# Filling potholes     0.2180      0.177      1.229      0.219      -0.130       0.566
# ====================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                         OR      2.5%     97.5%
# const             1.082666  0.742809  1.578019
# Filling potholes  1.243555  0.878303  1.760700
#
# --- Regression for Predictor: Sweeping around markets ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      205
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Wed, 21 May 2025   Pseudo R-squ.:               0.0005659
# Time:                                                          17:34:40   Log-Likelihood:                -141.89
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                    0.6885
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.1800      0.210      0.859      0.391      -0.231       0.591
# Sweeping around markets     0.0592      0.148      0.401      0.689      -0.230       0.349
# ===========================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                                OR      2.5%     97.5%
# const                    1.197238  0.793801  1.805714
# Sweeping around markets  1.060972  0.794356  1.417074
#
# --- Regression for Predictor: Information sharing ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      205
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Wed, 21 May 2025   Pseudo R-squ.:               0.0009028
# Time:                                                          17:34:40   Log-Likelihood:                -141.84
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                    0.6126
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.1774      0.190      0.933      0.351      -0.195       0.550
# Information sharing     0.0829      0.164      0.506      0.613      -0.238       0.404
# =======================================================================================
#
# Odds Ratios (OR) and 95% CI:
#                            OR      2.5%     97.5%
# const                1.194110  0.822623  1.733357
# Information sharing  1.086387  0.788017  1.497731

# %%
#hierarchical regression with control variables (preventive measures vs malaria history)

import pandas as pd
import statsmodels.api as sm
import numpy as np

#Load your dataset
#step 1 Load the data
file_path = r'/content/Data of Malaria (THESIS) 17 april.xlsx'
sheet_name = 'Form responses 1'

#step 2 read the data
data = pd.read_excel(file_path, sheet_name=sheet_name)

# Map binary and ordinal variables
binary_maps = {
    'History of malaria in the past year in the household': {'Yes': 1, 'No': 0},
    'Use of malaria preventive measures': {'Yes': 1, 'No': 0},
    'Gender': {'Male': 1, 'Female': 0},
    'Level of education': {'Higher education': 1, 'Secondary level': 0},
    'Occupation': {'Employed': 0, 'Unemployed': 1}
}

ordinal_maps = {
    'Marital status': {'Divorced': 0, 'Single': 1, 'Married': 2},
    'Length of stay in area of residence': {
        'Less than 1 year': 0,
        '1-5 years': 1,
        'More than 5 years': 2
    }
}

# Apply mappings
for col, mapping in binary_maps.items():
    data[col] = data[col].map(mapping)

for col, mapping in ordinal_maps.items():
    data[col] = data[col].map(mapping)

# Convert to numeric
data['Household size'] = pd.to_numeric(data['Household size'], errors='coerce')

# Drop rows with missing values in any relevant columns
data = data.dropna(subset=[
    'History of malaria in the past year in the household',
    'Use of malaria preventive measures',
    'Age', 'Gender', 'Level of education', 'Marital status',
    'Occupation', 'Household size', 'Length of stay in area of residence',
    'Area of residence'
])

# Split rural and urban data
rural_data = data[data['Area of residence'] == 'Rural area']
urban_data = data[data['Area of residence'] == 'Urban area']

# Logistic regression function with more iterations and error handling
def run_logistic(X, y):
    X = sm.add_constant(X, has_constant='add')
    try:
        model = sm.Logit(y, X)
        result = model.fit(disp=0, maxiter=100)
        return result
    except Exception as e:
        raise RuntimeError(f"Fit failed: {str(e)}")

# Define predictor and outcome
predictor = 'Use of malaria preventive measures'
outcome = 'History of malaria in the past year in the household'

# Define control variable sets
control_vars = [
    ['Age'],
    ['Age', 'Gender'],
    ['Age', 'Gender', 'Level of education'],
    ['Age', 'Gender', 'Level of education', 'Marital status'],
    ['Age', 'Gender', 'Level of education', 'Marital status', 'Occupation'],
    ['Age', 'Gender', 'Level of education', 'Marital status', 'Occupation', 'Household size'],
    ['Age', 'Gender', 'Level of education', 'Marital status', 'Occupation', 'Household size', 'Length of stay in area of residence'],
    ['Age', 'Gender', 'Level of education', 'Marital status', 'Occupation', 'Household size', 'Length of stay in area of residence', 'Area of residence']

]

# Hierarchical logistic regression for rural/urban data
def hierarchical_logistic(area_data, area_name):
    print(f"\n=== {area_name} Logistic Regression (Hierarchical) ===")
    for i, controls in enumerate(control_vars):
        model_vars = [predictor] + controls
        X = area_data[model_vars]
        y = area_data[outcome]
        print(f"\n--- Model {i+1}: Controls: {', '.join(controls)} ---")

        try:
            result = run_logistic(X, y)
            print(result.summary())
            odds_ratios = pd.DataFrame({
                'OR': np.exp(result.params),
                '2.5%': np.exp(result.conf_int()[0]),
                '97.5%': np.exp(result.conf_int()[1])
            })
            print("\nOdds Ratios with 95% CI:")
            print(odds_ratios)
        except Exception as e:
            print(f"Model {i+1} failed: {e}")

# Run hierarchical logistic regression
hierarchical_logistic(rural_data, "Rural Area")
hierarchical_logistic(urban_data, "Urban Area")
# Out:
# === Rural Area Logistic Regression (Hierarchical) ===
#
# --- Model 1: Controls: Age ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       72
# Method:                                                             MLE   Df Model:                            2
# Date:                                                  Wed, 14 May 2025   Pseudo R-squ.:                 0.03147
# Time:                                                          11:28:53   Log-Likelihood:                -37.652
# converged:                                                        False   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                    0.2942
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                 23.3734   3.66e+04      0.001      0.999   -7.17e+04    7.17e+04
# Use of malaria preventive measures   -21.1209   3.66e+04     -0.001      1.000   -7.17e+04    7.17e+04
# Age                                   -0.0358      0.052     -0.686      0.493      -0.138       0.067
# ======================================================================================================
#
# Odds Ratios with 95% CI:
#                                               OR      2.5%     97.5%
# const                               1.415589e+10  0.000000       inf
# Use of malaria preventive measures  6.719037e-10  0.000000       inf
# Age                                 9.648059e-01  0.870918  1.068815
#
# --- Model 2: Controls: Age, Gender ---
# Model 2 failed: Fit failed: Singular matrix
#
# --- Model 3: Controls: Age, Gender, Level of education ---
# Model 3 failed: Fit failed: Singular matrix
#
# --- Model 4: Controls: Age, Gender, Level of education, Marital status ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       69
# Method:                                                             MLE   Df Model:                            5
# Date:                                                  Wed, 14 May 2025   Pseudo R-squ.:                  0.1368
# Time:                                                          11:28:53   Log-Likelihood:                -33.556
# converged:                                                        False   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                   0.05903
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                 20.2681   6034.869      0.003      0.997   -1.18e+04    1.18e+04
# Use of malaria preventive measures   -17.1797   6034.869     -0.003      0.998   -1.18e+04    1.18e+04
# Age                                   -0.0569      0.061     -0.930      0.352      -0.177       0.063
# Gender                                 2.3560      1.090      2.162      0.031       0.220       4.492
# Level of education                    -0.4454      1.191     -0.374      0.708      -2.779       1.888
# Marital status                        -0.1913      0.600     -0.319      0.750      -1.367       0.985
# ======================================================================================================
#
# Odds Ratios with 95% CI:
#                                               OR      2.5%      97.5%
# const                               6.343694e+08  0.000000        inf
# Use of malaria preventive measures  3.459004e-08  0.000000        inf
# Age                                 9.446560e-01  0.837871   1.065050
# Gender                              1.054852e+01  1.246209  89.287843
# Level of education                  6.405370e-01  0.062083   6.608665
# Marital status                      8.259153e-01  0.254841   2.676715
#
# --- Model 5: Controls: Age, Gender, Level of education, Marital status, Occupation ---
# Model 5 failed: Fit failed: Singular matrix
#
# --- Model 6: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       67
# Method:                                                             MLE   Df Model:                            7
# Date:                                                  Wed, 14 May 2025   Pseudo R-squ.:                  0.2001
# Time:                                                          11:28:54   Log-Likelihood:                -31.095
# converged:                                                        False   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                   0.02945
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                 17.6717   5158.781      0.003      0.997   -1.01e+04    1.01e+04
# Use of malaria preventive measures   -16.9461   5158.780     -0.003      0.997   -1.01e+04    1.01e+04
# Age                                   -0.0196      0.071     -0.277      0.782      -0.158       0.119
# Gender                                 2.0667      1.101      1.877      0.061      -0.092       4.225
# Level of education                    -0.5788      1.224     -0.473      0.636      -2.978       1.820
# Marital status                         0.0881      0.596      0.148      0.882      -1.080       1.256
# Occupation                             1.3610      0.940      1.447      0.148      -0.482       3.204
# Household size                         0.1781      0.181      0.984      0.325      -0.177       0.533
# ======================================================================================================
#
# Odds Ratios with 95% CI:
#                                               OR      2.5%      97.5%
# const                               4.728420e+07  0.000000        inf
# Use of malaria preventive measures  4.369306e-08  0.000000        inf
# Age                                 9.806188e-01  0.853904   1.126137
# Gender                              7.898619e+00  0.912333  68.383095
# Level of education                  5.605587e-01  0.050891   6.174525
# Marital status                      1.092079e+00  0.339638   3.511497
# Occupation                          3.900194e+00  0.617552  24.631970
# Household size                      1.194990e+00  0.838022   1.704014
#
# --- Model 7: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size, Length of stay in area of residence ---
# Model 7 failed: Fit failed: Singular matrix
#
# === Urban Area Logistic Regression (Hierarchical) ===
#
# --- Model 1: Controls: Age ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      204
# Method:                                                             MLE   Df Model:                            2
# Date:                                                  Wed, 14 May 2025   Pseudo R-squ.:                0.003018
# Time:                                                          11:28:54   Log-Likelihood:                -141.54
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                    0.6515
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                 -0.6028      0.932     -0.647      0.518      -2.430       1.224
# Use of malaria preventive measures     0.5052      0.688      0.735      0.462      -0.842       1.853
# Age                                    0.0122      0.021      0.588      0.556      -0.028       0.053
# ======================================================================================================
#
# Odds Ratios with 95% CI:
#                                           OR      2.5%     97.5%
# const                               0.547278  0.088063  3.401146
# Use of malaria preventive measures  1.657392  0.430747  6.377170
# Age                                 1.012261  0.971981  1.054210
#
# --- Model 2: Controls: Age, Gender ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      203
# Method:                                                             MLE   Df Model:                            3
# Date:                                                  Wed, 14 May 2025   Pseudo R-squ.:                0.003019
# Time:                                                          11:28:54   Log-Likelihood:                -141.54
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                    0.8357
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                 -0.6039      0.935     -0.646      0.518      -2.436       1.228
# Use of malaria preventive measures     0.5055      0.688      0.735      0.462      -0.842       1.853
# Age                                    0.0121      0.021      0.580      0.562      -0.029       0.053
# Gender                                 0.0045      0.283      0.016      0.987      -0.551       0.560
# ======================================================================================================
#
# Odds Ratios with 95% CI:
#                                           OR      2.5%     97.5%
# const                               0.546675  0.087525  3.414503
# Use of malaria preventive measures  1.657759  0.430711  6.380529
# Age                                 1.012214  0.971562  1.054567
# Gender                              1.004541  0.576388  1.750736
#
# --- Model 3: Controls: Age, Gender, Level of education ---
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.11/dist-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /usr/local/lib/python3.11/dist-packages/statsmodels/discrete/discrete_model.py:2443: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q * linpred)))
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      202
# Method:                                                             MLE   Df Model:                            4
# Date:                                                  Wed, 14 May 2025   Pseudo R-squ.:                 0.02644
# Time:                                                          11:28:54   Log-Likelihood:                -138.21
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                    0.1114
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  1.2084      1.246      0.970      0.332      -1.234       3.650
# Use of malaria preventive measures     0.4026      0.689      0.585      0.559      -0.947       1.752
# Age                                    0.0076      0.022      0.351      0.725      -0.035       0.050
# Gender                                 0.0512      0.288      0.178      0.859      -0.513       0.615
# Level of education                    -1.6967      0.776     -2.186      0.029      -3.218      -0.175
# ======================================================================================================
#
# Odds Ratios with 95% CI:
#                                           OR      2.5%      97.5%
# const                               3.348208  0.291263  38.489303
# Use of malaria preventive measures  1.495663  0.387919   5.766682
# Age                                 1.007624  0.965839   1.051217
# Gender                              1.052516  0.598624   1.850562
# Level of education                  0.183296  0.040034   0.839232
#
# --- Model 4: Controls: Age, Gender, Level of education, Marital status ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      201
# Method:                                                             MLE   Df Model:                            5
# Date:                                                  Wed, 14 May 2025   Pseudo R-squ.:                 0.02862
# Time:                                                          11:28:54   Log-Likelihood:                -137.91
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                    0.1495
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  1.1500      1.252      0.919      0.358      -1.303       3.603
# Use of malaria preventive measures     0.3381      0.694      0.487      0.626      -1.022       1.699
# Age                                   -0.0002      0.024     -0.007      0.994      -0.047       0.046
# Gender                                 0.0746      0.290      0.257      0.797      -0.493       0.642
# Level of education                    -1.6767      0.778     -2.156      0.031      -3.201      -0.153
# Marital status                         0.2398      0.305      0.786      0.432      -0.358       0.838
# ======================================================================================================
#
# Odds Ratios with 95% CI:
#                                           OR      2.5%      97.5%
# const                               3.158281  0.271629  36.721904
# Use of malaria preventive measures  1.402271  0.359754   5.465858
# Age                                 0.999831  0.954439   1.047382
# Gender                              1.077405  0.610688   1.900810
# Level of education                  0.186982  0.040724   0.858511
# Marital status                      1.271055  0.699141   2.310808
#
# --- Model 5: Controls: Age, Gender, Level of education, Marital status, Occupation ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      200
# Method:                                                             MLE   Df Model:                            6
# Date:                                                  Wed, 14 May 2025   Pseudo R-squ.:                 0.03870
# Time:                                                          11:28:54   Log-Likelihood:                -136.47
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                   0.08874
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  0.1826      1.371      0.133      0.894      -2.504       2.870
# Use of malaria preventive measures     0.4486      0.701      0.640      0.522      -0.925       1.822
# Age                                    0.0160      0.026      0.618      0.537      -0.035       0.067
# Gender                                 0.0730      0.292      0.250      0.802      -0.499       0.645
# Level of education                    -1.5699      0.781     -2.011      0.044      -3.100      -0.040
# Marital status                         0.3180      0.312      1.020      0.308      -0.293       0.929
# Occupation                             0.6057      0.361      1.678      0.093      -0.102       1.313
# ======================================================================================================
#
# Odds Ratios with 95% CI:
#                                           OR      2.5%      97.5%
# const                               1.200389  0.081721  17.632348
# Use of malaria preventive measures  1.566164  0.396458   6.186960
# Age                                 1.016089  0.965938   1.068843
# Gender                              1.075718  0.607259   1.905564
# Level of education                  0.208058  0.045035   0.961208
# Marital status                      1.374422  0.745965   2.532338
# Occupation                          1.832515  0.903196   3.718031
#
# --- Model 6: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      199
# Method:                                                             MLE   Df Model:                            7
# Date:                                                  Wed, 14 May 2025   Pseudo R-squ.:                 0.05415
# Time:                                                          11:28:54   Log-Likelihood:                -134.28
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                   0.03148
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                 -0.3576      1.422     -0.252      0.801      -3.144       2.429
# Use of malaria preventive measures     0.4667      0.733      0.637      0.524      -0.969       1.903
# Age                                    0.0116      0.026      0.443      0.658      -0.040       0.063
# Gender                                 0.1463      0.297      0.492      0.623      -0.436       0.729
# Level of education                    -1.5616      0.783     -1.995      0.046      -3.096      -0.027
# Marital status                         0.3481      0.314      1.110      0.267      -0.267       0.963
# Occupation                             0.4494      0.370      1.213      0.225      -0.277       1.175
# Household size                         0.1349      0.066      2.042      0.041       0.005       0.264
# ======================================================================================================
#
# Odds Ratios with 95% CI:
#                                           OR      2.5%      97.5%
# const                               0.699345  0.043105  11.346288
# Use of malaria preventive measures  1.594669  0.379386   6.702846
# Age                                 1.011659  0.961054   1.064928
# Gender                              1.157567  0.646312   2.073243
# Level of education                  0.209809  0.045244   0.972935
# Marital status                      1.416380  0.765908   2.619287
# Occupation                          1.567310  0.758429   3.238883
# Household size                      1.144474  1.005435   1.302739
#
# --- Model 7: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size, Length of stay in area of residence ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      198
# Method:                                                             MLE   Df Model:                            8
# Date:                                                  Wed, 14 May 2025   Pseudo R-squ.:                 0.06407
# Time:                                                          11:28:54   Log-Likelihood:                -132.87
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                   0.01984
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -0.0474      1.439     -0.033      0.974      -2.867       2.773
# Use of malaria preventive measures      0.4344      0.735      0.591      0.554      -1.005       1.874
# Age                                     0.0209      0.027      0.776      0.438      -0.032       0.074
# Gender                                  0.1176      0.300      0.392      0.695      -0.470       0.706
# Level of education                     -1.5777      0.786     -2.007      0.045      -3.118      -0.037
# Marital status                          0.3268      0.315      1.038      0.299      -0.290       0.944
# Occupation                              0.5206      0.377      1.380      0.168      -0.219       1.260
# Household size                          0.1560      0.068      2.278      0.023       0.022       0.290
# Length of stay in area of residence    -0.4338      0.262     -1.655      0.098      -0.947       0.080
# =======================================================================================================
#
# Odds Ratios with 95% CI:
#                                            OR      2.5%      97.5%
# const                                0.953724  0.056843  16.001846
# Use of malaria preventive measures   1.544006  0.365960   6.514254
# Age                                  1.021087  0.968663   1.076348
# Gender                               1.124848  0.624697   2.025435
# Level of education                   0.206440  0.044230   0.963547
# Marital status                       1.386553  0.748122   2.569804
# Occupation                           1.683098  0.803526   3.525484
# Household size                       1.168860  1.022016   1.336802
# Length of stay in area of residence  0.648043  0.387712   1.083175

# %%
import pandas as pd

# Load your dataset
#step 1 Load the data
file_path = r'/content/Data of Malaria (THESIS) 17 april.xlsx'
sheet_name = 'Form responses 1'

#step 2 read the data
data = pd.read_excel(file_path, sheet_name=sheet_name)

# === 1. Descriptive statistics for household size ===
print("=== Descriptive Statistics: Household Size ===")
household_stats = data['Household size'].describe()
print(f"Mean: {household_stats['mean']:.2f}")
print(f"Median: {data['Household size'].median():.2f}")
print(f"Standard Deviation: {data['Household size'].std():.2f}")


# === 2. Frequency tables for household environmental practices ===
practice_columns = [
    'Eliminating standing water',
    'Maintaining drainage systems used to direct water away from homes',
    'Mowing grass around the house',
    'Covering water storage containers',
    'Managing trash cans',
    'Sweeping the yard',
    'Frequency of other household environmental measures not included in the survey'
]

# Rename last variable to "other"
column_mapping = {
    'Frequency of other household environmental measures not included in the survey': 'Other'
}

data_renamed = data.rename(columns=column_mapping)

# Update column list to reflect renaming
practice_columns = [
    'Eliminating standing water',
    'Maintaining drainage systems used to direct water away from homes',
    'Mowing grass around the house',
    'Covering water storage containers',
    'Managing trash cans',
    'Sweeping the yard',
    'Other'
]

# Define a function to map categories
def simplify_freq(val):
    if pd.isna(val):
        return 'No Response'
    val = val.strip().lower()
    if val in ['daily', 'weekly']:
        return 'Weekly/Daily'
    elif val in ['monthly', 'rarely']:
        return 'Rarely/Monthly'
    elif val == 'never':
        return 'Never'
    else:
        return 'Other'

print("\n=== Frequency of Household Environmental Practices (with Percentages) ===")
for col in practice_columns:
    simplified = data_renamed[col].apply(simplify_freq)
    freq = simplified.value_counts(dropna=False)
    perc = simplified.value_counts(normalize=True, dropna=False) * 100
    combined = pd.concat([freq, perc], axis=1)
    combined.columns = ['Count', 'Percentage (%)']
    print(f"\n{col}:")
    print(combined.round(2))
# Out:
# === Descriptive Statistics: Household Size ===
# Mean: 4.59
# Median: 4.00
# Standard Deviation: 2.29
#
# === Frequency of Household Environmental Practices (with Percentages) ===
#
# Eliminating standing water:
#                             Count  Percentage (%)
# Eliminating standing water
# Rarely/Monthly                120           42.55
# Never                          92           32.62
# Weekly/Daily                   70           24.82
#
# Maintaining drainage systems used to direct water away from homes:
#                                                     Count  Percentage (%)
# Maintaining drainage systems used to direct wat...
# Rarely/Monthly                                        126           44.68
# Never                                                 108           38.30
# Weekly/Daily                                           48           17.02
#
# Mowing grass around the house:
#                                Count  Percentage (%)
# Mowing grass around the house
# Rarely/Monthly                   171           60.64
# Never                             64           22.70
# Weekly/Daily                      47           16.67
#
# Covering water storage containers:
#                                    Count  Percentage (%)
# Covering water storage containers
# Never                                102           36.17
# Rarely/Monthly                        98           34.75
# Weekly/Daily                          82           29.08
#
# Managing trash cans:
#                      Count  Percentage (%)
# Managing trash cans
# Never                  111           39.36
# Rarely/Monthly          99           35.11
# Weekly/Daily            72           25.53
#
# Sweeping the yard:
#                    Count  Percentage (%)
# Sweeping the yard
# Weekly/Daily         131           46.45
# Rarely/Monthly        92           32.62
# Never                 59           20.92
#
# Other:
#                 Count  Percentage (%)
# Other
# Never             177           62.77
# Rarely/Monthly     55           19.50
# Weekly/Daily       50           17.73

# %%
#hierarchical regression between malaria preventive measures and history of malaria (introducing controls one by one)

import pandas as pd
import statsmodels.api as sm
import numpy as np

#step 1 Load the data
file_path = r'/content/Data of Malaria (THESIS) 17 april.xlsx'
sheet_name = 'Form responses 1'

#step 2 read the data
data = pd.read_excel(file_path, sheet_name=sheet_name)


# Step 2: Map binary and ordinal variables
binary_maps = {
    'History of malaria in the past year in the household': {'Yes': 1, 'No': 0},
    'Use of malaria preventive measures': {'Yes': 1, 'No': 0},
    'Gender': {'Male': 1, 'Female': 0},
    'Level of education': {'Higher education': 1, 'Secondary level': 0},
    'Occupation': {'Employed': 0, 'Unemployed': 1}
}

ordinal_maps = {
    'Marital status': {'Divorced': 0, 'Single': 1, 'Married': 2},
    'Length of stay in area of residence': {
        'Less than 1 year': 0,
        '1-5 years': 1,
        'More than 5 years': 2
    }
}

# Apply mappings
for col, mapping in binary_maps.items():
    data[col] = data[col].map(mapping)

for col, mapping in ordinal_maps.items():
    data[col] = data[col].map(mapping)

data['Household size'] = pd.to_numeric(data['Household size'], errors='coerce')

# Drop rows with missing values
data = data.dropna(subset=[
    'History of malaria in the past year in the household',
    'Use of malaria preventive measures',
    'Age', 'Gender', 'Level of education', 'Marital status',
    'Occupation', 'Household size', 'Length of stay in area of residence',
    'Area of residence'
])

# Split rural and urban data
rural_data = data[data['Area of residence'] == 'Rural area']
urban_data = data[data['Area of residence'] == 'Urban area']

# Logistic regression function
def run_logistic(X, y):
    X = sm.add_constant(X, has_constant='add')
    try:
        model = sm.Logit(y, X)
        result = model.fit(disp=0, maxiter=100)
        return result
    except Exception as e:
        raise RuntimeError(f"Fit failed: {str(e)}")

# Variables
predictor = 'Use of malaria preventive measures'
outcome = 'History of malaria in the past year in the household'

# Control variable sets for whole sample (includes area of residence)
full_controls = [
    ['Age'],
    ['Age', 'Gender'],
    ['Age', 'Gender', 'Level of education'],
    ['Age', 'Gender', 'Level of education', 'Marital status'],
    ['Age', 'Gender', 'Level of education', 'Marital status', 'Occupation'],
    ['Age', 'Gender', 'Level of education', 'Marital status', 'Occupation', 'Household size'],
    ['Age', 'Gender', 'Level of education', 'Marital status', 'Occupation', 'Household size', 'Length of stay in area of residence'],
    ['Age', 'Gender', 'Level of education', 'Marital status', 'Occupation', 'Household size', 'Length of stay in area of residence', 'Area of residence']
]

# Control sets for subgroup (area of residence removed)
subgroup_controls = [
    ['Age'],
    ['Age', 'Gender'],
    ['Age', 'Gender', 'Level of education'],
    ['Age', 'Gender', 'Level of education', 'Marital status'],
    ['Age', 'Gender', 'Level of education', 'Marital status', 'Occupation'],
    ['Age', 'Gender', 'Level of education', 'Marital status', 'Occupation', 'Household size'],
    ['Age', 'Gender', 'Level of education', 'Marital status', 'Occupation', 'Household size', 'Length of stay in area of residence']
]

# Function for hierarchical logistic regression
def hierarchical_logistic(data_subset, area_name, controls_list):
    print(f"\n=== {area_name} Logistic Regression (Hierarchical) ===")
    for i, controls in enumerate(controls_list):
        model_vars = [predictor] + controls
        X = data_subset[model_vars]
        y = data_subset[outcome]
        print(f"\n--- Model {i+1}: Controls: {', '.join(controls)} ---")

        try:
            result = run_logistic(X, y)
            print(result.summary())
            odds_ratios = pd.DataFrame({
                'OR': np.exp(result.params),
                '2.5%': np.exp(result.conf_int()[0]),
                '97.5%': np.exp(result.conf_int()[1])
            })
            print("\nOdds Ratios with 95% CI:")
            print(odds_ratios)
        except Exception as e:
            print(f"Model {i+1} failed: {e}")

# Run hierarchical logistic regressions
hierarchical_logistic(data, "Whole Sample", full_controls)
hierarchical_logistic(rural_data, "Rural Area", subgroup_controls)
hierarchical_logistic(urban_data, "Urban Area", subgroup_controls)
# Out:
# === Whole Sample Logistic Regression (Hierarchical) ===
#
# --- Model 1: Controls: Age ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      279
# Method:                                                             MLE   Df Model:                            2
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:               7.166e-05
# Time:                                                          11:33:38   Log-Likelihood:                -187.17
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                    0.9867
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  0.5591      0.800      0.699      0.484      -1.008       2.126
# Use of malaria preventive measures     0.0216      0.584      0.037      0.970      -1.123       1.166
# Age                                   -0.0030      0.019     -0.159      0.874      -0.040       0.034
# ======================================================================================================
#
# Odds Ratios with 95% CI:
#                                           OR      2.5%     97.5%
# const                               1.749184  0.364911  8.384635
# Use of malaria preventive measures  1.021841  0.325378  3.209067
# Age                                 0.997012  0.960922  1.034457
#
# --- Model 2: Controls: Age, Gender ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      278
# Method:                                                             MLE   Df Model:                            3
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:               0.0009470
# Time:                                                          11:33:38   Log-Likelihood:                -187.01
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                    0.9495
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  0.5313      0.800      0.664      0.507      -1.037       2.100
# Use of malaria preventive measures     0.0343      0.585      0.059      0.953      -1.111       1.180
# Age                                   -0.0046      0.019     -0.244      0.807      -0.042       0.033
# Gender                                 0.1432      0.250      0.572      0.567      -0.347       0.634
# ======================================================================================================
#
# Odds Ratios with 95% CI:
#                                           OR      2.5%     97.5%
# const                               1.701120  0.354368  8.166117
# Use of malaria preventive measures  1.034919  0.329132  3.254190
# Age                                 0.995376  0.958954  1.033182
# Gender                              1.153912  0.706483  1.884707
#
# --- Model 3: Controls: Age, Gender, Level of education ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      277
# Method:                                                             MLE   Df Model:                            4
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                 0.01808
# Time:                                                          11:33:38   Log-Likelihood:                -183.80
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                    0.1487
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  2.0420      1.053      1.939      0.052      -0.022       4.106
# Use of malaria preventive measures    -0.0507      0.586     -0.087      0.931      -1.198       1.097
# Age                                   -0.0085      0.020     -0.435      0.663      -0.047       0.030
# Gender                                 0.1757      0.253      0.694      0.488      -0.321       0.672
# Level of education                    -1.4132      0.639     -2.211      0.027      -2.666      -0.160
# ======================================================================================================
#
# Odds Ratios with 95% CI:
#                                           OR      2.5%      97.5%
# const                               7.705627  0.978441  60.685013
# Use of malaria preventive measures  0.950528  0.301701   2.994705
# Age                                 0.991546  0.954346   1.030195
# Gender                              1.192140  0.725779   1.958167
# Level of education                  0.243359  0.069513   0.851976
#
# --- Model 4: Controls: Age, Gender, Level of education, Marital status ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      276
# Method:                                                             MLE   Df Model:                            5
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                 0.02006
# Time:                                                          11:33:38   Log-Likelihood:                -183.43
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                    0.1854
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  1.9734      1.059      1.863      0.062      -0.102       4.049
# Use of malaria preventive measures    -0.0969      0.589     -0.165      0.869      -1.251       1.057
# Age                                   -0.0155      0.021     -0.733      0.463      -0.057       0.026
# Gender                                 0.1954      0.254      0.768      0.442      -0.303       0.694
# Level of education                    -1.4050      0.641     -2.193      0.028      -2.661      -0.149
# Marital status                         0.2251      0.262      0.860      0.390      -0.288       0.738
# ======================================================================================================
#
# Odds Ratios with 95% CI:
#                                           OR      2.5%      97.5%
# const                               7.195149  0.902586  57.357606
# Use of malaria preventive measures  0.907617  0.286285   2.877444
# Age                                 0.984612  0.944625   1.026292
# Gender                              1.215851  0.738403   2.002014
# Level of education                  0.245359  0.069878   0.861517
# Marital status                      1.252434  0.749778   2.092074
#
# --- Model 5: Controls: Age, Gender, Level of education, Marital status, Occupation ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      275
# Method:                                                             MLE   Df Model:                            6
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                 0.03822
# Time:                                                          11:33:38   Log-Likelihood:                -180.03
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                   0.02636
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  0.8301      1.145      0.725      0.468      -1.414       3.074
# Use of malaria preventive measures    -0.0455      0.596     -0.076      0.939      -1.214       1.123
# Age                                    0.0061      0.023      0.265      0.791      -0.039       0.051
# Gender                                 0.1727      0.258      0.670      0.503      -0.332       0.678
# Level of education                    -1.3185      0.643     -2.050      0.040      -2.579      -0.058
# Marital status                         0.3349      0.268      1.251      0.211      -0.190       0.860
# Occupation                             0.8038      0.314      2.561      0.010       0.189       1.419
# ======================================================================================================
#
# Odds Ratios with 95% CI:
#                                           OR      2.5%      97.5%
# const                               2.293614  0.243182  21.632586
# Use of malaria preventive measures  0.955528  0.297098   3.073175
# Age                                 1.006128  0.961732   1.052574
# Gender                              1.188500  0.717356   1.969082
# Level of education                  0.267534  0.075838   0.943778
# Marital status                      1.397840  0.826997   2.362715
# Occupation                          2.234047  1.207516   4.133249
#
# --- Model 6: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      274
# Method:                                                             MLE   Df Model:                            7
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                 0.05529
# Time:                                                          11:33:38   Log-Likelihood:                -176.84
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                  0.004242
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  0.2796      1.184      0.236      0.813      -2.041       2.600
# Use of malaria preventive measures    -0.0158      0.615     -0.026      0.979      -1.222       1.191
# Age                                    0.0008      0.023      0.035      0.972      -0.045       0.047
# Gender                                 0.2175      0.262      0.831      0.406      -0.295       0.730
# Level of education                    -1.3281      0.645     -2.060      0.039      -2.592      -0.064
# Marital status                         0.3715      0.269      1.381      0.167      -0.156       0.899
# Occupation                             0.6122      0.323      1.893      0.058      -0.022       1.246
# Household size                         0.1502      0.061      2.458      0.014       0.030       0.270
# ======================================================================================================
#
# Odds Ratios with 95% CI:
#                                           OR      2.5%      97.5%
# const                               1.322645  0.129879  13.469370
# Use of malaria preventive measures  0.984303  0.294588   3.288841
# Age                                 1.000815  0.955921   1.047816
# Gender                              1.243011  0.744352   2.075734
# Level of education                  0.264967  0.074878   0.937627
# Marital status                      1.449946  0.855615   2.457115
# Occupation                          1.844542  0.978632   3.476621
# Household size                      1.162035  1.030888   1.309866
#
# --- Model 7: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size, Length of stay in area of residence ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      273
# Method:                                                             MLE   Df Model:                            8
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                 0.06354
# Time:                                                          11:33:38   Log-Likelihood:                -175.29
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                  0.002488
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                   0.4826      1.192      0.405      0.686      -1.854       2.819
# Use of malaria preventive measures      0.0385      0.617      0.062      0.950      -1.170       1.247
# Age                                     0.0103      0.024      0.426      0.670      -0.037       0.058
# Gender                                  0.2059      0.263      0.783      0.434      -0.310       0.722
# Level of education                     -1.3882      0.649     -2.139      0.032      -2.660      -0.116
# Marital status                          0.3411      0.270      1.261      0.207      -0.189       0.871
# Occupation                              0.7149      0.332      2.150      0.032       0.063       1.367
# Household size                          0.1771      0.064      2.755      0.006       0.051       0.303
# Length of stay in area of residence    -0.4050      0.234     -1.730      0.084      -0.864       0.054
# =======================================================================================================
#
# Odds Ratios with 95% CI:
#                                            OR      2.5%      97.5%
# const                                1.620214  0.156641  16.758685
# Use of malaria preventive measures   1.039230  0.310246   3.481110
# Age                                  1.010336  0.963673   1.059259
# Gender                               1.228600  0.733623   2.057538
# Level of education                   0.249529  0.069925   0.890455
# Marital status                       1.406558  0.827812   2.389920
# Occupation                           2.043979  1.065304   3.921744
# Household size                       1.193751  1.052458   1.354011
# Length of stay in area of residence  0.666968  0.421535   1.055302
#
# --- Model 8: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size, Length of stay in area of residence, Area of residence ---
# Model 8 failed: Fit failed: Pandas data cast to numpy dtype of object. Check input data with np.asarray(data).
#
# === Rural Area Logistic Regression (Hierarchical) ===
#
# --- Model 1: Controls: Age ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       72
# Method:                                                             MLE   Df Model:                            2
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                 0.03147
# Time:                                                          11:33:38   Log-Likelihood:                -37.652
# converged:                                                        False   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                    0.2942
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                 23.3734   3.66e+04      0.001      0.999   -7.17e+04    7.17e+04
# Use of malaria preventive measures   -21.1209   3.66e+04     -0.001      1.000   -7.17e+04    7.17e+04
# Age                                   -0.0358      0.052     -0.686      0.493      -0.138       0.067
# ======================================================================================================
#
# Odds Ratios with 95% CI:
#                                               OR      2.5%     97.5%
# const                               1.415589e+10  0.000000       inf
# Use of malaria preventive measures  6.719037e-10  0.000000       inf
# Age                                 9.648059e-01  0.870918  1.068815
#
# --- Model 2: Controls: Age, Gender ---
# Model 2 failed: Fit failed: Singular matrix
#
# --- Model 3: Controls: Age, Gender, Level of education ---
# Model 3 failed: Fit failed: Singular matrix
#
# --- Model 4: Controls: Age, Gender, Level of education, Marital status ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       69
# Method:                                                             MLE   Df Model:                            5
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                  0.1368
# Time:                                                          11:33:38   Log-Likelihood:                -33.556
# converged:                                                        False   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                   0.05903
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                 20.2681   6034.869      0.003      0.997   -1.18e+04    1.18e+04
# Use of malaria preventive measures   -17.1797   6034.869     -0.003      0.998   -1.18e+04    1.18e+04
# Age                                   -0.0569      0.061     -0.930      0.352      -0.177       0.063
# Gender                                 2.3560      1.090      2.162      0.031       0.220       4.492
# Level of education                    -0.4454      1.191     -0.374      0.708      -2.779       1.888
# Marital status                        -0.1913      0.600     -0.319      0.750      -1.367       0.985
# ======================================================================================================
#
# Odds Ratios with 95% CI:
#                                               OR      2.5%      97.5%
# const                               6.343694e+08  0.000000        inf
# Use of malaria preventive measures  3.459004e-08  0.000000        inf
# Age                                 9.446560e-01  0.837871   1.065050
# Gender                              1.054852e+01  1.246209  89.287843
# Level of education                  6.405370e-01  0.062083   6.608665
# Marital status                      8.259153e-01  0.254841   2.676715
#
# --- Model 5: Controls: Age, Gender, Level of education, Marital status, Occupation ---
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.11/dist-packages/statsmodels/discrete/discrete_model.py:2385: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# /usr/local/lib/python3.11/dist-packages/statsmodels/discrete/discrete_model.py:2443: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q * linpred)))
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Model 5 failed: Fit failed: Singular matrix
#
# --- Model 6: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       67
# Method:                                                             MLE   Df Model:                            7
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                  0.2001
# Time:                                                          11:33:38   Log-Likelihood:                -31.095
# converged:                                                        False   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                   0.02945
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                 17.6717   5158.781      0.003      0.997   -1.01e+04    1.01e+04
# Use of malaria preventive measures   -16.9461   5158.780     -0.003      0.997   -1.01e+04    1.01e+04
# Age                                   -0.0196      0.071     -0.277      0.782      -0.158       0.119
# Gender                                 2.0667      1.101      1.877      0.061      -0.092       4.225
# Level of education                    -0.5788      1.224     -0.473      0.636      -2.978       1.820
# Marital status                         0.0881      0.596      0.148      0.882      -1.080       1.256
# Occupation                             1.3610      0.940      1.447      0.148      -0.482       3.204
# Household size                         0.1781      0.181      0.984      0.325      -0.177       0.533
# ======================================================================================================
#
# Odds Ratios with 95% CI:
#                                               OR      2.5%      97.5%
# const                               4.728420e+07  0.000000        inf
# Use of malaria preventive measures  4.369306e-08  0.000000        inf
# Age                                 9.806188e-01  0.853904   1.126137
# Gender                              7.898619e+00  0.912333  68.383095
# Level of education                  5.605587e-01  0.050891   6.174525
# Marital status                      1.092079e+00  0.339638   3.511497
# Occupation                          3.900194e+00  0.617552  24.631970
# Household size                      1.194990e+00  0.838022   1.704014
#
# --- Model 7: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size, Length of stay in area of residence ---
# Model 7 failed: Fit failed: Singular matrix
#
# === Urban Area Logistic Regression (Hierarchical) ===
#
# --- Model 1: Controls: Age ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      204
# Method:                                                             MLE   Df Model:                            2
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                0.003018
# Time:                                                          11:33:38   Log-Likelihood:                -141.54
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                    0.6515
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                 -0.6028      0.932     -0.647      0.518      -2.430       1.224
# Use of malaria preventive measures     0.5052      0.688      0.735      0.462      -0.842       1.853
# Age                                    0.0122      0.021      0.588      0.556      -0.028       0.053
# ======================================================================================================
#
# Odds Ratios with 95% CI:
#                                           OR      2.5%     97.5%
# const                               0.547278  0.088063  3.401146
# Use of malaria preventive measures  1.657392  0.430747  6.377170
# Age                                 1.012261  0.971981  1.054210
#
# --- Model 2: Controls: Age, Gender ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      203
# Method:                                                             MLE   Df Model:                            3
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                0.003019
# Time:                                                          11:33:38   Log-Likelihood:                -141.54
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                    0.8357
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                 -0.6039      0.935     -0.646      0.518      -2.436       1.228
# Use of malaria preventive measures     0.5055      0.688      0.735      0.462      -0.842       1.853
# Age                                    0.0121      0.021      0.580      0.562      -0.029       0.053
# Gender                                 0.0045      0.283      0.016      0.987      -0.551       0.560
# ======================================================================================================
#
# Odds Ratios with 95% CI:
#                                           OR      2.5%     97.5%
# const                               0.546675  0.087525  3.414503
# Use of malaria preventive measures  1.657759  0.430711  6.380529
# Age                                 1.012214  0.971562  1.054567
# Gender                              1.004541  0.576388  1.750736
#
# --- Model 3: Controls: Age, Gender, Level of education ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      202
# Method:                                                             MLE   Df Model:                            4
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                 0.02644
# Time:                                                          11:33:38   Log-Likelihood:                -138.21
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                    0.1114
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  1.2084      1.246      0.970      0.332      -1.234       3.650
# Use of malaria preventive measures     0.4026      0.689      0.585      0.559      -0.947       1.752
# Age                                    0.0076      0.022      0.351      0.725      -0.035       0.050
# Gender                                 0.0512      0.288      0.178      0.859      -0.513       0.615
# Level of education                    -1.6967      0.776     -2.186      0.029      -3.218      -0.175
# ======================================================================================================
#
# Odds Ratios with 95% CI:
#                                           OR      2.5%      97.5%
# const                               3.348208  0.291263  38.489303
# Use of malaria preventive measures  1.495663  0.387919   5.766682
# Age                                 1.007624  0.965839   1.051217
# Gender                              1.052516  0.598624   1.850562
# Level of education                  0.183296  0.040034   0.839232
#
# --- Model 4: Controls: Age, Gender, Level of education, Marital status ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      201
# Method:                                                             MLE   Df Model:                            5
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                 0.02862
# Time:                                                          11:33:38   Log-Likelihood:                -137.91
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                    0.1495
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  1.1500      1.252      0.919      0.358      -1.303       3.603
# Use of malaria preventive measures     0.3381      0.694      0.487      0.626      -1.022       1.699
# Age                                   -0.0002      0.024     -0.007      0.994      -0.047       0.046
# Gender                                 0.0746      0.290      0.257      0.797      -0.493       0.642
# Level of education                    -1.6767      0.778     -2.156      0.031      -3.201      -0.153
# Marital status                         0.2398      0.305      0.786      0.432      -0.358       0.838
# ======================================================================================================
#
# Odds Ratios with 95% CI:
#                                           OR      2.5%      97.5%
# const                               3.158281  0.271629  36.721904
# Use of malaria preventive measures  1.402271  0.359754   5.465858
# Age                                 0.999831  0.954439   1.047382
# Gender                              1.077405  0.610688   1.900810
# Level of education                  0.186982  0.040724   0.858511
# Marital status                      1.271055  0.699141   2.310808
#
# --- Model 5: Controls: Age, Gender, Level of education, Marital status, Occupation ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      200
# Method:                                                             MLE   Df Model:                            6
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                 0.03870
# Time:                                                          11:33:38   Log-Likelihood:                -136.47
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                   0.08874
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  0.1826      1.371      0.133      0.894      -2.504       2.870
# Use of malaria preventive measures     0.4486      0.701      0.640      0.522      -0.925       1.822
# Age                                    0.0160      0.026      0.618      0.537      -0.035       0.067
# Gender                                 0.0730      0.292      0.250      0.802      -0.499       0.645
# Level of education                    -1.5699      0.781     -2.011      0.044      -3.100      -0.040
# Marital status                         0.3180      0.312      1.020      0.308      -0.293       0.929
# Occupation                             0.6057      0.361      1.678      0.093      -0.102       1.313
# ======================================================================================================
#
# Odds Ratios with 95% CI:
#                                           OR      2.5%      97.5%
# const                               1.200389  0.081721  17.632348
# Use of malaria preventive measures  1.566164  0.396458   6.186960
# Age                                 1.016089  0.965938   1.068843
# Gender                              1.075718  0.607259   1.905564
# Level of education                  0.208058  0.045035   0.961208
# Marital status                      1.374422  0.745965   2.532338
# Occupation                          1.832515  0.903196   3.718031
#
# --- Model 6: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      199
# Method:                                                             MLE   Df Model:                            7
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                 0.05415
# Time:                                                          11:33:38   Log-Likelihood:                -134.28
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                   0.03148
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                 -0.3576      1.422     -0.252      0.801      -3.144       2.429
# Use of malaria preventive measures     0.4667      0.733      0.637      0.524      -0.969       1.903
# Age                                    0.0116      0.026      0.443      0.658      -0.040       0.063
# Gender                                 0.1463      0.297      0.492      0.623      -0.436       0.729
# Level of education                    -1.5616      0.783     -1.995      0.046      -3.096      -0.027
# Marital status                         0.3481      0.314      1.110      0.267      -0.267       0.963
# Occupation                             0.4494      0.370      1.213      0.225      -0.277       1.175
# Household size                         0.1349      0.066      2.042      0.041       0.005       0.264
# ======================================================================================================
#
# Odds Ratios with 95% CI:
#                                           OR      2.5%      97.5%
# const                               0.699345  0.043105  11.346288
# Use of malaria preventive measures  1.594669  0.379386   6.702846
# Age                                 1.011659  0.961054   1.064928
# Gender                              1.157567  0.646312   2.073243
# Level of education                  0.209809  0.045244   0.972935
# Marital status                      1.416380  0.765908   2.619287
# Occupation                          1.567310  0.758429   3.238883
# Household size                      1.144474  1.005435   1.302739
#
# --- Model 7: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size, Length of stay in area of residence ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      198
# Method:                                                             MLE   Df Model:                            8
# Date:                                                  Mon, 19 May 2025   Pseudo R-squ.:                 0.06407
# Time:                                                          11:33:38   Log-Likelihood:                -132.87
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                   0.01984
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -0.0474      1.439     -0.033      0.974      -2.867       2.773
# Use of malaria preventive measures      0.4344      0.735      0.591      0.554      -1.005       1.874
# Age                                     0.0209      0.027      0.776      0.438      -0.032       0.074
# Gender                                  0.1176      0.300      0.392      0.695      -0.470       0.706
# Level of education                     -1.5777      0.786     -2.007      0.045      -3.118      -0.037
# Marital status                          0.3268      0.315      1.038      0.299      -0.290       0.944
# Occupation                              0.5206      0.377      1.380      0.168      -0.219       1.260
# Household size                          0.1560      0.068      2.278      0.023       0.022       0.290
# Length of stay in area of residence    -0.4338      0.262     -1.655      0.098      -0.947       0.080
# =======================================================================================================
#
# Odds Ratios with 95% CI:
#                                            OR      2.5%      97.5%
# const                                0.953724  0.056843  16.001846
# Use of malaria preventive measures   1.544006  0.365960   6.514254
# Age                                  1.021087  0.968663   1.076348
# Gender                               1.124848  0.624697   2.025435
# Level of education                   0.206440  0.044230   0.963547
# Marital status                       1.386553  0.748122   2.569804
# Occupation                           1.683098  0.803526   3.525484
# Household size                       1.168860  1.022016   1.336802
# Length of stay in area of residence  0.648043  0.387712   1.083175

# %%
#hierarchical with environmental practices as the predictor and malaria hist as outcome

import pandas as pd
import statsmodels.api as sm
import numpy as np

# Step 1: Load the data
file_path = r'/content/Data of Malaria (THESIS) 17 april.xlsx'
sheet_name = 'Form responses 1'

#step 2 read the data
data = pd.read_excel(file_path, sheet_name=sheet_name)

# Step 2: Map binary and ordinal variables
binary_maps = {
    'History of malaria in the past year in the household': {'Yes': 1, 'No': 0},
    'Engaged in household environmental measures': {'Yes': 1, 'No': 0},  # <-- updated predictor
    'Gender': {'Male': 1, 'Female': 0},
    'Level of education': {'Higher education': 1, 'Secondary level': 0},
    'Occupation': {'Employed': 0, 'Unemployed': 1}
}

ordinal_maps = {
    'Marital status': {'Divorced': 0, 'Single': 1, 'Married': 2},
    'Length of stay in area of residence': {
        'Less than 1 year': 0,
        '1-5 years': 1,
        'More than 5 years': 2
    }
}

# Apply mappings
for col, mapping in binary_maps.items():
    data[col] = data[col].map(mapping)

for col, mapping in ordinal_maps.items():
    data[col] = data[col].map(mapping)

# Convert numeric
data['Household size'] = pd.to_numeric(data['Household size'], errors='coerce')

# Drop rows with missing values in key columns
data = data.dropna(subset=[
    'History of malaria in the past year in the household',
    'Engaged in household environmental measures',
    'Age', 'Gender', 'Level of education', 'Marital status',
    'Occupation', 'Household size', 'Length of stay in area of residence',
    'Area of residence'
])

# Split rural and urban data
rural_data = data[data['Area of residence'] == 'Rural area']
urban_data = data[data['Area of residence'] == 'Urban area']

# Logistic regression helper
def run_logistic(X, y):
    X = sm.add_constant(X, has_constant='add')
    try:
        model = sm.Logit(y, X)
        result = model.fit(disp=0, maxiter=100)
        return result
    except Exception as e:
        raise RuntimeError(f"Fit failed: {str(e)}")

# Set outcome and predictor
predictor = 'Engaged in household environmental measures'
outcome = 'History of malaria in the past year in the household'

# Control variable sets (includes Area of residence for full sample only)
control_vars_full = [
    ['Age'],
    ['Age', 'Gender'],
    ['Age', 'Gender', 'Level of education'],
    ['Age', 'Gender', 'Level of education', 'Marital status'],
    ['Age', 'Gender', 'Level of education', 'Marital status', 'Occupation'],
    ['Age', 'Gender', 'Level of education', 'Marital status', 'Occupation', 'Household size'],
    ['Age', 'Gender', 'Level of education', 'Marital status', 'Occupation', 'Household size', 'Length of stay in area of residence'],
    ['Age', 'Gender', 'Level of education', 'Marital status', 'Occupation', 'Household size', 'Length of stay in area of residence', 'Area of residence']
]

# For rural/urban samples (no Area of residence)
control_vars_split = [vars[:-1] for vars in control_vars_full if 'Area of residence' in vars or len(vars) < 8]

# Hierarchical logistic regression function
def hierarchical_logistic(area_data, area_name, control_vars):
    print(f"\n=== {area_name} Logistic Regression (Hierarchical) ===")
    for i, controls in enumerate(control_vars):
        model_vars = [predictor] + controls
        X = area_data[model_vars]
        y = area_data[outcome]
        print(f"\n--- Model {i+1}: Controls: {', '.join(controls)} ---")
        try:
            result = run_logistic(X, y)
            print(result.summary())
            odds_ratios = pd.DataFrame({
                'OR': np.exp(result.params),
                '2.5%': np.exp(result.conf_int()[0]),
                '97.5%': np.exp(result.conf_int()[1])
            })
            print("\nOdds Ratios with 95% CI:")
            print(odds_ratios)
        except Exception as e:
            print(f"Model {i+1} failed: {e}")

# Run regression for full dataset
hierarchical_logistic(data, "Full Sample", control_vars_full)

# Run regression for rural and urban (excluding 'Area of residence' as a control)
hierarchical_logistic(rural_data, "Rural Area", control_vars_split)
hierarchical_logistic(urban_data, "Urban Area", control_vars_split)
# Out:
# === Full Sample Logistic Regression (Hierarchical) ===
#
# --- Model 1: Controls: Age ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      279
# Method:                                                             MLE   Df Model:                            2
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:               0.0007127
# Time:                                                          09:03:55   Log-Likelihood:                -187.05
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                    0.8751
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                           0.3422      0.742      0.461      0.645      -1.112       1.797
# Engaged in household environmental measures     0.2568      0.520      0.494      0.621      -0.762       1.275
# Age                                            -0.0031      0.019     -0.167      0.867      -0.040       0.034
# ===============================================================================================================
#
# Odds Ratios with 95% CI:
#                                                    OR      2.5%     97.5%
# const                                        1.408010  0.328789  6.029688
# Engaged in household environmental measures  1.292792  0.466830  3.580125
# Age                                          0.996866  0.960781  1.034306
#
# --- Model 2: Controls: Age, Gender ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      278
# Method:                                                             MLE   Df Model:                            3
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                0.001733
# Time:                                                          09:03:56   Log-Likelihood:                -186.86
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                    0.8852
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                           0.2977      0.745      0.399      0.690      -1.163       1.759
# Engaged in household environmental measures     0.2867      0.522      0.549      0.583      -0.737       1.310
# Age                                            -0.0049      0.019     -0.260      0.795      -0.042       0.032
# Gender                                          0.1552      0.251      0.617      0.537      -0.338       0.648
# ===============================================================================================================
#
# Odds Ratios with 95% CI:
#                                                    OR      2.5%     97.5%
# const                                        1.346774  0.312472  5.804678
# Engaged in household environmental measures  1.332057  0.478542  3.707882
# Age                                          0.995068  0.958640  1.032881
# Gender                                       1.167849  0.713494  1.911540
#
# --- Model 3: Controls: Age, Gender, Level of education ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      277
# Method:                                                             MLE   Df Model:                            4
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                 0.01847
# Time:                                                          09:03:56   Log-Likelihood:                -183.73
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                    0.1404
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                           1.7855      1.009      1.769      0.077      -0.193       3.764
# Engaged in household environmental measures     0.2075      0.523      0.397      0.692      -0.818       1.233
# Age                                            -0.0087      0.020     -0.444      0.657      -0.047       0.030
# Gender                                          0.1856      0.254      0.730      0.465      -0.313       0.684
# Level of education                             -1.3991      0.639     -2.188      0.029      -2.652      -0.146
# ===============================================================================================================
#
# Odds Ratios with 95% CI:
#                                                    OR      2.5%      97.5%
# const                                        5.962408  0.824530  43.115834
# Engaged in household environmental measures  1.230630  0.441191   3.432636
# Age                                          0.991379  0.954184   1.030025
# Gender                                       1.203883  0.731466   1.981411
# Level of education                           0.246818  0.070484   0.864291
#
# --- Model 4: Controls: Age, Gender, Level of education, Marital status ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      276
# Method:                                                             MLE   Df Model:                            5
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                 0.02034
# Time:                                                          09:03:56   Log-Likelihood:                -183.38
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                    0.1787
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                           1.6880      1.019      1.657      0.098      -0.309       3.685
# Engaged in household environmental measures     0.1926      0.524      0.367      0.713      -0.835       1.221
# Age                                            -0.0154      0.021     -0.730      0.466      -0.057       0.026
# Gender                                          0.2046      0.255      0.801      0.423      -0.296       0.705
# Level of education                             -1.3897      0.641     -2.168      0.030      -2.646      -0.134
# Marital status                                  0.2178      0.261      0.835      0.404      -0.293       0.729
# ===============================================================================================================
#
# Odds Ratios with 95% CI:
#                                                    OR      2.5%      97.5%
# const                                        5.408607  0.734340  39.835797
# Engaged in household environmental measures  1.212438  0.433752   3.389046
# Age                                          0.984708  0.944779   1.026324
# Gender                                       1.227020  0.743786   2.024207
# Level of education                           0.249156  0.070952   0.874943
# Marital status                               1.243367  0.745831   2.072803
#
# --- Model 5: Controls: Age, Gender, Level of education, Marital status, Occupation ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      275
# Method:                                                             MLE   Df Model:                            6
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                 0.03849
# Time:                                                          09:03:56   Log-Likelihood:                -179.98
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                   0.02537
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                           0.6140      1.096      0.560      0.575      -1.535       2.763
# Engaged in household environmental measures     0.1747      0.531      0.329      0.742      -0.867       1.216
# Age                                             0.0061      0.023      0.267      0.790      -0.039       0.051
# Gender                                          0.1811      0.259      0.700      0.484      -0.326       0.688
# Level of education                             -1.3065      0.643     -2.031      0.042      -2.567      -0.046
# Marital status                                  0.3295      0.267      1.234      0.217      -0.194       0.853
# Occupation                                      0.8034      0.314      2.560      0.010       0.188       1.419
# ===============================================================================================================
#
# Odds Ratios with 95% CI:
#                                                    OR      2.5%      97.5%
# const                                        1.847883  0.215487  15.846260
# Engaged in household environmental measures  1.190846  0.420362   3.373557
# Age                                          1.006151  0.961827   1.052517
# Gender                                       1.198518  0.721907   1.989793
# Level of education                           0.270767  0.076742   0.955341
# Marital status                               1.390281  0.823765   2.346399
# Occupation                                   2.233206  1.207171   4.131319
#
# --- Model 6: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      274
# Method:                                                             MLE   Df Model:                            7
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                 0.05551
# Time:                                                          09:03:56   Log-Likelihood:                -176.80
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                  0.004109
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                           0.1139      1.132      0.101      0.920      -2.104       2.332
# Engaged in household environmental measures     0.1549      0.540      0.287      0.774      -0.904       1.214
# Age                                             0.0008      0.023      0.033      0.974      -0.045       0.047
# Gender                                          0.2247      0.263      0.855      0.392      -0.290       0.740
# Level of education                             -1.3188      0.645     -2.045      0.041      -2.583      -0.055
# Marital status                                  0.3678      0.268      1.370      0.171      -0.158       0.894
# Occupation                                      0.6116      0.323      1.891      0.059      -0.022       1.246
# Household size                                  0.1500      0.061      2.454      0.014       0.030       0.270
# ===============================================================================================================
#
# Odds Ratios with 95% CI:
#                                                    OR      2.5%      97.5%
# const                                        1.120657  0.121950  10.298288
# Engaged in household environmental measures  1.167513  0.404866   3.366766
# Age                                          1.000773  0.955944   1.047705
# Gender                                       1.251995  0.748009   2.095552
# Level of education                           0.267446  0.075564   0.946582
# Marital status                               1.444549  0.853528   2.444820
# Occupation                                   1.843440  0.977888   3.475114
# Household size                               1.161827  1.030636   1.309718
#
# --- Model 7: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size, Length of stay in area of residence ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      273
# Method:                                                             MLE   Df Model:                            8
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                 0.06409
# Time:                                                          09:03:56   Log-Likelihood:                -175.19
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                  0.002297
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                           0.2868      1.138      0.252      0.801      -1.945       2.518
# Engaged in household environmental measures     0.2516      0.545      0.462      0.644      -0.817       1.320
# Age                                             0.0103      0.024      0.427      0.669      -0.037       0.057
# Gender                                          0.2159      0.264      0.817      0.414      -0.302       0.734
# Level of education                             -1.3779      0.649     -2.122      0.034      -2.650      -0.105
# Marital status                                  0.3361      0.270      1.246      0.213      -0.193       0.865
# Occupation                                      0.7161      0.333      2.153      0.031       0.064       1.368
# Household size                                  0.1775      0.064      2.756      0.006       0.051       0.304
# Length of stay in area of residence            -0.4147      0.235     -1.765      0.078      -0.875       0.046
# ===============================================================================================================
#
# Odds Ratios with 95% CI:
#                                                    OR      2.5%      97.5%
# const                                        1.332183  0.143051  12.406161
# Engaged in household environmental measures  1.286054  0.441969   3.742194
# Age                                          1.010337  0.963761   1.059164
# Gender                                       1.241025  0.739431   2.082875
# Level of education                           0.252100  0.070621   0.899940
# Marital status                               1.399492  0.824653   2.375033
# Occupation                                   2.046380  1.066432   3.926804
# Household size                               1.194238  1.052632   1.354894
# Length of stay in area of residence          0.660558  0.416771   1.046947
#
# --- Model 8: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size, Length of stay in area of residence, Area of residence ---
# Model 8 failed: Fit failed: Pandas data cast to numpy dtype of object. Check input data with np.asarray(data).
#
# === Rural Area Logistic Regression (Hierarchical) ===
#
# --- Model 1: Controls:  ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       73
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                 0.03209
# Time:                                                          09:03:56   Log-Likelihood:                -37.628
# converged:                                                         True   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                    0.1142
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                          39.8160   2.19e+07   1.82e-06      1.000    -4.3e+07     4.3e+07
# Engaged in household environmental measures   -38.5996   2.19e+07  -1.76e-06      1.000    -4.3e+07     4.3e+07
# ===============================================================================================================
#
# Odds Ratios with 95% CI:
#                                                        OR  2.5%  97.5%
# const                                        1.958221e+17   0.0    inf
# Engaged in household environmental measures  1.723503e-17   0.0    inf
#
# --- Model 2: Controls: Age ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       72
# Method:                                                             MLE   Df Model:                            2
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                 0.03848
# Time:                                                          09:03:56   Log-Likelihood:                -37.380
# converged:                                                        False   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                    0.2240
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                          25.5066   9.17e+04      0.000      1.000    -1.8e+05     1.8e+05
# Engaged in household environmental measures   -23.2245   9.17e+04     -0.000      1.000    -1.8e+05     1.8e+05
# Age                                            -0.0375      0.053     -0.708      0.479      -0.141       0.066
# ===============================================================================================================
#
# Odds Ratios with 95% CI:
#                                                        OR      2.5%     97.5%
# const                                        1.195026e+11  0.000000       inf
# Engaged in household environmental measures  8.198543e-11  0.000000       inf
# Age                                          9.631632e-01  0.868066  1.068679
#
# --- Model 3: Controls: Age, Gender ---
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       71
# Method:                                                             MLE   Df Model:                            3
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                  0.1443
# Time:                                                          09:03:56   Log-Likelihood:                -33.264
# converged:                                                        False   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                   0.01058
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                          33.1193   3.56e+06   9.31e-06      1.000   -6.97e+06    6.97e+06
# Engaged in household environmental measures   -30.4802   3.56e+06  -8.57e-06      1.000   -6.97e+06    6.97e+06
# Age                                            -0.0662      0.060     -1.101      0.271      -0.184       0.052
# Gender                                          2.4008      1.090      2.202      0.028       0.264       4.538
# ===============================================================================================================
#
# Odds Ratios with 95% CI:
#                                                        OR      2.5%      97.5%
# const                                        2.418419e+14  0.000000        inf
# Engaged in household environmental measures  5.789015e-14  0.000000        inf
# Age                                          9.359635e-01  0.831939   1.052995
# Gender                                       1.103155e+01  1.301587  93.497464
#
# --- Model 4: Controls: Age, Gender, Level of education ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       70
# Method:                                                             MLE   Df Model:                            4
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                  0.1469
# Time:                                                          09:03:56   Log-Likelihood:                -33.164
# converged:                                                        False   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                   0.02220
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                          33.3743   3.01e+06   1.11e-05      1.000    -5.9e+06     5.9e+06
# Engaged in household environmental measures   -30.2102   3.01e+06     -1e-05      1.000    -5.9e+06     5.9e+06
# Age                                            -0.0680      0.060     -1.125      0.261      -0.186       0.050
# Gender                                          2.4143      1.094      2.207      0.027       0.270       4.558
# Level of education                             -0.5141      1.192     -0.431      0.666      -2.851       1.823
# ===============================================================================================================
#
# Odds Ratios with 95% CI:
#                                                        OR      2.5%      97.5%
# const                                        3.120844e+14  0.000000        inf
# Engaged in household environmental measures  7.583355e-14  0.000000        inf
# Age                                          9.342591e-01  0.829899   1.051743
# Gender                                       1.118171e+01  1.310487  95.407762
# Level of education                           5.980518e-01  0.057772   6.190970
#
# --- Model 5: Controls: Age, Gender, Level of education, Marital status ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       69
# Method:                                                             MLE   Df Model:                            5
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                  0.1475
# Time:                                                          09:03:56   Log-Likelihood:                -33.142
# converged:                                                        False   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                   0.04287
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                          34.9691   6.61e+06   5.29e-06      1.000    -1.3e+07     1.3e+07
# Engaged in household environmental measures   -31.7656   6.61e+06  -4.81e-06      1.000    -1.3e+07     1.3e+07
# Age                                            -0.0638      0.064     -1.003      0.316      -0.188       0.061
# Gender                                          2.4068      1.094      2.199      0.028       0.262       4.552
# Level of education                             -0.4942      1.195     -0.414      0.679      -2.836       1.848
# Marital status                                 -0.1268      0.604     -0.210      0.834      -1.311       1.058
# ===============================================================================================================
#
# Odds Ratios with 95% CI:
#                                                        OR      2.5%      97.5%
# const                                        1.537820e+15  0.000000        inf
# Engaged in household environmental measures  1.600871e-14  0.000000        inf
# Age                                          9.382208e-01  0.828264   1.062775
# Gender                                       1.109867e+01  1.299135  94.817272
# Level of education                           6.100644e-01  0.058653   6.345436
# Marital status                               8.809420e-01  0.269456   2.880094
#
# --- Model 6: Controls: Age, Gender, Level of education, Marital status, Occupation ---
# Model 6 failed: Fit failed: Singular matrix
#
# --- Model 7: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       67
# Method:                                                             MLE   Df Model:                            7
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                  0.2077
# Time:                                                          09:03:56   Log-Likelihood:                -30.800
# converged:                                                        False   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                   0.02377
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                          25.0050   1.32e+05      0.000      1.000   -2.59e+05    2.59e+05
# Engaged in household environmental measures   -23.9008   1.32e+05     -0.000      1.000   -2.59e+05    2.59e+05
# Age                                            -0.0368      0.073     -0.506      0.613      -0.179       0.106
# Gender                                          2.1304      1.112      1.916      0.055      -0.049       4.310
# Level of education                             -0.6261      1.232     -0.508      0.611      -3.041       1.789
# Marital status                                  0.1362      0.600      0.227      0.821      -1.040       1.313
# Occupation                                      1.2187      0.927      1.314      0.189      -0.599       3.036
# Household size                                  0.2014      0.182      1.106      0.269      -0.155       0.558
# ===============================================================================================================
#
# Odds Ratios with 95% CI:
#                                                        OR      2.5%      97.5%
# const                                        7.236828e+10  0.000000        inf
# Engaged in household environmental measures  4.168999e-11  0.000000        inf
# Age                                          9.638920e-01  0.836011   1.111334
# Gender                                       8.418365e+00  0.951826  74.455715
# Level of education                           5.346851e-01  0.047797   5.981330
# Marital status                               1.145876e+00  0.353356   3.715884
# Occupation                                   3.382833e+00  0.549511  20.824999
# Household size                               1.223121e+00  0.856030   1.747632
#
# --- Model 8: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size, Length of stay in area of residence ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       66
# Method:                                                             MLE   Df Model:                            8
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                  0.2337
# Time:                                                          09:03:56   Log-Likelihood:                -29.789
# converged:                                                        False   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                   0.01997
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                          23.6698   6.59e+04      0.000      1.000   -1.29e+05    1.29e+05
# Engaged in household environmental measures   -22.1497   6.59e+04     -0.000      1.000   -1.29e+05    1.29e+05
# Age                                             0.0032      0.079      0.041      0.967      -0.152       0.159
# Gender                                          2.3052      1.126      2.048      0.041       0.099       4.511
# Level of education                             -1.2095      1.342     -0.901      0.368      -3.841       1.422
# Marital status                                 -0.0426      0.630     -0.068      0.946      -1.277       1.191
# Occupation                                      1.6090      1.015      1.586      0.113      -0.379       3.597
# Household size                                  0.3316      0.213      1.559      0.119      -0.085       0.748
# Length of stay in area of residence            -0.9754      0.717     -1.360      0.174      -2.381       0.430
# ===============================================================================================================
#
# Odds Ratios with 95% CI:
#                                                        OR      2.5%      97.5%
# const                                        1.904019e+10  0.000000        inf
# Engaged in household environmental measures  2.401606e-10  0.000000        inf
# Age                                          1.003238e+00  0.858939   1.171780
# Gender                                       1.002639e+01  1.104255  91.037420
# Level of education                           2.983555e-01  0.021481   4.144006
# Marital status                               9.582985e-01  0.278979   3.291774
# Occupation                                   4.997602e+00  0.684253  36.501189
# Household size                               1.393196e+00  0.918274   2.113743
# Length of stay in area of residence          3.770471e-01  0.092440   1.537907
#
# === Urban Area Logistic Regression (Hierarchical) ===
#
# --- Model 1: Controls:  ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      205
# Method:                                                             MLE   Df Model:                            1
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                0.006395
# Time:                                                          09:03:56   Log-Likelihood:                -141.06
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                    0.1778
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                          -0.5596      0.627     -0.893      0.372      -1.788       0.669
# Engaged in household environmental measures     0.8473      0.643      1.317      0.188      -0.413       2.108
# ===============================================================================================================
#
# Odds Ratios with 95% CI:
#                                                    OR      2.5%     97.5%
# const                                        0.571429  0.167280  1.952004
# Engaged in household environmental measures  2.333333  0.661446  8.231125
#
# --- Model 2: Controls: Age ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      204
# Method:                                                             MLE   Df Model:                            2
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                0.007496
# Time:                                                          09:03:56   Log-Likelihood:                -140.90
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                    0.3450
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                          -0.9047      0.883     -1.025      0.305      -2.635       0.825
# Engaged in household environmental measures     0.8481      0.644      1.317      0.188      -0.414       2.110
# Age                                             0.0116      0.021      0.557      0.577      -0.029       0.052
# ===============================================================================================================
#
# Odds Ratios with 95% CI:
#                                                    OR      2.5%     97.5%
# const                                        0.404672  0.071750  2.282370
# Engaged in household environmental measures  2.335290  0.661242  8.247480
# Age                                          1.011640  0.971303  1.053652
#
# --- Model 3: Controls: Age, Gender ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      203
# Method:                                                             MLE   Df Model:                            3
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                0.007578
# Time:                                                          09:03:56   Log-Likelihood:                -140.89
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                    0.5416
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                          -0.9234      0.891     -1.036      0.300      -2.670       0.823
# Engaged in household environmental measures     0.8589      0.648      1.326      0.185      -0.411       2.128
# Age                                             0.0111      0.021      0.531      0.595      -0.030       0.052
# Gender                                          0.0436      0.286      0.152      0.879      -0.517       0.604
# ===============================================================================================================
#
# Odds Ratios with 95% CI:
#                                                    OR      2.5%     97.5%
# const                                        0.397168  0.069246  2.277997
# Engaged in household environmental measures  2.360500  0.663213  8.401460
# Age                                          1.011195  0.970510  1.053584
# Gender                                       1.044546  0.596361  1.829556
#
# --- Model 4: Controls: Age, Gender, Level of education ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      202
# Method:                                                             MLE   Df Model:                            4
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                 0.03041
# Time:                                                          09:03:56   Log-Likelihood:                -137.65
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                   0.07093
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                           0.8533      1.210      0.705      0.481      -1.517       3.224
# Engaged in household environmental measures     0.7703      0.649      1.188      0.235      -0.501       2.041
# Age                                             0.0068      0.022      0.312      0.755      -0.036       0.049
# Gender                                          0.0871      0.290      0.300      0.764      -0.482       0.656
# Level of education                             -1.6778      0.776     -2.161      0.031      -3.199      -0.156
# ===============================================================================================================
#
# Odds Ratios with 95% CI:
#                                                    OR      2.5%      97.5%
# const                                        2.347455  0.219286  25.129553
# Engaged in household environmental measures  2.160362  0.606006   7.701515
# Age                                          1.006779  0.964962   1.050407
# Gender                                       1.090964  0.617477   1.927524
# Level of education                           0.186779  0.040786   0.855350
#
# --- Model 5: Controls: Age, Gender, Level of education, Marital status ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      201
# Method:                                                             MLE   Df Model:                            5
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                 0.03284
# Time:                                                          09:03:56   Log-Likelihood:                -137.31
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                   0.09676
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                           0.7276      1.223      0.595      0.552      -1.670       3.125
# Engaged in household environmental measures     0.7635      0.650      1.175      0.240      -0.510       2.037
# Age                                            -0.0013      0.024     -0.055      0.956      -0.048       0.045
# Gender                                          0.1115      0.292      0.382      0.703      -0.461       0.684
# Level of education                             -1.6545      0.778     -2.127      0.033      -3.179      -0.130
# Marital status                                  0.2527      0.304      0.831      0.406      -0.343       0.849
# ===============================================================================================================
#
# Odds Ratios with 95% CI:
#                                                    OR      2.5%      97.5%
# const                                        2.070091  0.188217  22.767794
# Engaged in household environmental measures  2.145682  0.600342   7.668884
# Age                                          0.998699  0.953405   1.046145
# Gender                                       1.117912  0.630626   1.981727
# Level of education                           0.191184  0.041611   0.878396
# Marital status                               1.287477  0.709284   2.337002
#
# --- Model 6: Controls: Age, Gender, Level of education, Marital status, Occupation ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      200
# Method:                                                             MLE   Df Model:                            6
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                 0.04218
# Time:                                                          09:03:56   Log-Likelihood:                -135.98
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                   0.06249
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                          -0.0933      1.323     -0.071      0.944      -2.686       2.500
# Engaged in household environmental measures     0.7605      0.656      1.160      0.246      -0.524       2.045
# Age                                             0.0139      0.026      0.539      0.590      -0.037       0.064
# Gender                                          0.1082      0.294      0.368      0.713      -0.468       0.684
# Level of education                             -1.5534      0.781     -1.990      0.047      -3.083      -0.023
# Marital status                                  0.3335      0.311      1.072      0.284      -0.276       0.943
# Occupation                                      0.5814      0.360      1.616      0.106      -0.124       1.287
# ===============================================================================================================
#
# Odds Ratios with 95% CI:
#                                                    OR      2.5%      97.5%
# const                                        0.910930  0.068138  12.178207
# Engaged in household environmental measures  2.139356  0.591907   7.732372
# Age                                          1.013956  0.964125   1.066362
# Gender                                       1.114245  0.626410   1.981996
# Level of education                           0.211524  0.045806   0.976777
# Marital status                               1.395813  0.758648   2.568115
# Occupation                                   1.788548  0.883589   3.620352
#
# --- Model 7: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      199
# Method:                                                             MLE   Df Model:                            7
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                 0.05671
# Time:                                                          09:03:56   Log-Likelihood:                -133.92
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                   0.02421
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                          -0.5454      1.362     -0.401      0.689      -3.214       2.123
# Engaged in household environmental measures     0.6951      0.663      1.048      0.295      -0.605       1.995
# Age                                             0.0097      0.026      0.371      0.711      -0.041       0.061
# Gender                                          0.1787      0.299      0.597      0.551      -0.408       0.766
# Level of education                             -1.5489      0.783     -1.979      0.048      -3.083      -0.015
# Marital status                                  0.3639      0.313      1.162      0.245      -0.250       0.978
# Occupation                                      0.4337      0.369      1.174      0.240      -0.290       1.158
# Household size                                  0.1326      0.067      1.980      0.048       0.001       0.264
# ===============================================================================================================
#
# Odds Ratios with 95% CI:
#                                                    OR      2.5%     97.5%
# const                                        0.579601  0.040195  8.357773
# Engaged in household environmental measures  2.003863  0.545894  7.355766
# Age                                          1.009707  0.959438  1.062609
# Gender                                       1.195709  0.664900  2.150277
# Level of education                           0.212491  0.045827  0.985272
# Marital status                               1.438907  0.778989  2.657872
# Occupation                                   1.542906  0.747896  3.183007
# Household size                               1.141752  1.001355  1.301834
#
# --- Model 8: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size, Length of stay in area of residence ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      198
# Method:                                                             MLE   Df Model:                            8
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                 0.06785
# Time:                                                          09:03:56   Log-Likelihood:                -132.34
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                   0.01351
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                          -0.3338      1.371     -0.243      0.808      -3.022       2.354
# Engaged in household environmental measures     0.7869      0.672      1.170      0.242      -0.531       2.105
# Age                                             0.0195      0.027      0.728      0.467      -0.033       0.072
# Gender                                          0.1530      0.302      0.506      0.613      -0.440       0.746
# Level of education                             -1.5619      0.786     -1.986      0.047      -3.103      -0.021
# Marital status                                  0.3384      0.314      1.077      0.282      -0.278       0.954
# Occupation                                      0.5100      0.377      1.354      0.176      -0.228       1.248
# Household size                                  0.1544      0.069      2.225      0.026       0.018       0.290
# Length of stay in area of residence            -0.4618      0.264     -1.752      0.080      -0.978       0.055
# ===============================================================================================================
#
# Odds Ratios with 95% CI:
#                                                    OR      2.5%      97.5%
# const                                        0.716165  0.048721  10.527213
# Engaged in household environmental measures  2.196629  0.588075   8.205039
# Age                                          1.019692  0.967551   1.074642
# Gender                                       1.165343  0.644249   2.107918
# Level of education                           0.209736  0.044909   0.979506
# Marital status                               1.402650  0.757630   2.596816
# Occupation                                   1.665374  0.796062   3.483986
# Household size                               1.166941  1.018566   1.336931
# Length of stay in area of residence          0.630175  0.375956   1.056297

# %%
#hierachical with community eng as the pred and malaria his as the outcome

import pandas as pd
import statsmodels.api as sm
import numpy as np

 #Step 1: Load the data
file_path = r'/content/Data of Malaria (THESIS) 17 april.xlsx'
sheet_name = 'Form responses 1'

#step 2 read the data
data = pd.read_excel(file_path, sheet_name=sheet_name)

# Step 2: Map binary and ordinal variables
binary_maps = {
    'History of malaria in the past year in the household': {'Yes': 1, 'No': 0},
    'Community engagement in control of mosquito breeding sites': {'Yes': 1, 'No': 0},  # <-- updated predictor
    'Gender': {'Male': 1, 'Female': 0},
    'Level of education': {'Higher education': 1, 'Secondary level': 0},
    'Occupation': {'Employed': 0, 'Unemployed': 1}
}

ordinal_maps = {
    'Marital status': {'Divorced': 0, 'Single': 1, 'Married': 2},
    'Length of stay in area of residence': {
        'Less than 1 year': 0,
        '1-5 years': 1,
        'More than 5 years': 2
    }
}

# Apply mappings
for col, mapping in binary_maps.items():
    data[col] = data[col].map(mapping)

for col, mapping in ordinal_maps.items():
    data[col] = data[col].map(mapping)

# Convert numeric
data['Household size'] = pd.to_numeric(data['Household size'], errors='coerce')

# Drop missing
data = data.dropna(subset=[
    'History of malaria in the past year in the household',
    'Community engagement in control of mosquito breeding sites',
    'Age', 'Gender', 'Level of education', 'Marital status',
    'Occupation', 'Household size', 'Length of stay in area of residence',
    'Area of residence'
])

# Split rural and urban data
rural_data = data[data['Area of residence'] == 'Rural area']
urban_data = data[data['Area of residence'] == 'Urban area']

# Logistic regression helper
def run_logistic(X, y):
    X = sm.add_constant(X, has_constant='add')
    try:
        model = sm.Logit(y, X)
        result = model.fit(disp=0, maxiter=100)
        return result
    except Exception as e:
        raise RuntimeError(f"Fit failed: {str(e)}")

# Set outcome and predictor
predictor = 'Community engagement in control of mosquito breeding sites'
outcome = 'History of malaria in the past year in the household'

# Control variable sets
control_vars_full = [
    ['Age'],
    ['Age', 'Gender'],
    ['Age', 'Gender', 'Level of education'],
    ['Age', 'Gender', 'Level of education', 'Marital status'],
    ['Age', 'Gender', 'Level of education', 'Marital status', 'Occupation'],
    ['Age', 'Gender', 'Level of education', 'Marital status', 'Occupation', 'Household size'],
    ['Age', 'Gender', 'Level of education', 'Marital status', 'Occupation', 'Household size', 'Length of stay in area of residence'],
    ['Age', 'Gender', 'Level of education', 'Marital status', 'Occupation', 'Household size', 'Length of stay in area of residence', 'Area of residence']
]

# For rural/urban: drop area control
control_vars_split = [vars[:-1] for vars in control_vars_full if len(vars) == 8] + control_vars_full[:7]

# Hierarchical regression function
def hierarchical_logistic(area_data, area_name, control_vars):
    print(f"\n=== {area_name} Logistic Regression (Hierarchical) ===")
    for i, controls in enumerate(control_vars):
        model_vars = [predictor] + controls
        X = area_data[model_vars]
        y = area_data[outcome]
        print(f"\n--- Model {i+1}: Controls: {', '.join(controls)} ---")
        try:
            result = run_logistic(X, y)
            print(result.summary())
            odds_ratios = pd.DataFrame({
                'OR': np.exp(result.params),
                '2.5%': np.exp(result.conf_int()[0]),
                '97.5%': np.exp(result.conf_int()[1])
            })
            print("\nOdds Ratios with 95% CI:")
            print(odds_ratios)
        except Exception as e:
            print(f"Model {i+1} failed: {e}")

# Run regression for full dataset
hierarchical_logistic(data, "Full Sample", control_vars_full)

# Run regression for rural and urban
hierarchical_logistic(rural_data, "Rural Area", control_vars_split)
hierarchical_logistic(urban_data, "Urban Area", control_vars_split)
# Out:
# === Full Sample Logistic Regression (Hierarchical) ===
#
# --- Model 1: Controls: Age ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      279
# Method:                                                             MLE   Df Model:                            2
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                0.006684
# Time:                                                          09:30:22   Log-Likelihood:                -185.94
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                    0.2862
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                          0.2059      0.616      0.334      0.738      -1.002       1.413
# Community engagement in control of mosquito breeding sites     0.4229      0.268      1.578      0.115      -0.102       0.948
# Age                                                           -0.0003      0.019     -0.018      0.986      -0.038       0.037
# ==============================================================================================================================
#
# Odds Ratios with 95% CI:
#                                                           OR      2.5%  \
# const                                               1.228598  0.367265
# Community engagement in control of mosquito bre...  1.526329  0.902683
# Age                                                 0.999665  0.963103
#
#                                                        97.5%
# const                                               4.109991
# Community engagement in control of mosquito bre...  2.580841
# Age                                                 1.037615
#
# --- Model 2: Controls: Age, Gender ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      278
# Method:                                                             MLE   Df Model:                            3
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                0.007295
# Time:                                                          09:30:22   Log-Likelihood:                -185.82
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                    0.4350
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                          0.1995      0.616      0.324      0.746      -1.008       1.406
# Community engagement in control of mosquito breeding sites     0.4153      0.269      1.547      0.122      -0.111       0.942
# Age                                                           -0.0018      0.019     -0.092      0.927      -0.039       0.036
# Gender                                                         0.1202      0.252      0.478      0.633      -0.373       0.613
# ==============================================================================================================================
#
# Odds Ratios with 95% CI:
#                                                           OR      2.5%  \
# const                                               1.220740  0.365119
# Community engagement in control of mosquito bre...  1.514875  0.894975
# Age                                                 0.998236  0.961317
# Gender                                              1.127698  0.688746
#
#                                                        97.5%
# const                                               4.081419
# Community engagement in control of mosquito bre...  2.564145
# Age                                                 1.036574
# Gender                                              1.846401
#
# --- Model 3: Controls: Age, Gender, Level of education ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      277
# Method:                                                             MLE   Df Model:                            4
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                 0.02555
# Time:                                                          09:30:23   Log-Likelihood:                -182.40
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                   0.04840
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                          1.6303      0.892      1.827      0.068      -0.118       3.379
# Community engagement in control of mosquito breeding sites     0.4581      0.273      1.678      0.093      -0.077       0.993
# Age                                                           -0.0052      0.020     -0.262      0.793      -0.044       0.034
# Gender                                                         0.1522      0.255      0.597      0.550      -0.347       0.651
# Level of education                                            -1.4603      0.641     -2.277      0.023      -2.717      -0.203
# ==============================================================================================================================
#
# Odds Ratios with 95% CI:
#                                                           OR      2.5%  \
# const                                               5.105612  0.888383
# Community engagement in control of mosquito bre...  1.581038  0.925889
# Age                                                 0.994832  0.957072
# Gender                                              1.164351  0.706791
# Level of education                                  0.232171  0.066041
#
#                                                         97.5%
# const                                               29.342383
# Community engagement in control of mosquito bre...   2.699762
# Age                                                  1.034083
# Gender                                               1.918126
# Level of education                                   0.816211
#
# --- Model 4: Controls: Age, Gender, Level of education, Marital status ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      276
# Method:                                                             MLE   Df Model:                            5
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                 0.02766
# Time:                                                          09:30:23   Log-Likelihood:                -182.01
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                   0.06575
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                          1.5101      0.904      1.670      0.095      -0.262       3.282
# Community engagement in control of mosquito breeding sites     0.4643      0.274      1.698      0.090      -0.072       1.000
# Age                                                           -0.0125      0.021     -0.583      0.560      -0.054       0.029
# Gender                                                         0.1732      0.256      0.677      0.499      -0.328       0.675
# Level of education                                            -1.4523      0.643     -2.259      0.024      -2.713      -0.192
# Marital status                                                 0.2331      0.263      0.887      0.375      -0.282       0.748
# ==============================================================================================================================
#
# Odds Ratios with 95% CI:
#                                                           OR      2.5%  \
# const                                               4.527072  0.769254
# Community engagement in control of mosquito bre...  1.590966  0.930768
# Age                                                 0.987619  0.947138
# Gender                                              1.189095  0.720016
# Level of education                                  0.234021  0.066366
# Marital status                                      1.262458  0.754184
#
#                                                         97.5%
# const                                               26.641898
# Community engagement in control of mosquito bre...   2.719445
# Age                                                  1.029830
# Gender                                               1.963770
# Level of education                                   0.825206
# Marital status                                       2.113278
#
# --- Model 5: Controls: Age, Gender, Level of education, Marital status, Occupation ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      275
# Method:                                                             MLE   Df Model:                            6
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                 0.04636
# Time:                                                          09:30:23   Log-Likelihood:                -178.51
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                  0.008060
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                          0.4091      0.990      0.413      0.679      -1.531       2.349
# Community engagement in control of mosquito breeding sites     0.4851      0.277      1.748      0.080      -0.059       1.029
# Age                                                            0.0096      0.023      0.414      0.679      -0.036       0.055
# Gender                                                         0.1507      0.259      0.582      0.561      -0.357       0.659
# Level of education                                            -1.3926      0.650     -2.144      0.032      -2.666      -0.120
# Marital status                                                 0.3424      0.269      1.272      0.203      -0.185       0.870
# Occupation                                                     0.8178      0.315      2.598      0.009       0.201       1.435
# ==============================================================================================================================
#
# Odds Ratios with 95% CI:
#                                                           OR      2.5%  \
# const                                               1.505405  0.216324
# Community engagement in control of mosquito bre...  1.624278  0.942920
# Age                                                 1.009692  0.964647
# Gender                                              1.162654  0.699625
# Level of education                                  0.248425  0.069549
# Marital status                                      1.408313  0.831110
# Occupation                                          2.265559  1.222471
#
#                                                         97.5%
# const                                               10.476161
# Community engagement in control of mosquito bre...   2.797989
# Age                                                  1.056841
# Gender                                               1.932126
# Level of education                                   0.887358
# Marital status                                       2.386382
# Occupation                                           4.198673
#
# --- Model 6: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      274
# Method:                                                             MLE   Df Model:                            7
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                 0.06271
# Time:                                                          09:30:23   Log-Likelihood:                -175.45
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                  0.001406
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -0.1280      1.032     -0.124      0.901      -2.150       1.894
# Community engagement in control of mosquito breeding sites     0.4681      0.281      1.669      0.095      -0.082       1.018
# Age                                                            0.0046      0.024      0.197      0.844      -0.042       0.051
# Gender                                                         0.1978      0.263      0.751      0.452      -0.318       0.714
# Level of education                                            -1.3800      0.648     -2.130      0.033      -2.650      -0.110
# Marital status                                                 0.3826      0.271      1.413      0.158      -0.148       0.913
# Occupation                                                     0.6361      0.324      1.961      0.050       0.000       1.272
# Household size                                                 0.1475      0.061      2.409      0.016       0.028       0.267
# ==============================================================================================================================
#
# Odds Ratios with 95% CI:
#                                                           OR      2.5%  \
# const                                               0.879813  0.116488
# Community engagement in control of mosquito bre...  1.596982  0.921527
# Age                                                 1.004661  0.959185
# Gender                                              1.218768  0.727488
# Level of education                                  0.251584  0.070666
# Marital status                                      1.466107  0.862318
# Occupation                                          1.889155  1.000432
# Household size                                      1.158895  1.027888
#
#                                                        97.5%
# const                                               6.645062
# Community engagement in control of mosquito bre...  2.767526
# Age                                                 1.052292
# Gender                                              2.041813
# Level of education                                  0.895683
# Marital status                                      2.492665
# Occupation                                          3.567365
# Household size                                      1.306599
#
# --- Model 7: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size, Length of stay in area of residence ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  282
# Model:                                                            Logit   Df Residuals:                      273
# Method:                                                             MLE   Df Model:                            8
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                 0.07232
# Time:                                                          09:30:23   Log-Likelihood:                -173.65
# converged:                                                         True   LL-Null:                       -187.19
# Covariance Type:                                              nonrobust   LLR p-value:                 0.0006858
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                          0.1091      1.045      0.104      0.917      -1.940       2.158
# Community engagement in control of mosquito breeding sites     0.5171      0.285      1.813      0.070      -0.042       1.076
# Age                                                            0.0156      0.024      0.637      0.524      -0.032       0.064
# Gender                                                         0.1803      0.265      0.680      0.496      -0.339       0.700
# Level of education                                            -1.4594      0.654     -2.231      0.026      -2.741      -0.178
# Marital status                                                 0.3534      0.272      1.301      0.193      -0.179       0.886
# Occupation                                                     0.7519      0.334      2.252      0.024       0.097       1.406
# Household size                                                 0.1755      0.064      2.732      0.006       0.050       0.301
# Length of stay in area of residence                           -0.4403      0.236     -1.864      0.062      -0.903       0.023
# ==============================================================================================================================
#
# Odds Ratios with 95% CI:
#                                                           OR      2.5%  \
# const                                               1.115229  0.143774
# Community engagement in control of mosquito bre...  1.677144  0.959074
# Age                                                 1.015701  0.968172
# Gender                                              1.197600  0.712291
# Level of education                                  0.232383  0.064493
# Marital status                                      1.423944  0.836041
# Occupation                                          2.121106  1.102374
# Household size                                      1.191874  1.050833
# Length of stay in area of residence                 0.643851  0.405225
#
#                                                        97.5%
# const                                               8.650640
# Community engagement in control of mosquito bre...  2.932844
# Age                                                 1.065564
# Gender                                              2.013568
# Level of education                                  0.837328
# Marital status                                      2.425260
# Occupation                                          4.081275
# Household size                                      1.351845
# Length of stay in area of residence                 1.022998
#
# --- Model 8: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size, Length of stay in area of residence, Area of residence ---
# Model 8 failed: Fit failed: Pandas data cast to numpy dtype of object. Check input data with np.asarray(data).
#
# === Rural Area Logistic Regression (Hierarchical) ===
#
# --- Model 1: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size, Length of stay in area of residence ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       66
# Method:                                                             MLE   Df Model:                            8
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                  0.2184
# Time:                                                          09:30:23   Log-Likelihood:                -30.385
# converged:                                                         True   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                   0.03031
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                          1.5294      2.651      0.577      0.564      -3.667       6.726
# Community engagement in control of mosquito breeding sites    -0.5579      1.098     -0.508      0.611      -2.710       1.594
# Age                                                            0.0125      0.078      0.161      0.872      -0.140       0.165
# Gender                                                         2.1831      1.136      1.922      0.055      -0.043       4.409
# Level of education                                            -0.9314      1.447     -0.644      0.520      -3.767       1.904
# Marital status                                                -0.0298      0.663     -0.045      0.964      -1.329       1.269
# Occupation                                                     1.6772      1.056      1.589      0.112      -0.392       3.747
# Household size                                                 0.3622      0.218      1.665      0.096      -0.064       0.789
# Length of stay in area of residence                           -1.0666      0.709     -1.505      0.132      -2.456       0.323
# ==============================================================================================================================
#
# Odds Ratios with 95% CI:
#                                                           OR      2.5%  \
# const                                               4.615446  0.025548
# Community engagement in control of mosquito bre...  0.572382  0.066511
# Age                                                 1.012595  0.869705
# Gender                                              8.873992  0.957902
# Level of education                                  0.394007  0.023126
# Marital status                                      0.970624  0.264794
# Occupation                                          5.350679  0.675566
# Household size                                      1.436506  0.937737
# Length of stay in area of residence                 0.344165  0.085781
#
#                                                          97.5%
# const                                               833.825611
# Community engagement in control of mosquito bre...    4.925838
# Age                                                   1.178961
# Gender                                               82.208564
# Level of education                                    6.712792
# Marital status                                        3.557909
# Occupation                                           42.378910
# Household size                                        2.200561
# Length of stay in area of residence                   1.380835
#
# --- Model 2: Controls: Age ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       72
# Method:                                                             MLE   Df Model:                            2
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                 0.02242
# Time:                                                          09:30:23   Log-Likelihood:                -38.004
# converged:                                                         True   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                    0.4183
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                          3.2595      1.761      1.850      0.064      -0.193       6.712
# Community engagement in control of mosquito breeding sites    -0.8383      0.823     -1.019      0.308      -2.451       0.775
# Age                                                           -0.0446      0.053     -0.841      0.400      -0.148       0.059
# ==============================================================================================================================
#
# Odds Ratios with 95% CI:
#                                                            OR      2.5%  \
# const                                               26.036629  0.824585
# Community engagement in control of mosquito bre...   0.432432  0.086184
# Age                                                  0.956409  0.862091
#
#                                                          97.5%
# const                                               822.117900
# Community engagement in control of mosquito bre...    2.169747
# Age                                                   1.061046
#
# --- Model 3: Controls: Age, Gender ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       71
# Method:                                                             MLE   Df Model:                            3
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                  0.1216
# Time:                                                          09:30:23   Log-Likelihood:                -34.147
# converged:                                                         True   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                   0.02379
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                          3.1548      1.799      1.754      0.079      -0.371       6.680
# Community engagement in control of mosquito breeding sites    -0.5432      0.852     -0.637      0.524      -2.213       1.127
# Age                                                           -0.0652      0.058     -1.119      0.263      -0.179       0.049
# Gender                                                         2.3276      1.086      2.143      0.032       0.199       4.457
# ==============================================================================================================================
#
# Odds Ratios with 95% CI:
#                                                            OR      2.5%  \
# const                                               23.447517  0.690166
# Community engagement in control of mosquito bre...   0.580911  0.109359
# Age                                                  0.936844  0.835707
# Gender                                              10.253616  1.219765
#
#                                                          97.5%
# const                                               796.599788
# Community engagement in control of mosquito bre...    3.085766
# Age                                                   1.050221
# Gender                                               86.194185
#
# --- Model 4: Controls: Age, Gender, Level of education ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       70
# Method:                                                             MLE   Df Model:                            4
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                  0.1218
# Time:                                                          09:30:23   Log-Likelihood:                -34.140
# converged:                                                         True   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                   0.05033
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                          3.2815      2.086      1.573      0.116      -0.807       7.370
# Community engagement in control of mosquito breeding sites    -0.5009      0.916     -0.547      0.585      -2.297       1.295
# Age                                                           -0.0659      0.059     -1.125      0.260      -0.181       0.049
# Gender                                                         2.3329      1.089      2.142      0.032       0.198       4.467
# Level of education                                            -0.1551      1.281     -0.121      0.904      -2.665       2.355
# ==============================================================================================================================
#
# Odds Ratios with 95% CI:
#                                                            OR      2.5%  \
# const                                               26.616170  0.446311
# Community engagement in control of mosquito bre...   0.605977  0.100556
# Age                                                  0.936214  0.834670
# Gender                                              10.308046  1.219453
# Level of education                                   0.856371  0.069569
#
#                                                           97.5%
# const                                               1587.281119
# Community engagement in control of mosquito bre...     3.651773
# Age                                                    1.050111
# Gender                                                87.133983
# Level of education                                    10.541580
#
# --- Model 5: Controls: Age, Gender, Level of education, Marital status ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       69
# Method:                                                             MLE   Df Model:                            5
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                  0.1228
# Time:                                                          09:30:23   Log-Likelihood:                -34.100
# converged:                                                         True   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                   0.08900
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                          3.3472      2.101      1.593      0.111      -0.771       7.465
# Community engagement in control of mosquito breeding sites    -0.4450      0.934     -0.476      0.634      -2.275       1.385
# Age                                                           -0.0609      0.061     -0.996      0.319      -0.181       0.059
# Gender                                                         2.3357      1.092      2.139      0.032       0.196       4.476
# Level of education                                            -0.1677      1.278     -0.131      0.896      -2.673       2.338
# Marital status                                                -0.1748      0.620     -0.282      0.778      -1.390       1.041
# ==============================================================================================================================
#
# Odds Ratios with 95% CI:
#                                                            OR      2.5%  \
# const                                               28.422122  0.462552
# Community engagement in control of mosquito bre...   0.640835  0.102763
# Age                                                  0.940908  0.834659
# Gender                                              10.336964  1.216235
# Level of education                                   0.845610  0.069031
# Marital status                                       0.839637  0.248996
#
#                                                           97.5%
# const                                               1746.436244
# Community engagement in control of mosquito bre...     3.996275
# Age                                                    1.060683
# Gender                                                87.855436
# Level of education                                    10.358425
# Marital status                                         2.831325
#
# --- Model 6: Controls: Age, Gender, Level of education, Marital status, Occupation ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       68
# Method:                                                             MLE   Df Model:                            6
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                  0.1678
# Time:                                                          09:30:23   Log-Likelihood:                -32.352
# converged:                                                         True   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                   0.04230
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                          1.2411      2.437      0.509      0.611      -3.536       6.018
# Community engagement in control of mosquito breeding sites    -0.2368      1.001     -0.236      0.813      -2.199       1.726
# Age                                                           -0.0093      0.068     -0.136      0.892      -0.143       0.125
# Gender                                                         2.1641      1.101      1.965      0.049       0.006       4.322
# Level of education                                            -0.3498      1.314     -0.266      0.790      -2.925       2.226
# Marital status                                                 0.0156      0.625      0.025      0.980      -1.209       1.241
# Occupation                                                     1.5759      0.914      1.724      0.085      -0.216       3.368
# ==============================================================================================================================
#
# Odds Ratios with 95% CI:
#                                                           OR      2.5%  \
# const                                               3.459416  0.029123
# Community engagement in control of mosquito bre...  0.789167  0.110878
# Age                                                 0.990775  0.866535
# Gender                                              8.706857  1.005807
# Level of education                                  0.704838  0.053653
# Marital status                                      1.015750  0.298360
# Occupation                                          4.835122  0.805849
#
#                                                          97.5%
# const                                               410.927912
# Community engagement in control of mosquito bre...    5.616860
# Age                                                   1.132826
# Gender                                               75.371682
# Level of education                                    9.259430
# Marital status                                        3.458069
# Occupation                                           29.010911
#
# --- Model 7: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# Model:                                                            Logit   Df Residuals:                       67
# Method:                                                             MLE   Df Model:                            7
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                  0.1862
# Time:                                                          09:30:23   Log-Likelihood:                -31.637
# converged:                                                         True   LL-Null:                       -38.875
# Covariance Type:                                              nonrobust   LLR p-value:                   0.04331
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                          1.0185      2.518      0.405      0.686      -3.916       5.953
# Community engagement in control of mosquito breeding sites    -0.4978      1.027     -0.485      0.628      -2.510       1.514
# Age                                                           -0.0281      0.071     -0.395      0.693      -0.168       0.112
# Gender                                                         2.0282      1.111      1.826      0.068      -0.149       4.205
# Level of education                                            -0.3026      1.304     -0.232      0.817      -2.859       2.254
# Marital status                                                 0.1230      0.625      0.197      0.844      -1.102       1.348
# Occupation                                                     1.1852      0.953      1.243      0.214      -0.683       3.054
# Household size                                                 0.2182      0.188      1.163      0.245      -0.150       0.586
# ==============================================================================================================================
#
# Odds Ratios with 95% CI:
#                                                           OR      2.5%  \
# const                                               2.768967  0.019915
# Community engagement in control of mosquito bre...  0.607840  0.081254
# Age                                                 0.972263  0.845532
# Gender                                              7.600634  0.861984
# Level of education                                  0.738897  0.057342
# Marital status                                      1.130929  0.332364
# Occupation                                          3.271481  0.504993
# Household size                                      1.243789  0.861132
#
#                                                          97.5%
# const                                               384.987331
# Community engagement in control of mosquito bre...    4.547073
# Age                                                   1.117988
# Gender                                               67.019352
# Level of education                                    9.521285
# Marital status                                        3.848188
# Occupation                                           21.193552
# Household size                                        1.796485
#
# --- Model 8: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size, Length of stay in area of residence ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                   75
# ...
#
# Odds Ratios with 95% CI:
#                                                           OR      2.5%  \
# const                                               3.207430  0.413046
# Community engagement in control of mosquito bre...  1.791855  0.972732
# Age                                                 1.011495  0.968887
# Gender                                              0.966400  0.543741
# Level of education                                  0.176054  0.038203
#
#                                                         97.5%
# const                                               24.906675
# Community engagement in control of mosquito bre...   3.300749
# Age                                                  1.055977
# Gender                                               1.717600
# Level of education                                   0.811325
#
# --- Model 5: Controls: Age, Gender, Level of education, Marital status ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      201
# Method:                                                             MLE   Df Model:                            5
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                 0.04112
# Time:                                                          09:30:23   Log-Likelihood:                -136.13
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                   0.03950
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                          0.9871      1.065      0.927      0.354      -1.100       3.074
# Community engagement in control of mosquito breeding sites     0.6074      0.314      1.936      0.053      -0.007       1.222
# Age                                                            0.0017      0.024      0.073      0.942      -0.045       0.049
# Gender                                                        -0.0060      0.295     -0.020      0.984      -0.584       0.572
# Level of education                                            -1.7070      0.781     -2.186      0.029      -3.238      -0.176
# Marital status                                                 0.3050      0.308      0.989      0.323      -0.299       0.909
# ==============================================================================================================================
#
# Odds Ratios with 95% CI:
#                                                           OR      2.5%  \
# const                                               2.683360  0.332954
# Community engagement in control of mosquito bre...  1.835697  0.992598
# Age                                                 1.001748  0.955822
# Gender                                              0.994019  0.557528
# Level of education                                  0.181410  0.039261
# Marital status                                      1.356622  0.741210
#
#                                                         97.5%
# const                                               21.625871
# Community engagement in control of mosquito bre...   3.394913
# Age                                                  1.049880
# Gender                                               1.772241
# Level of education                                   0.838237
# Marital status                                       2.482996
#
# --- Model 6: Controls: Age, Gender, Level of education, Marital status, Occupation ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      200
# Method:                                                             MLE   Df Model:                            6
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                 0.05051
# Time:                                                          09:30:23   Log-Likelihood:                -134.80
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                   0.02604
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                          0.1825      1.170      0.156      0.876      -2.111       2.476
# Community engagement in control of mosquito breeding sites     0.6091      0.316      1.930      0.054      -0.010       1.228
# Age                                                            0.0171      0.026      0.657      0.511      -0.034       0.068
# Gender                                                        -0.0064      0.297     -0.022      0.983      -0.588       0.576
# Level of education                                            -1.6305      0.789     -2.067      0.039      -3.176      -0.085
# Marital status                                                 0.3823      0.315      1.214      0.225      -0.235       0.999
# Occupation                                                     0.5850      0.361      1.621      0.105      -0.122       1.292
# ==============================================================================================================================
#
# Odds Ratios with 95% CI:
#                                                           OR      2.5%  \
# const                                               1.200272  0.121115
# Community engagement in control of mosquito bre...  1.838725  0.990526
# Age                                                 1.017262  0.966652
# Gender                                              0.993607  0.555229
# Level of education                                  0.195831  0.041734
# Marital status                                      1.465604  0.790653
# Occupation                                          1.795009  0.884936
#
#                                                         97.5%
# const                                               11.894907
# Community engagement in control of mosquito bre...   3.413247
# Age                                                  1.070522
# Gender                                               1.778105
# Level of education                                   0.918916
# Marital status                                       2.716736
# Occupation                                           3.641005
#
# --- Model 7: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      199
# Method:                                                             MLE   Df Model:                            7
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                 0.06556
# Time:                                                          09:30:23   Log-Likelihood:                -132.66
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                  0.009483
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -0.3786      1.219     -0.311      0.756      -2.767       2.010
# Community engagement in control of mosquito breeding sites     0.6058      0.319      1.900      0.057      -0.019       1.231
# Age                                                            0.0130      0.026      0.494      0.622      -0.039       0.065
# Gender                                                         0.0706      0.303      0.233      0.816      -0.523       0.664
# Level of education                                            -1.5944      0.786     -2.028      0.043      -3.135      -0.054
# Marital status                                                 0.4136      0.317      1.305      0.192      -0.208       1.035
# Occupation                                                     0.4361      0.371      1.176      0.239      -0.291       1.163
# Household size                                                 0.1353      0.067      2.016      0.044       0.004       0.267
# ==============================================================================================================================
#
# Odds Ratios with 95% CI:
#                                                           OR      2.5%  \
# const                                               0.684852  0.062825
# Community engagement in control of mosquito bre...  1.832782  0.981131
# Age                                                 1.013079  0.962125
# Gender                                              1.073162  0.592941
# Level of education                                  0.203039  0.043497
# Marital status                                      1.512192  0.812454
# Occupation                                          1.546725  0.747868
# Household size                                      1.144865  1.003757
#
#                                                        97.5%
# const                                               7.465572
# Community engagement in control of mosquito bre...  3.423690
# Age                                                 1.066730
# Gender                                              1.942311
# Level of education                                  0.947770
# Marital status                                      2.814590
# Occupation                                          3.198903
# Household size                                      1.305811
#
# --- Model 8: Controls: Age, Gender, Level of education, Marital status, Occupation, Household size, Length of stay in area of residence ---
#                                             Logit Regression Results
# ================================================================================================================
# Dep. Variable:     History of malaria in the past year in the household   No. Observations:                  207
# Model:                                                            Logit   Df Residuals:                      198
# Method:                                                             MLE   Df Model:                            8
# Date:                                                  Tue, 20 May 2025   Pseudo R-squ.:                 0.07861
# Time:                                                          09:30:23   Log-Likelihood:                -130.81
# converged:                                                         True   LL-Null:                       -141.97
# Covariance Type:                                              nonrobust   LLR p-value:                  0.004356
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                         -0.1373      1.235     -0.111      0.911      -2.557       2.282
# Community engagement in control of mosquito breeding sites     0.6855      0.327      2.098      0.036       0.045       1.326
# Age                                                            0.0248      0.027      0.913      0.361      -0.028       0.078
# Gender                                                         0.0235      0.307      0.077      0.939      -0.578       0.625
# Level of education                                            -1.6162      0.789     -2.048      0.041      -3.163      -0.070
# Marital status                                                 0.3976      0.317      1.253      0.210      -0.224       1.019
# Occupation                                                     0.5269      0.379      1.391      0.164      -0.215       1.269
# Household size                                                 0.1586      0.069      2.287      0.022       0.023       0.294
# Length of stay in area of residence                           -0.5060      0.268     -1.890      0.059      -1.031       0.019
# ==============================================================================================================================
#
# Odds Ratios with 95% CI:
#                                                           OR      2.5%  \
# const                                               0.871736  0.077538
# Community engagement in control of mosquito bre...  1.984851  1.046198
# Age                                                 1.025143  0.971922
# Gender                                              1.023778  0.561143
# Level of education                                  0.198658  0.042312
# Marital status                                      1.488202  0.799080
# Occupation                                          1.693611  0.806327
# Household size                                      1.171830  1.022947
# Length of stay in area of residence                 0.602916  0.356798
#
#                                                        97.5%
# const                                               9.800618
# Community engagement in control of mosquito bre...  3.765667
# Age                                                 1.081278
# Gender                                              1.867831
# Level of education                                  0.932722
# Marital status                                      2.771620
# Occupation                                          3.557265
# Household size                                      1.342381
# Length of stay in area of residence                 1.018805
